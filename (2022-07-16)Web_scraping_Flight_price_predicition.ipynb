# %%
import selenium
import pandas as pd
from selenium import webdriver
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.makemytrip.com/flight/search?cabinClass=E&ccde=IN&deviceMemory=8&intl=false&itinerary=DEL-MAA-01/08/2022&lang=&msExperiments=showFare%3Atrue&msv=2&pafs&paxType=A-1_C-0_I-0&ssr=true&tripType=O&pwa=false&cmp=SEO')

# %%
company=[]
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue

# %%
company
# Out:
# ['SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara']

# %%
len(company)
# Out:
# 17

# %%
depart_time=[]
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(depart_time)
# Out:
# 17

# %%
depart_time
# Out:
# ['08:45',
#  '07:10',
#  '08:30',
#  '12:55',
#  '17:25',
#  '19:10',
#  '20:30',
#  '09:50',
#  '15:40',
#  '07:00',
#  '17:25',
#  '19:55',
#  '05:55',
#  '09:45',
#  '16:15',
#  '20:40',
#  '13:35']

# %%
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[16]/div[1]/div[2]/div[2]/label/div/div/div[2]/p
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[17]/div[1]/div[2]/div[2]/label/div/div/div[2]/p

# %%
flight_time=[]
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(flight_time)
# Out:
# 17

# %%
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[16]/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[17]/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span

# %%
arrival_time=[]
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(arrival_time)
# Out:
# 17

# %%
num_stops=[]
stop_location=[]
source=[]
destination=[]
days_remaining=[]
day=[]
for i in range(0,17):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Chennai')
    days_remaining.append(0)
    day.append('Monday')

# %%
len(num_stops)
# Out:
# 38

# %%
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[1]/div[1]/div[2]/div[4]/div/div/p
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[2]/div[1]/div[2]/div[4]/div/div/p

# %%
price=[]
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(price)
# Out:
# 17

# %%
company=company[0:17]

# %%
depart_time=depart_time[0:17]

# %%
stop_location=stop_location[0:17]

# %%
stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span")
stop_1.click()
time.sleep(5)

# %%
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[1]/div[1]/div[2]/div[1]/div/p[1]
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[2]/div[1]/div[2]/div[1]/div/p[1]

# %%
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue

# %%
len(company)
# Out:
# 38

# %%
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[1]/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[2]/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span

# %%
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(depart_time)
# Out:
# 38

# %%
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(flight_time)
# Out:
# 38

# %%
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(arrival_time)
# Out:
# 38

# %%
for i in range(21):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Chennai')
    days_remaining.append(0)
    day.append('Monday')

# %%
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[26]/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p
#/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div[29]/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p

# %%
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(stop_location)
# Out:
# 38

# %%
len(day)
# Out:
# 38

# %%
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue

# %%
len(price)
# Out:
# 38

# %%
url='https://www.makemytrip.com/flight/search?cabinClass=E&ccde=IN&deviceMemory=8&intl=false&itinerary=BOM-MAA-01/08/2022&lang=&msExperiments=showFare%3Atrue&msv=2&pafs&paxType=A-1_C-0_I-0&ssr=true&tripType=O&pwa=false&cmp=SEO'
driver.get(url)

# %%
#stop_0=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[1]/div/span[1]/span/span")
#stop_0.click()
#time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Chennai')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
# Out:
# company: 53
# new_count: 15
# depart_time: 53
# flight_time: 53
# arrival_time: 53
# stop_location: 53
# stop_location: 53

# %%
#now for stops
driver.get(url)
stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Chennai')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 71
# new_count: 18
# depart_time: 71
# flight_time: 71
# arrival_time: 71
# stop_location: 71
# price: 71

# %%
company=company[0:53]
depart_time=depart_time[0:53]
flight_time=flight_time[0:53]
arrival_time=arrival_time[0:53]
stop_location=stop_location[0:53]
num_stops=num_stops[0:53]
source=source[0:53]
destination=destination[0:53]
days_remaining=days_remaining[0:53]
day=day[0:53]
price=price[0:53]

# %%
url='https://www.makemytrip.com/flight/search?cabinClass=E&ccde=IN&deviceMemory=8&intl=false&itinerary=BOM-MAA-11/08/2022&lang=&msExperiments=showFare%3Atrue&msv=2&pafs&paxType=A-1_C-0_I-0&ssr=true&tripType=O&pwa=false&cmp=SEO'
driver.get(url)

# %%
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 62
# new_count: 9
# depart_time: 62
# flight_time: 62
# arrival_time: 62
# stop_location: 62
# price: 62

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 71
# new_count: 9
# depart_time: 71
# flight_time: 71
# arrival_time: 71
# stop_location: 71
# price: 71

# %%
url='https://www.makemytrip.com/flight/search?cabinClass=E&ccde=IN&deviceMemory=8&intl=false&itinerary=BOM-MAA-21/08/2022&lang=&msExperiments=showFare%3Atrue&msv=2&pafs&paxType=A-1_C-0_I-0&ssr=true&tripType=O&pwa=false&cmp=SEO'
driver.get(url)

# %%
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 88
# new_count: 17
# depart_time: 88
# flight_time: 88
# arrival_time: 88
# stop_location: 88
# price: 88

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 97
# new_count: 9
# depart_time: 97
# flight_time: 97
# arrival_time: 97
# stop_location: 97
# price: 97

# %%
url='https://www.makemytrip.com/flight/search?cabinClass=E&ccde=IN&deviceMemory=8&intl=false&itinerary=BOM-MAA-30/08/2022&lang=&msExperiments=showFare%3Atrue&msv=2&pafs&paxType=A-1_C-0_I-0&ssr=true&tripType=O&pwa=false&cmp=SEO'
driver.get(url)

# %%
#non-stop-mumbai-chennai-30days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 106
# new_count: 9
# depart_time: 106
# flight_time: 106
# arrival_time: 106
# stop_location: 106
# price: 106

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 124
# new_count: 18
# depart_time: 124
# flight_time: 124
# arrival_time: 124
# stop_location: 124
# price: 124

# %%
#non-stop-mumbai-chennai-40days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 133
# new_count: 9
# depart_time: 133
# flight_time: 133
# arrival_time: 133
# stop_location: 133
# price: 133

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Chennai')
    days_remaining.append(40)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 151
# new_count: 18
# depart_time: 151
# flight_time: 151
# arrival_time: 151
# stop_location: 151
# price: 151

# %%
#non-stop-coimbatore-chennai-0days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 158
# new_count: 7
# depart_time: 158
# flight_time: 158
# arrival_time: 158
# stop_location: 158
# price: 158

# %%
company=company[0:190]
depart_time=depart_time[0:190]
flight_time=flight_time[0:190]
arrival_time=arrival_time[0:190]
stop_location=stop_location[0:190]
num_stops=num_stops[0:190]
source=source[0:190]
destination=destination[0:190]
days_remaining=days_remaining[0:190]
day=day[0:190]
price=price[0:190]

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 161
# new_count: 3
# depart_time: 161
# flight_time: 161
# arrival_time: 161
# stop_location: 161
# price: 161

# %%
#non-stop-coimbatore-chennai-10days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 169
# new_count: 8
# depart_time: 169
# flight_time: 169
# arrival_time: 169
# stop_location: 169
# price: 169

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 172
# new_count: 3
# depart_time: 172
# flight_time: 172
# arrival_time: 172
# stop_location: 172
# price: 172

# %%
#non-stop-coimbatore-chennai-20days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 180
# new_count: 8
# depart_time: 180
# flight_time: 180
# arrival_time: 180
# stop_location: 180
# price: 180

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 183
# new_count: 3
# depart_time: 183
# flight_time: 183
# arrival_time: 183
# stop_location: 183
# price: 183

# %%
#non-stop-coimbatore-chennai-30days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 191
# new_count: 8
# depart_time: 191
# flight_time: 191
# arrival_time: 191
# stop_location: 191
# price: 191

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Coimbatore')
    destination.append('Chennai')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 193
# new_count: 3
# depart_time: 193
# flight_time: 193
# arrival_time: 193
# stop_location: 193
# price: 193

# %%
#non-stop-new_delhi-mumbai-0days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 211
# new_count: 21
# depart_time: 211
# flight_time: 211
# arrival_time: 211
# stop_location: 211
# price: 211

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 229
# new_count: 18
# depart_time: 229
# flight_time: 229
# arrival_time: 229
# stop_location: 229
# price: 229

# %%
#non-stop-new_delhi-mumbai-10days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 250
# new_count: 21
# depart_time: 250
# flight_time: 250
# arrival_time: 250
# stop_location: 250
# price: 250

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 271
# new_count: 21
# depart_time: 271
# flight_time: 271
# arrival_time: 271
# stop_location: 271
# price: 271

# %%
#non-stop-new_delhi-mumbai-20days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 291
# new_count: 21
# depart_time: 291
# flight_time: 291
# arrival_time: 291
# stop_location: 291
# price: 291

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 309
# new_count: 18
# depart_time: 309
# flight_time: 309
# arrival_time: 309
# stop_location: 309
# price: 309

# %%
#non-stop-new_delhi-mumbai-30days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 330
# new_count: 21
# depart_time: 330
# flight_time: 330
# arrival_time: 330
# stop_location: 330
# price: 330

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 348
# new_count: 18
# depart_time: 348
# flight_time: 348
# arrival_time: 348
# stop_location: 348
# price: 348

# %%
#non-stop-new_delhi-mumbai-40days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(40)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 369
# new_count: 21
# depart_time: 369
# flight_time: 369
# arrival_time: 369
# stop_location: 369
# price: 369

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Mumbai')
    days_remaining.append(40)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 390
# new_count: 21
# depart_time: 390
# flight_time: 390
# arrival_time: 390
# stop_location: 390
# price: 390

# %%
#non-stop-bangalore-mumbai-0days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 411
# new_count: 21
# depart_time: 411
# flight_time: 411
# arrival_time: 411
# stop_location: 411
# price: 411

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 432
# new_count: 21
# depart_time: 432
# flight_time: 432
# arrival_time: 432
# stop_location: 432
# price: 432

# %%
#non-stop-bangalore-mumbai-10days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 453
# new_count: 21
# depart_time: 453
# flight_time: 453
# arrival_time: 453
# stop_location: 453
# price: 453

# %%
#now for stops
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 474
# new_count: 21
# depart_time: 474
# flight_time: 474
# arrival_time: 474
# stop_location: 474
# price: 474

# %%
#non-stop-bangalore-mumbai-20days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 495
# new_count: 21
# depart_time: 495
# flight_time: 495
# arrival_time: 495
# stop_location: 495
# price: 495

# %%
#now for stops bangalore- mumbai - 20 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 516
# new_count: 21
# depart_time: 516
# flight_time: 516
# arrival_time: 516
# stop_location: 516
# price: 516

# %%
#non-stop-bangalore-mumbai-30days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 537
# new_count: 21
# depart_time: 537
# flight_time: 537
# arrival_time: 537
# stop_location: 537
# price: 537

# %%
#now for stops bangalore- mumbai - 30 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 558
# new_count: 21
# depart_time: 558
# flight_time: 558
# arrival_time: 558
# stop_location: 558
# price: 558

# %%
#non-stop-bangalore-mumbai-40days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(40)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 579
# new_count: 21
# depart_time: 579
# flight_time: 579
# arrival_time: 579
# stop_location: 579
# price: 579

# %%
#now for stops bangalore- mumbai - 40 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Mumbai')
    days_remaining.append(40)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 597
# new_count: 18
# depart_time: 597
# flight_time: 597
# arrival_time: 597
# stop_location: 597
# price: 597

# %%
#non-stop-chennai-mumbai-0days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 614
# new_count: 17
# depart_time: 614
# flight_time: 614
# arrival_time: 614
# stop_location: 614
# price: 614

# %%
#now for stops Chennai- mumbai - 0 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 628
# new_count: 14
# depart_time: 628
# flight_time: 628
# arrival_time: 628
# stop_location: 628
# price: 628

# %%
#non-stop-chennai-mumbai-10days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 646
# new_count: 18
# depart_time: 646
# flight_time: 646
# arrival_time: 646
# stop_location: 646
# price: 646

# %%
#now for stops Chennai- mumbai - 10 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 660
# new_count: 14
# depart_time: 660
# flight_time: 660
# arrival_time: 660
# stop_location: 660
# price: 660

# %%
#non-stop-chennai-mumbai-20days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 678
# new_count: 18
# depart_time: 678
# flight_time: 678
# arrival_time: 678
# stop_location: 678
# price: 678

# %%
#now for stops Chennai- mumbai - 20 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 695
# new_count: 17
# depart_time: 695
# flight_time: 695
# arrival_time: 695
# stop_location: 695
# price: 695

# %%
#non-stop-chennai-mumbai-30days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 712
# new_count: 17
# depart_time: 712
# flight_time: 712
# arrival_time: 712
# stop_location: 712
# price: 712

# %%
#now for stops Chennai- mumbai - 30 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 728
# new_count: 16
# depart_time: 728
# flight_time: 728
# arrival_time: 728
# stop_location: 728
# price: 728

# %%
#non-stop-chennai-mumbai-40days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(40)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 745
# new_count: 17
# depart_time: 745
# flight_time: 745
# arrival_time: 745
# stop_location: 745
# price: 745

# %%
#now for stops Chennai- mumbai - 40 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Chennai')
    destination.append('Mumbai')
    days_remaining.append(40)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 760
# new_count: 15
# depart_time: 760
# flight_time: 760
# arrival_time: 760
# stop_location: 760
# price: 760

# %%
#non-stop-Delhi-Hyderabad-0days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Hyderabad')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 781
# new_count: 21
# depart_time: 781
# flight_time: 781
# arrival_time: 781
# stop_location: 781
# price: 781

# %%
#now for stops Delhi- Hyderabad -0 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Hrderabad')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 802
# new_count: 21
# depart_time: 802
# flight_time: 802
# arrival_time: 802
# stop_location: 802
# price: 802

# %%
#non-stop-Delhi-Hyderabad-10days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Hyderabad')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 844
# new_count: 21
# depart_time: 844
# flight_time: 844
# arrival_time: 844
# stop_location: 844
# price: 844

# %%
#now for stops Delhi- Hyderabad -10 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Hrderabad')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 865
# new_count: 21
# depart_time: 865
# flight_time: 865
# arrival_time: 865
# stop_location: 865
# price: 865

# %%
#non-stop-Delhi-Hyderabad-20days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Hyderabad')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 886
# new_count: 21
# depart_time: 886
# flight_time: 886
# arrival_time: 886
# stop_location: 886
# price: 886

# %%
#now for stops Delhi- Hyderabad -20 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Hrderabad')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 907
# new_count: 21
# depart_time: 907
# flight_time: 907
# arrival_time: 907
# stop_location: 907
# price: 907

# %%
#non-stop-Delhi-Hyderabad-30days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Hyderabad')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 928
# new_count: 21
# depart_time: 928
# flight_time: 928
# arrival_time: 928
# stop_location: 928
# price: 928

# %%
#now for stops Delhi- Hyderabad -30 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Hrderabad')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 949
# new_count: 21
# depart_time: 949
# flight_time: 949
# arrival_time: 949
# stop_location: 949
# price: 949

# %%
#non-stop-Delhi-Hyderabad-40days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Hyderabad')
    days_remaining.append(40)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 970
# new_count: 21
# depart_time: 970
# flight_time: 970
# arrival_time: 970
# stop_location: 970
# price: 970

# %%
#now for stops Delhi- Hyderabad -40 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Hrderabad')
    days_remaining.append(40)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 991
# new_count: 21
# depart_time: 991
# flight_time: 991
# arrival_time: 991
# stop_location: 991
# price: 991

# %%
#non-stop-Bangalore-Hyderabad-0 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1006
# new_count: 15
# depart_time: 1006
# flight_time: 1006
# arrival_time: 1006
# stop_location: 1006
# price: 1006

# %%
#now for stops Bangalore- Hyderabad -0 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1025
# new_count: 19
# depart_time: 1025
# flight_time: 1025
# arrival_time: 1025
# stop_location: 1025
# price: 1025

# %%
#non-stop-Bangalore-Hyderabad-10 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1040
# new_count: 15
# depart_time: 1040
# flight_time: 1040
# arrival_time: 1040
# stop_location: 1040
# price: 1040

# %%
#now for stops Bangalore- Hyderabad -10 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1061
# new_count: 21
# depart_time: 1061
# flight_time: 1061
# arrival_time: 1061
# stop_location: 1061
# price: 1061

# %%
#non-stop-Bangalore-Hyderabad-20 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1076
# new_count: 15
# depart_time: 1076
# flight_time: 1076
# arrival_time: 1076
# stop_location: 1076
# price: 1076

# %%
#now for stops Bangalore- Hyderabad -20 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1097
# new_count: 21
# depart_time: 1097
# flight_time: 1097
# arrival_time: 1097
# stop_location: 1097
# price: 1097

# %%
#non-stop-Bangalore-Hyderabad-30 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1112
# new_count: 15
# depart_time: 1112
# flight_time: 1112
# arrival_time: 1112
# stop_location: 1112
# price: 1112

# %%
#now for stops Bangalore- Hyderabad -30 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1166
# new_count: 19
# depart_time: 1166
# flight_time: 1166
# arrival_time: 1166
# stop_location: 1166
# price: 1166

# %%
#non-stop-Bangalore-Hyderabad-40 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Bangalore')
    destination.append('Hyderabad')
    days_remaining.append(40)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1182
# new_count: 16
# depart_time: 1182
# flight_time: 1182
# arrival_time: 1182
# stop_location: 1182
# price: 1182

# %%
#non-stop-Mumbai-Hyderabad-0 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1214
# new_count: 14
# depart_time: 1214
# flight_time: 1214
# arrival_time: 1214
# stop_location: 1214
# price: 1214

# %%
#now for stops Mumbai- Hyderabad -0 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1235
# new_count: 21
# depart_time: 1235
# flight_time: 1235
# arrival_time: 1235
# stop_location: 1235
# price: 1235

# %%
#non-stop-Mumbai-Hyderabad-10 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1249
# new_count: 14
# depart_time: 1249
# flight_time: 1249
# arrival_time: 1249
# stop_location: 1249
# price: 1249

# %%
#now for stops Mumbai- Hyderabad -10 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1270
# new_count: 21
# depart_time: 1270
# flight_time: 1270
# arrival_time: 1270
# stop_location: 1270
# price: 1270

# %%
#non-stop-Mumbai-Hyderabad-20 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))   )
# Out:
# company: 1284
# new_count: 14
# depart_time: 1284
# flight_time: 1284
# arrival_time: 1284
# stop_location: 1284
# price: 1284

# %%
#now for stops Mumbai- Hyderabad -20 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(20)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1305
# new_count: 21
# depart_time: 1305
# flight_time: 1305
# arrival_time: 1305
# stop_location: 1305
# price: 1305

# %%
#non-stop-Mumbai-Hyderabad-30 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1319
# new_count: 14
# depart_time: 1319
# flight_time: 1319
# arrival_time: 1319
# stop_location: 1319
# price: 1319

# %%
#now for stops Mumbai- Hyderabad -30 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1340
# new_count: 21
# depart_time: 1340
# flight_time: 1340
# arrival_time: 1340
# stop_location: 1340
# price: 1340

# %%
#non-stop-Mumbai-Hyderabad-40 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(40)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1354
# new_count: 14
# depart_time: 1354
# flight_time: 1354
# arrival_time: 1354
# stop_location: 1354
# price: 1354

# %%
#now for stops Mumbai- Hyderabad -40 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Mumbai')
    destination.append('Hyderabad')
    days_remaining.append(40)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1375
# new_count: 21
# depart_time: 1375
# flight_time: 1375
# arrival_time: 1375
# stop_location: 1375
# price: 1375

# %%
#non-stop-Delhi-Kolkata-0 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(0)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1396
# new_count: 21
# depart_time: 1396
# flight_time: 1396
# arrival_time: 1396
# stop_location: 1396
# price: 1396

# %%
#now for stops Delhi- Kolkata -0 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(0)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1417
# new_count: 21
# depart_time: 1417
# flight_time: 1417
# arrival_time: 1417
# stop_location: 1417
# price: 1417

# %%
#non-stop-Delhi-Kolkata-10 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(10)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1438
# new_count: 21
# depart_time: 1438
# flight_time: 1438
# arrival_time: 1438
# stop_location: 1438
# price: 1438

# %%
#now for stops Delhi- Kolkata -10 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(10)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1459
# new_count: 21
# depart_time: 1459
# flight_time: 1459
# arrival_time: 1459
# stop_location: 1459
# price: 1459

# %%
#non-stop-Delhi-Kolkata-20 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(20)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1480
# new_count: 21
# depart_time: 1480
# flight_time: 1480
# arrival_time: 1480
# stop_location: 1480
# price: 1480

# %%
# Out:
# company: 1501
# new_count: 21
# depart_time: 1501
# flight_time: 1501
# arrival_time: 1501
# stop_location: 1501
# price: 1501

# %%
#non-stop-Delhi-Kolkata-30 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(30)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1522
# new_count: 21
# depart_time: 1522
# flight_time: 1522
# arrival_time: 1522
# stop_location: 1522
# price: 1522

# %%
#now for stops Delhi- Kolkata -30 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(30)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1543
# new_count: 21
# depart_time: 1543
# flight_time: 1543
# arrival_time: 1543
# stop_location: 1543
# price: 1543

# %%
#non-stop-Delhi-Kolkata-40 days
new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #arrival_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(0)
    stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(40)
    day.append('Monday')
print('stop_location:',len(stop_location))
    
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1564
# new_count: 21
# depart_time: 1564
# flight_time: 1564
# arrival_time: 1564
# stop_location: 1564
# price: 1564

# %%
#now for stops Delhi- Kolkata -40 days
#driver.get(url)
#stop_1=driver.find_element_by_xpath("/html/body/div/div/div[2]/div[2]/div/div[1]/div[2]/div[3]/div/label[2]/div/span[1]/span/span")
#stop_1.click()
time.sleep(5)

new_count=[]

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[1]/div/p[1]')
        company.append(element.text)
        new_count.append(element.text)
    except NoSuchElementException:
        #company.append(np.nan)
        continue
print('company:',len(company))
print('new_count:',len(new_count))

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[1]/div[1]/p[1]/span')
        depart_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('depart_time:',len(depart_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/p')
        flight_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('flight_time:',len(flight_time))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[3]/div[1]/p[1]/span')
        arrival_time.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('arrival_time:',len(arrival_time))
        
for i in range(len(new_count)):
    num_stops.append(1)
    #stop_location.append('None')
    source.append('Delhi')
    destination.append('Kolkata')
    days_remaining.append(40)
    day.append('Monday')

for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[2]/label/div/div/div[2]/div/p')
        stop_location.append(element.text.split(' ')[-1])
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('stop_location:',len(stop_location))
        
for i in range(1,30):
    try:
        element=driver.find_element_by_xpath('/html/body/div/div/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/div/div/div['+str(i)+']/div[1]/div[2]/div[4]/div/div/p')
        price.append(element.text)
    except NoSuchElementException:
        #depart_time.append(np.nan)
        continue
print('price:',len(price))
# Out:
# company: 1585
# new_count: 21
# depart_time: 1585
# flight_time: 1585
# arrival_time: 1585
# stop_location: 1585
# price: 1585

# %%
flight_price=pd.DataFrame()
flight_price['Company']=company
flight_price['depart_time']=depart_time
flight_price['flight_time']=flight_time
flight_price['arrival_time']=arrival_time
flight_price['num_stops']=num_stops
flight_price['stop_location']=stop_location
flight_price['source']=source
flight_price['destination']=destination
flight_price['days_remaining']=days_remaining
#flight_price['day']=day
flight_price['price']=price

# %%
flight_price.tail(20)
# Out:
#               Company depart_time flight_time arrival_time  num_stops  \
# 1565           IndiGo       05:30   05 h 55 m        11:25          1
# 1566           IndiGo       07:20   05 h 10 m        12:30          1
# 1567           IndiGo       07:30   05 h 45 m        13:15          1
# 1568           IndiGo       10:30   06 h 55 m        17:25          1
# 1569           IndiGo       13:25   04 h 05 m        17:30          1
# 1570           IndiGo       12:25   05 h 05 m        17:30          1
# 1571           IndiGo       09:20   08 h 10 m        17:30          1
# 1572           IndiGo       14:00   05 h 05 m        19:05          1
# 1573           IndiGo       08:25   10 h 40 m        19:05          1
# 1574           IndiGo       13:00   07 h 10 m        20:10          1
# 1575           IndiGo       15:55        05 h        20:55          1
# 1576           IndiGo       16:20   05 h 15 m        21:35          1
# ...

# %%
#company=company[0:1112]
#depart_time=depart_time[0:1112]
#flight_time=flight_time[0:1112]
#arrival_time=arrival_time[0:1112]
#stop_location=stop_location[0:1112]
#num_stops=num_stops[0:1112]
#source=source[0:1112]
#destination=destination[0:1112]
#days_remaining=days_remaining[0:1112]
#day=day[0:1112]
#price=price[0:1112]

# %%
flight_price.to_csv('flight_price1.csv')

# %%
flight_price['Company'].value_counts()
# Out:
# IndiGo              955
# Vistara             252
# AirAsia             152
# Air India            76
# Go First             73
# SpiceJet             65
# Alliance Air          6
# IndiGo, Go First      3
# Star Air              2
# AirAsia, IndiGo       1
# Name: Company, dtype: int64
