# %% [markdown]
# # Basic statistics

# %% [raw]
# Definition:-The science of collecting, organizing, presenting, analyzing and interpreting data to assist in making more effective decisions.
# Statictics is a branch of mathematics used to summarize, analyze, and interpret a group of numbers or observations .

# %% [markdown]
# # Types of statistics

# %% [raw]
# 1. Descriptive statistics   2. Inferential statistics.
#
# Descriptive  statistics deals with the entire population( all members present in the dataset.)
# Inferential statistics deals with a sample(subset of the entire dataset)
#
# Ex- we have the data to 10000 students. In desciptive statistics we will consider data of 10000 students for the analysis.
#
# but
#
# in inferential statistics we will take a sample of 500 students from the dataset of 10000 students and consider only the sample of 500 students for analysis.

# %% [markdown]
# # Descriptive statistics

# %% [raw]
# Descriptive statistics can be devided into two parts:-
#     1. Measure of central tendency(Mean, Median, Mode)
#     2. Measures of dispersion(Range, Percentiles/Quartiles,Inter quartile range(IQR), Variance, Standard deviation,                    Skewness, Kurtosis)
#
# Median:- Arranges the data in ascending order and finds the central data.
# Mode:- Finds out the data with maximum frequency.
#
# Mean gets too much effected by outliers.
# Median is not much effected by outliers

# %% [markdown]
# # Independent and dependent variables

# %% [raw]
# variables are defined as the properties or kinds of characteristics of certain events or objects.
#
# 1.Independent variables:- They are variables that are manipulated or are changed and whose effects are meausured or compared. The other name of independent variables are predictors
#
# 2.Dependent variables:- It refers to that type of variable that measures the effect of independent variable(s). The dependent variables are completely dependent on the independent variables. Can be called as output or predicted variable.
#
#   *Dependent variables are plotted on X-axis and independent variables are plotted on Y-axis.
#
# Independent variables are also called as:-
# 1. Controlled variable
# 2. explanatory variable
# 3. input variable
#
# Dependent variables are also called as:-
# 1. Response variable
# 2. Measured variable
# 3. Observed variable
# 4. Outcome variable
# 5. Output variable
#
# Ex(independent Event):- Three coins are being tossed. Two are heads. What is the probality that the third coin will also be head? The probability of the third coin being head still remains 0.5 inspite of the previous two coins coming head. Hence the three tosses are independent of each other.

# %% [markdown]
# # Types of variables/Data

# %% [markdown]
# ![Screenshot%20%28338%29.png](attachment:Screenshot%20%28338%29.png)

# %% [raw]
# Data is of two types:-
# 1. Categorical data  2. Numerical data
#
#   a. Categorical data/ Nominal data- Marital status, Political party, Eye Color (Only specific options available), 0 or          1,true or flase
#   b. Numerical data:-
#       1. Dicrete:- Number of children, Defects per hour. (Counted items)(Decimal value not possible)
#       2. Continuous:- Weight of person, Voltage.(Decimal value possible)

# %% [raw]
# Categorical data:-
# 1. This type of data is non numeric
# 2. We use it to quantify things in categories like gender, ethnicity, natoinality, political party etc.
# 3. Gender- M of F
# 4. Country- US, UK, UAE
# 5. We can asign number to the categories, but the numbers wouldnot in that case, represent their value per say. They will only separate one type from the other- (type1, type2, type3)
#    For example while calculating India's population, Bangalore could be number 1, Mumbai number 2, and so on.

# %% [raw]
# Ordinal data:-
# 1.Ordinal data is a amalgamation of numerical and categorical data. Simply put, these data consists of categories put in order.
# 2.The intervals between categories are not known.
# 3.Movie or music ratings that use stars to denote quality.
# 4.Numbers simply represent the bad or good qualities.
# 5.A movie with 5 star rating is obviously very good as opposed to a movie with only 1 star, which very likely is terrible.
# 6.Note that the numbers in this example do denote value.
# 7.Mathematically speaking, 5 is grater than 1. This difference in value is used to differentiate good films from bad. Good films receive a higher rating of 4 or 5, while bad films get a lower rating of 1 or 2

# %% [raw]
# Interval data:-
# Data at this level can be ordered as it is in a range of values and meneaningful differences between data points can be calculated.
# eg- temperature in range of 0-10 is denoted as 1
#     temperature in range of 10-20 is denoted as 2.
#     temperature in range of 20-30 is denoted as 3 and so on.

# %% [markdown]
# ![IMG20220224200628.jpg](attachment:IMG20220224200628.jpg)

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [raw]
# Standard deviation is high means the data is spreaded over a long range.

# %%
#Both pandas and numpy hold statistics

# %%
import numpy as np

# %%
a=np.array([14,13,15,50,100,56]) #np.array is a function that converts a list into an array. 
#() denotes the function.[] denotes the list.

# %%
a
# Out:
# array([ 14,  13,  15,  50, 100,  56])

# %%
np.mean(a)
# Out:
# 41.333333333333336

# %%
np.median(a) #arranges the numbers in the array in ascending order and finds the middle data.
# Out:
# 32.5

# %%
a=np.array([[3,7,5],[8,4,3],[2,4,9]])

# %%
a
# Out:
# array([[3, 7, 5],
#        [8, 4, 3],
#        [2, 4, 9]])

# %%
np.median(a)
# Out:
# 4.0

# %%
#finding median in each column
np.median(a,axis=0)#columnwise
# Out:
# array([3., 4., 5.])

# %%
#finding median in each row
np.median(a,axis=1)#rowwise
# Out:
# array([5., 4., 4.])

# %%
np.mean(a) #mean of all the data present in the matrix
# Out:
# 5.0

# %%
#finding mean in each column
np.mean(a,axis=0)#columnwise
# Out:
# array([4.33333333, 5.        , 5.66666667])

# %%
#finding mean in each row
np.mean(a,axis=1)#rowwise
# Out:
# array([5., 5., 5.])

# %%
#mode cannot be found out using numpy

# %% [markdown]
# # Range

# %% [raw]
# Range=Difference between maximum and minimum value

# %%
a=np.array([14,13,15,50,100,56])

# %%
a
# Out:
# array([ 14,  13,  15,  50, 100,  56])

# %%
#finding the variance
np.var(a)
# Out:
# 995.888888888889

# %%
#finding the standard deviation
np.std(a)
# Out:
# 31.55770728188106

# %%
round(np.std(a),2) #rounding off the obtained results to two points after decimal
# Out:
# 31.56

# %%
a
# Out:
# array([[3, 7, 5],
#        [8, 4, 3],
#        [2, 4, 9]])

# %%
np.var(a,axis=0)#finding variance in a matrix columnwise
# Out:
# array([6.88888889, 2.        , 6.22222222])

# %%
np.var(a,axis=1)#finding variance in a matrix rowwise
# Out:
# array([2.66666667, 4.66666667, 8.66666667])

# %%
np.std(a,axis=0)#finding standard deviation in a matrix columnwise
# Out:
# array([2.62466929, 1.41421356, 2.49443826])

# %%
np.std(a,axis=1)#finding standard deviation in a matrix rowwise
# Out:
# array([1.63299316, 2.1602469 , 2.94392029])

# %%
a
# Out:
# array([ 14,  13,  15,  50, 100,  56])

# %%
x=np.max(a) #Find out the maximum data from the array.
x
# Out:
# 100

# %%
y=np.min(a) #Find out the minimum data from the array.
y
# Out:
# 13

# %%
mrange=x-y
mrange
# Out:
# 87

# %%
import pandas as pd

# %%
data_height=pd.read_csv("president_heights.csv")

# %%
data_height
# Out:
#     order                    name  height
# 0       1       George Washington     189
# 1       2              John Adams     170
# 2       3        Thomas Jefferson     189
# 3       4           James Madison     163
# 4       5            James Monroe     183
# 5       6       John Quincy Adams     171
# 6       7          Andrew Jackson     185
# 7       8        Martin Van Buren     168
# 8       9  William Henry Harrison     173
# 9      10              John Tyler     183
# 10     11           James K. Polk     173
# 11     12          Zachary Taylor     173
# 12     13        Millard Fillmore     175
# 13     14         Franklin Pierce     178
# 14     15          James Buchanan     183
# 15     16         Abraham Lincoln     193
# 16     17          Andrew Johnson     178
# 17     18        Ulysses S. Grant     173
# 18     19     Rutherford B. Hayes     174
# 19     20       James A. Garfield     183
# 20     21       Chester A. Arthur     183
# ...

# %%
heights=data_height['height'] #taking the height column out of the table

# %%
print("Mean height:", heights.mean())
print("Standard deviation:", heights.std())
print("Minimum height:", heights.min())
print("Maximumheight:", heights.max())
print("Median height:", heights.median())
# Out:
# Mean height: 179.73809523809524
# Standard deviation: 7.015868855358296
# Minimum height: 163
# Maximumheight: 193
# Median height: 182.0

# %%
print("Median:", np.median(heights))
# Out:
# Median: 182.0
