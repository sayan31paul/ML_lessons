# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('brain_size.csv',sep=';',na_values='.')
#','separator is default but here there is ';' separator in raw file. We have to use sep=';' to make computer understand it.
#na_values='.' is to make computer understand that missing values are represented by '.' in raw file.

# %%
df
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 1    2    Male   140  150  124     NaN    72.5    1001121
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# ...

# %%
df.head()
# Out:
#    id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0   1  Female   133  132  124   118.0    64.5     816932
# 1   2    Male   140  150  124     NaN    72.5    1001121
# 2   3    Male   139  123  150   143.0    73.3    1038437
# 3   4    Male   133  129  128   172.0    68.8     965353
# 4   5  Female   137  132  134   147.0    65.0     951545

# %%
df.head(10)
# Out:
#    id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0   1  Female   133  132  124   118.0    64.5     816932
# 1   2    Male   140  150  124     NaN    72.5    1001121
# 2   3    Male   139  123  150   143.0    73.3    1038437
# 3   4    Male   133  129  128   172.0    68.8     965353
# 4   5  Female   137  132  134   147.0    65.0     951545
# 5   6  Female    99   90  110   146.0    69.0     928799
# 6   7  Female   138  136  131   138.0    64.5     991305
# 7   8  Female    92   90   98   175.0    66.0     854258
# 8   9    Male    89   93   84   134.0    66.3     904858
# 9  10    Male   133  114  147   172.0    68.8     955466

# %%
df.tail(10)
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 30  31  Female   133  126  132   127.0    62.5     857782
# 31  32    Male   144  145  137   191.0    67.0     949589
# 32  33    Male   103   96  110   192.0    75.5     997925
# 33  34    Male    90   96   86   181.0    69.0     879987
# 34  35  Female    83   90   81   143.0    66.5     834344
# 35  36  Female   133  129  128   153.0    66.5     948066
# 36  37    Male   140  150  124   144.0    70.5     949395
# 37  38  Female    88   86   94   139.0    64.5     893983
# 38  39    Male    81   90   74   148.0    74.0     930016
# 39  40    Male    89   91   89   179.0    75.5     935863

# %%
df.sample(4) #Shows any four samples.
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 29  30  Female   130  126  124   159.0    66.5     866662
# 27  28    Male   103   96  110   187.0    77.0    1062462
# 22  23  Female   135  129  134   122.0    62.0     790619
# 39  40    Male    89   91   89   179.0    75.5     935863

# %%
df.shape #tells the number of rows and columns. #() is not used because .shape is and attribute(data member inside class)
# Out:
# (40, 8)

# %%
df.dtypes #() are not used because dtypes is attribute(data member inside class). () is used after methods only.
# Out:
# id             int64
# Gender        object
# FSIQ           int64
# VIQ            int64
# PIQ            int64
# Weight       float64
# Height       float64
# MRI_Count      int64
# dtype: object

# %%
df.info() #This is a method. so () is used after it.# This is mainly used to know if there is any null value present in column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         40 non-null     int64
#  1   Gender     40 non-null     object
#  2   FSIQ       40 non-null     int64
#  3   VIQ        40 non-null     int64
#  4   PIQ        40 non-null     int64
#  5   Weight     38 non-null     float64
#  6   Height     39 non-null     float64
#  7   MRI_Count  40 non-null     int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.6+ KB

# %%
df.notnull() #null values are represented by false
# Out:
#       id  Gender  FSIQ   VIQ   PIQ  Weight  Height  MRI_Count
# 0   True    True  True  True  True    True    True       True
# 1   True    True  True  True  True   False    True       True
# 2   True    True  True  True  True    True    True       True
# 3   True    True  True  True  True    True    True       True
# 4   True    True  True  True  True    True    True       True
# 5   True    True  True  True  True    True    True       True
# 6   True    True  True  True  True    True    True       True
# 7   True    True  True  True  True    True    True       True
# 8   True    True  True  True  True    True    True       True
# 9   True    True  True  True  True    True    True       True
# 10  True    True  True  True  True    True    True       True
# 11  True    True  True  True  True    True    True       True
# 12  True    True  True  True  True    True    True       True
# 13  True    True  True  True  True    True    True       True
# ...

# %%
df.isnull() #null values are represented by true.
# Out:
#        id  Gender   FSIQ    VIQ    PIQ  Weight  Height  MRI_Count
# 0   False   False  False  False  False   False   False      False
# 1   False   False  False  False  False    True   False      False
# 2   False   False  False  False  False   False   False      False
# 3   False   False  False  False  False   False   False      False
# 4   False   False  False  False  False   False   False      False
# 5   False   False  False  False  False   False   False      False
# 6   False   False  False  False  False   False   False      False
# 7   False   False  False  False  False   False   False      False
# 8   False   False  False  False  False   False   False      False
# 9   False   False  False  False  False   False   False      False
# 10  False   False  False  False  False   False   False      False
# 11  False   False  False  False  False   False   False      False
# 12  False   False  False  False  False   False   False      False
# ...

# %%
df.isnull().sum() #Gibes the total NaN values present in each column
# Out:
# id           0
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       2
# Height       1
# MRI_Count    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count'], dtype='object')

# %%
df.describe()
# Out:
#               id        FSIQ         VIQ        PIQ      Weight     Height  \
# count  40.000000   40.000000   40.000000   40.00000   38.000000  39.000000
# mean   20.500000  113.450000  112.350000  111.02500  151.052632  68.525641
# std    11.690452   24.082071   23.616107   22.47105   23.478509   3.994649
# min     1.000000   77.000000   71.000000   72.00000  106.000000  62.000000
# 25%    10.750000   89.750000   90.000000   88.25000  135.250000  66.000000
# 50%    20.500000  116.500000  113.000000  115.00000  146.500000  68.000000
# 75%    30.250000  135.500000  129.750000  128.00000  172.000000  70.500000
# max    40.000000  144.000000  150.000000  150.00000  192.000000  77.000000
#
#           MRI_Count
# count  4.000000e+01
# mean   9.087550e+05
# std    7.228205e+04
# min    7.906190e+05
# 25%    8.559185e+05
# 50%    9.053990e+05
# 75%    9.500780e+05
# max    1.079549e+06

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(df['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.distplot(df['Height'],bins=10)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Height'],kde=False,bins=20)
# Out:
# <AxesSubplot:xlabel='Height'>

# %%
df['Weight'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Height'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count'], dtype='object')

# %%
sns.boxplot(y='FSIQ',data=df)
# Out:
# <AxesSubplot:ylabel='FSIQ'>

# %%
sns.boxplot(y=df['FSIQ'])
# Out:
# <AxesSubplot:ylabel='FSIQ'>

# %%
sns.boxplot(df['FSIQ'])
# Out:
# <AxesSubplot:xlabel='FSIQ'>

# %%
sns.boxplot(y=df['VIQ'])
# Out:
# <AxesSubplot:ylabel='VIQ'>

# %%
sns.boxplot(df['VIQ'])
# Out:
# <AxesSubplot:xlabel='VIQ'>

# %%
sns.boxplot(y='VIQ',data=df)
# Out:
# <AxesSubplot:ylabel='VIQ'>

# %%
df['PIQ'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# id           0
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       2
# Height       1
# MRI_Count    0
# dtype: int64

# %% [raw]
# If number of rows with NaN values is very less as compared to the number of rows in the table, then we can drop the rows with NaN values.
# If the number of rows with NaN values is comparable to the number of rows in the table then we have to assume some data in place of the NaN values.ex- We can take the mean of all data present in the column.

# %%
#Show all rows containing NaN values.
df[df.isna().any(axis=1)]
# Out:
#     id Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 1    2   Male   140  150  124     NaN    72.5    1001121
# 20  21   Male    83   83   86     NaN     NaN     892420

# %%
#df.fillna()?

import numpy as np
df['PIQ'].replace(np.NaN,df['PIQ'].mean,inplace=True)#replacing all NaN values with mean.

# %%
df
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 1    2    Male   140  150  124     NaN    72.5    1001121
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# 15  16  Female    83   71   96   135.0    68.0     865363
# ...

# %%
sns.heatmap(df.isnull()) #now no NaN values are present
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()     #now no NaN values are present
# Out:
# id           0
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       0
# Height       0
# MRI_Count    0
# dtype: int64

# %%
dfcor=df.corr()
dfcor
# Out:
#                  id      FSIQ       VIQ       PIQ    Weight    Height  \
# id         1.000000 -0.309480 -0.191436 -0.366591  0.174359  0.173798
# FSIQ      -0.309480  1.000000  0.945114  0.934427 -0.051483 -0.118448
# VIQ       -0.191436  0.945114  1.000000  0.776020 -0.076088 -0.118976
# PIQ       -0.366591  0.934427  0.776020  1.000000  0.002512 -0.093156
# Weight     0.174359 -0.051483 -0.076088  0.002512  1.000000  0.699614
# Height     0.173798 -0.118448 -0.118976 -0.093156  0.699614  1.000000
# MRI_Count -0.091564  0.333714  0.300279  0.377782  0.513378  0.588377
#
#            MRI_Count
# id         -0.091564
# FSIQ        0.333714
# VIQ         0.300279
# PIQ         0.377782
# Weight      0.513378
# Height      0.588377
# MRI_Count   1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Machine Learning

# %%
independent variables/predictor/explanatory variable/Features

Dependent variable/Target/Label/Predicted/Outcome/Label

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [raw]
# Training and testing splits:- The machine is first trained(both questions and answers are give to the machine) with the training data. Then the test data(only questions) is given to the machine and it is checked whether the machine outputs matches with the actual data.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [markdown]
# ![1_rbaxTrB_CZCqbty_zv2bEg%20%281%29.png](attachment:1_rbaxTrB_CZCqbty_zv2bEg%20%281%29.png)

# %% [raw]
# Machine learning can be divided into two categories:-
# 1. Supervised Learning
# 2. Unsupervised Learning
#
# Supervised machine learning:- The machine is 'Trained' on a predefined set of data or correct answer or 'training examples', which then facilitates its ability to reach an accurate conclusion when given new data.
# Both train_x and train_y is supplied for training purpose.
#
# Unsupervised learning:- The program is given with a bunch of data and must find patterns and relationships within data.There no answer or training examples is provided to the program.It depends on the program to find structure and patterns in the data.
# Only train_x is supplied for training purpose. No train_y is supplied for training.

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %% [raw]
# Supervised machine learning can be devided into two types:-
# 1.Classification        2.Regression
#
# Regression machine learning systems:- In regression the output/label/target types are continuous(decimal) valued. This systems helps us with the question of 'How much?' or 'How many?' .
#
# Classification machine learning systems:- It is used when we donot need numerical output. It categorizes the data with 'yes' or 'no' prediction. ex- Based on certain input tomorrow will be sunny/rainy/windy/chilly day.

# %% [raw]
# Regression machine learning system can be divided into many types. Two of them are:-
#     1. Linear regression
#     2. Logistic regerssion
