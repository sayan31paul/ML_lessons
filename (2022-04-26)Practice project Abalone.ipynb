# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('abalone.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.isnull().sum()

#no null values present
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# # EDA

# %%
sns.pairplot(df)

# %%
plt.scatter(df['Length'],df['Diameter'])

#diameter increasing with length

# %%
plt.scatter(df['Length'],df['Rings'])

#Number of rings is increasing at a samller rate with increase in length

# %%
plt.scatter(df['Diameter'],df['Rings'])

#Number of rings is increasing at a samller rate with increase in diameter

# %%
plt.scatter(df['Height'],df['Rings'])

#Number of rings is increasing at a higher rate with increase in Height

# %%
plt.scatter(df['Whole weight'],df['Rings'])

#number of rings is initially increasing at a higher rate with whole weight, then the rate of increasing decreases.

# %%
plt.scatter(df['Shucked weight'],df['Rings'])

#number of rings is initially increasing at a higher rate with Shucked weight, then the rate of increasing decreases.

# %%
plt.scatter(df['Viscera weight'],df['Rings'])

#number of rings is initially increasing at a higher rate with Viscera weight, then the rate of increasing decreases.

# %%
plt.scatter(df['Shell weight'],df['Rings'])

#number of rings is initially increasing at a higher rate with shell weight, then the rate of increasing decreases.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# Number of rings has low correlation with most of the features but it has lowest correlation with Shucked weight.
# But we are not removing the 'Shucked Wright' column because the number of columns is already low.

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [raw]
# The difference between mean and standard deviation in most of the columns is low.Then low skewness may be present in the columns.
#
# Outliers may be present in Height,Whole Weight, Shucked Weight, Shell weight, Rings column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.plot(kind='box',subplots=True,layout=(3,4),figsize=(10,10),color='green')
plt.show()

# %% [raw]
# From the boxplots, it is evident that good number of outliers are present in the dataset.

# %%
df.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %% [raw]
# Skewness threshold is taken as 0.65:-
#
# Columns haning high skewness are:-
#     1. Height
#     2. Shucked Weight
#     3. Rings

# %%
sns.distplot(df['Length'])
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
sns.distplot(df['Diameter'])
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
sns.distplot(df['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Whole weight'])
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
sns.distplot(df['Viscera weight'])
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
sns.distplot(df['Shell weight'])
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
sns.distplot(df['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %% [raw]
# Skewness is present in modt of the columns, so it is better to remove skewness from all columns

# %% [markdown]
# # Appliying Label encoder

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder =LabelEncoder()
df['Sex']= label_encoder.fit_transform(df['Sex'])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (4177, 9)

# %%
pd.DataFrame(z)
# Out:
#              0         1         2         3         4         5         6  \
# 0     1.151980  0.574558  0.432149  1.064424  0.641898  0.607685  0.726212
# 1     1.151980  1.448986  1.439929  1.183978  1.230277  1.170910  1.205221
# 2     1.280690  0.050033  0.122130  0.107991  0.309469  0.463500  0.356690
# 3     1.151980  0.699476  0.432149  0.347099  0.637819  0.648238  0.607600
# 4     0.064355  1.615544  1.540707  1.423087  1.272086  1.215968  1.287337
# ...        ...       ...       ...       ...       ...       ...       ...
# 4172  1.280690  0.341509  0.424464  0.609334  0.118813  0.047908  0.532900
# 4173  1.151980  0.549706  0.323686  0.107991  0.279929  0.358808  0.309362
# 4174  1.151980  0.632985  0.676409  1.565767  0.708212  0.748559  0.975413
# 4175  1.280690  0.841182  0.777187  0.250672  0.541998  0.773341  0.733627
# 4176  1.151980  1.549052  1.482634  1.326659  2.283681  2.640993  1.787449
#
#              7         8
# 0     0.638217  1.571544
# ...

# %%
df_new=df[(z<4.0).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (4177, 9)
# (4148, 9)

# %%
print('Loss_percent=',(4177-3990)/4177*100)
# Out:
# Loss_percent= 4.476897294709121

# %% [raw]
# Loss is less than 8% so it is not a matter of concern

# %%
sns.countplot(df_new['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %%
df=df_new

# %%
df.shape
# Out:
# (4148, 9)

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.12787907, -0.68371003, -0.54797317, ..., -0.53903096,
#         -0.6898897 , -0.58814816],
#        [ 1.12787907, -1.39400915, -1.38495065, ..., -1.30731617,
#         -1.32856554, -1.32737968],
#        [-1.31161811, -0.06568354,  0.01418094, ..., -0.36396086,
#         -0.2508659 , -0.09656102],
#        ...,
#        [ 1.12787907,  0.60516904,  0.65834538, ...,  0.84980447,
#          1.03053727,  0.61133713],
#        [-1.31161811,  0.86857751,  0.78491244, ...,  0.87070144,
#          0.82755829,  0.53028561],
#        [ 1.12787907,  1.86587818,  1.75873309, ...,  2.14280436,
#          1.63604744,  1.70958778]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.12787907, -0.68371003, -0.54797317, ..., -0.53903096,
#         -0.6898897 , -0.58814816],
#        [ 1.12787907, -1.39400915, -1.38495065, ..., -1.30731617,
#         -1.32856554, -1.32737968],
#        [-1.31161811, -0.06568354,  0.01418094, ..., -0.36396086,
#         -0.2508659 , -0.09656102],
#        ...,
#        [ 1.12787907,  0.60516904,  0.65834538, ...,  0.84980447,
#          1.03053727,  0.61133713],
#        [-1.31161811,  0.86857751,  0.78491244, ...,  0.87070144,
#          0.82755829,  0.53028561],
#        [ 1.12787907,  1.86587818,  1.75873309, ...,  2.14280436,
#          1.63604744,  1.70958778]])

# %% [markdown]
# # Testing different regession models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Tring to find out the best polynomial for Linear Regression

# %%
poly = PolynomialFeatures(1)
X_=poly.fit_transform(x)
lr =LinearRegression()
lsscore=cross_val_score(lr,X_,y,cv=5)
print(lsscore.mean())
# Out:
# 0.42628309659438174

# %%
poly = PolynomialFeatures(2)
X_=poly.fit_transform(x)
lr =LinearRegression()
lsscore=cross_val_score(lr,X_,y,cv=5)
print(lsscore.mean())
# Out:
# 0.4742878626189923

# %%
poly = PolynomialFeatures(3)
X_=poly.fit_transform(x)
lr =LinearRegression()
lsscore=cross_val_score(lr,X_,y,cv=5)
print(lsscore.mean())
# Out:
# 0.39039116706978944

# %%
poly = PolynomialFeatures(4)
X_=poly.fit_transform(x)
lr =LinearRegression()
lsscore=cross_val_score(lr,X_,y,cv=5)
print(lsscore.mean())
# Out:
# -7.456290991209497

# %% [raw]
# Polynomial Linear Regression model with degree=3 is giving the highest r2_score

# %% [markdown]
# Lets try out polynomial linear regresison

# %%
poly = PolynomialFeatures(2)
X_=poly.fit_transform(x)
lr=LinearRegression()
scores = cross_val_score(lr, X_, y, cv=5)
print('Cross Validation score:',scores.mean())
# Out:
# Cross Validation score: 0.4742878626189923

# %% [markdown]
# Trying Ridge regression

# %%
r=Ridge()
parameters={'alpha':[0.1,0.01,0.001],'random_state':list(range(0,66))}
gd_sr=GridSearchCV(estimator=r, param_grid= parameters, scoring='r2')
gd_sr.fit(X_,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'alpha': 0.1, 'random_state': 0}
# 0.47540790514407893

# %% [markdown]
# Trying Lasso Regression

# %%
l=Lasso()
parameters={'alpha':[0.1,0.01,0.001],'random_state':list(range(0,80))}
gd_sr=GridSearchCV(estimator=l, param_grid= parameters, scoring='r2')
gd_sr.fit(X_,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'alpha': 0.001, 'random_state': 0}
# 0.48329692136929303

# %% [markdown]
# Applying GridSearchCV on KNN regressor

# %%
knr=KNeighborsRegressor()
parameters={'n_neighbors':[3,5,7,9,11,15,20,25,30]}
gd_sr=GridSearchCV(estimator=knr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'n_neighbors': 15}
# 0.4429795967602093

# %% [markdown]
# Trying RandomForestRegressor

# %%
rfr=RandomForestRegressor()
parameters={'n_estimators':[30,50,70,100],'max_depth':[10,13,15,20]}
gd_sr=GridSearchCV(estimator=rfr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'max_depth': 10, 'n_estimators': 100}
# 0.46526432151099906

# %% [raw]
# Lasso Regression is giving the highest cross validation score of all the regressors.

# %% [markdown]
# # Building the possible model

# %%
rfr=RandomForestRegressor(n_estimators=50,max_depth=10)
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=35,test_size=0.20)
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score:',r2_score(y_test,y_pred))
# Out:
# Root Mean Squared error: 2.1999327851361654
# r2_score: 0.5290784553111385

# %%
l=Lasso(alpha=0.001)
poly = PolynomialFeatures(2)
X_=poly.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(X_,y,random_state=4,test_size=0.20)
l.fit(x_train,y_train)
y_pred=l.predict(x_test)
print('Root Mean Squared error:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score:',r2_score(y_test,y_pred))
# Out:
# Root Mean Squared error: 2.1105898052032024
# r2_score: 0.5289563330394348

# %% [markdown]
# Trying to improve the accuracy of lasso regreesion based model

# %%
l=Lasso(alpha=0.001)
poly = PolynomialFeatures(2)
X_=poly.fit_transform(x)

random_state=[]
r2Score=[]

for i in list(range(0,80)):
    x_train,x_test,y_train,y_test=train_test_split(X_,y,random_state=i,test_size=0.20)
    l.fit(x_train,y_train)
    y_pred=l.predict(x_test)
    random_state.append(i)
    r2Score.append(r2_score(y_test,y_pred))
    
acc=pd.DataFrame()
acc['random_state']=random_state
acc['r2score']=r2Score
acc[(acc['r2score']==acc['r2score'].max())]
# Out:
#     random_state   r2score
# 32            32  0.611382

# %%
acc
# Out:
#     random_state   r2score
# 0              0  0.563174
# 1              1  0.574103
# 2              2  0.564139
# 3              3  0.544507
# 4              4  0.528956
# ..           ...       ...
# 75            75  0.570964
# 76            76  0.553887
# 77            77  0.573374
# 78            78  0.597763
# 79            79  0.586176
#
# [80 rows x 2 columns]

# %%
acc['r2score'].max()
# Out:
# 0.6113815323823388

# %%
acc[(acc['r2score']==0.6113815323823388)]
# Out:
#     random_state   r2score
# 32            32  0.611382

# %% [markdown]
# # Making the final model

# %%
l=Lasso(alpha=0.001)
poly = PolynomialFeatures(2)
X_=poly.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(X_,y,random_state=32,test_size=0.20)
l.fit(x_train,y_train)
y_pred=l.predict(x_test)
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('r2_score:',r2_score(y_test,y_pred))
# Out:
# Root mean squared error: 1.9675199276942157
# r2_score: 0.6113815323823388

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='abalone.pkl'
pickle.dump(l,open(filename,'wb'))
