# %% [markdown]
# # Weighted hybrid technique for recommender system.

# %% [raw]
# #Here we are considering only content based filtering and not collaborative filtering

# %%
import numpy as np
import pandas as pd

# %%
credits=pd.read_csv('tmdb_5000_credits.csv')
credits
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
movies_df=pd.read_csv('tmdb_5000_movies.csv')
movies_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
credits.shape
# Out:
# (4803, 4)

# %%
movies_df.shape
# Out:
# (4803, 20)

# %%
#combining two dataframe
credits=credits.rename(columns={"movie_id":"id"})
credits
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# ...

# %%
movies_df_merge=movies_df.merge(credits,on='id')
movies_df_merge
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
movies_df_merge.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_x', 'vote_average',
#        'vote_count', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
movies_cleaned_df=movies_df_merge.drop(columns=['homepage','title_x','title_y','status','production_countries'])

# %%
movies_cleaned_df.shape
# Out:
# (4803, 18)

# %%
movies_cleaned_df.info() #no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   id                    4803 non-null   int64
#  3   keywords              4803 non-null   object
#  4   original_language     4803 non-null   object
#  5   original_title        4803 non-null   object
#  6   overview              4800 non-null   object
#  7   popularity            4803 non-null   float64
#  8   production_companies  4803 non-null   object
#  9   release_date          4802 non-null   object
#  10  revenue               4803 non-null   int64
#  11  runtime               4801 non-null   float64
#  12  spoken_languages      4803 non-null   object
#  13  tagline               3959 non-null   object
#  14  vote_average          4803 non-null   float64
# ...

# %%
movies_cleaned_df['vote_average'].mean()
# Out:
# 6.092171559442011

# %% [markdown]
# # Using weighted average for each movie's average rating

# %% [markdown]
# ![Screenshot%20%28306%29.png](attachment:Screenshot%20%28306%29.png)

# %%
#calculate all the components based on the above formula
v=movies_cleaned_df['vote_count']
R=movies_cleaned_df['vote_average']
C=movies_cleaned_df['vote_average'].mean()
m=movies_cleaned_df['vote_count'].quantile(0.70)

# %%
#create a new column called weighted average
movies_cleaned_df['weighted_average']=((R*v)+(C*m))/(v+m)

# %%
movies_cleaned_df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
movie_sorted_rank=movies_cleaned_df.sort_values('weighted_average',ascending=False)
movie_sorted_rank[['original_title','vote_count','vote_average','weighted_average','popularity']]
# Out:
#                 original_title  vote_count  vote_average  weighted_average  \
# 1881  The Shawshank Redemption        8205           8.5          8.340775
# 3337             The Godfather        5893           8.4          8.192887
# 662                 Fight Club        9413           8.3          8.171648
# 3232              Pulp Fiction        8428           8.3          8.157615
# 65             The Dark Knight       12002           8.2          8.102674
# ...                        ...         ...           ...               ...
# 303                   Catwoman         808           4.2          4.991470
# 3746         The Boy Next Door        1022           4.1          4.822053
# 210             Batman & Robin        1418           4.2          4.749951
# 242             Fantastic Four        2278           4.4          4.743880
# 1652      Dragonball Evolution         462           2.9          4.678190
#
#       popularity
# 1881  136.747729
# 3337  143.659698
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.barplot(x=movie_sorted_rank['weighted_average'].head(10),y=movie_sorted_rank['original_title'].head(10))
plt.xlim(4,10)
plt.title('Best movie by average votes',weight='bold')
plt.xlabel('Weighted average',weight='bold')
plt.ylabel('Movie Title',weight='bold')
# Out:
# Text(0, 0.5, 'Movie Title')

# %%
movie_sorted_popu=movies_cleaned_df.sort_values('popularity',ascending=False)
movie_sorted_popu
# Out:
#          budget                                             genres      id  \
# 546    74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...  211672
# 95    165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...  157336
# 788    58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  293660
# 94    170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...  118340
# 127   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   76341
# ...         ...                                                ...     ...
# 4625          0                     [{"id": 27, "name": "Horror"}]  426067
# 4118          0                                                 []  325140
# 4727          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...   65448
# 3361          0  [{"id": 27, "name": "Horror"}, {"id": 28, "nam...   77156
# 4553          0                                                 []  380097
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=movie_sorted_popu['popularity'].head(10),y=movie_sorted_popu['original_title'].head(10))

plt.title('Best movie by popularity',weight='bold')
plt.xlabel('Popularity',weight='bold')
plt.ylabel('Movie Title',weight='bold')
# Out:
# Text(0, 0.5, 'Movie Title')

# %% [markdown]
# # Recommend based on scaled weighted average and plopularity score(Priority is given 50% to both)

# %% [raw]
# The popularity and weighted average has different magnitudes. So it is necessary to bring then on the same scale.
# We will be briniging them on a scale of 0 to 10 so that equality can be established.

# %%
from sklearn.preprocessing import MinMaxScaler #MinManscaler will be used for scaling.
scaling=MinMaxScaler()
movie_scaled_df=scaling.fit_transform(movies_cleaned_df[['weighted_average','popularity']]) #used for bringing weighted_average and popularity on same sclae.
movie_scaled_df
# Out:
# array([[0.6743388 , 0.17181451],
#        [0.5814027 , 0.15884603],
#        [0.43627257, 0.12263486],
#        ...,
#        [0.38859469, 0.00164973],
#        [0.38478644, 0.00097879],
#        [0.38758191, 0.00220412]])

# %%
movie_normalized_df=pd.DataFrame(movie_scaled_df,columns=['weighted_average','popularity'])
movie_normalized_df
# Out:
#       weighted_average  popularity
# 0             0.674339    0.171815
# 1             0.581403    0.158846
# 2             0.436273    0.122635
# 3             0.773054    0.128272
# 4             0.387739    0.050169
# ...                ...         ...
# 4798          0.426353    0.016298
# 4799          0.385613    0.000734
# 4800          0.388595    0.001650
# 4801          0.384786    0.000979
# 4802          0.387582    0.002204
#
# [4803 rows x 2 columns]

# %%
#adding new columns to movies_cleaned_df
movies_cleaned_df[['normalized_weight_average','normalized_popularity']]=movie_normalized_df
movies_cleaned_df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
#again adding a new column to movies_cleaned_df
movies_cleaned_df['score']=movies_cleaned_df['normalized_weight_average']*0.5+movies_cleaned_df['normalized_popularity']*0.5

# %%
#creating a new dataframe 'movies_scored_df' in which rows are sorted on basis of score.
movies_scored_df=movies_cleaned_df.sort_values(['score'],ascending=False)

#taking out four coulmns from movies_scored_df
movies_scored_df[['original_title','normalized_weight_average','normalized_popularity','score']]
# Out:
#                original_title  normalized_weight_average  \
# 95               Interstellar                   0.906439
# 546                   Minions                   0.460630
# 94    Guardians of the Galaxy                   0.851874
# 788                  Deadpool                   0.725217
# 127        Mad Max: Fury Road                   0.670973
# ...                       ...                        ...
# 2122               Epic Movie                   0.102239
# 210            Batman & Robin                   0.019593
# 3746        The Boy Next Door                   0.039279
# 242            Fantastic Four                   0.017935
# 1652     Dragonball Evolution                   0.000000
#
#       normalized_popularity     score
# 95                 0.827162  0.866801
# 546                1.000000  0.730315
# 94                 0.549462  0.700668
# 788                0.587690  0.656453
# 127                0.495989  0.583481
# ...                     ...       ...
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=movies_scored_df['score'].head(10),y=movies_scored_df['original_title'].head(10))

plt.title('Best movie by popularity and rating',weight='bold')
plt.xlabel('popularity and rating',weight='bold')
plt.ylabel('Movie Title',weight='bold')
# Out:
# Text(0, 0.5, 'Movie Title')
