# %% [markdown]
# ![Screenshot%20%28460%29.png](attachment:Screenshot%20%28460%29.png)

# %% [markdown]
# This is the first model

# %% [markdown]
# ![Screenshot%20%28455%29.png](attachment:Screenshot%20%28455%29.png)

# %% [raw]
# Here the 5*5 layer is replaced with two 3*3 layer

# %% [markdown]
# ![Screenshot%20%28457%29.png](attachment:Screenshot%20%28457%29.png)

# %% [raw]
# Here n*n layer is replaced by a n*1 and 1*n layer in series connection

# %% [markdown]
# ![Screenshot%20%28458%29.png](attachment:Screenshot%20%28458%29.png)

# %% [raw]
# Here instead of series connection it is broken down in parallel connection to increase the width of the network

# %% [raw]
# Improvements in the new versions of inception are as follows:-
#     1. They have improvised on the learning rate.
#     2. They have removed dropout
#     3. The weightage of l2 regularizer is decreased.
#     4. Accelerated the decay of learning rate. Decaying the learning rate helps in convergence.
#     5. Removed local response normalisation.
#     6. Reduced image distortion.

# %%
Chnages in version 3:-
    1. They added batch normalisation in auxillary branches giving it a bit of regularization.
    2. They addef RMS prop as optimiser.
    3. They factorized 7*7 factorization. (7*1 and 1*7)
    4. Label smoothening(regularization method)(this reduces the confidence level of the model)

# %% [markdown]
# ### Inception V4 and inception Resnet.

# %% [raw]
# Inception resnet is a combination on inception and resnet.
# Inception V3 is very similar to Inception resnet V1
# Inception V4 is very similar to Inception resnet V2
#
# In inception V4 the stem is changed.

# %%
Instead of going for pooling we can use reduction blocks.

# %% [raw]
# In Resnet to add F(x) and x,the dimensions of F(x) and x should be same. i.e the input and output dimensions should be same.The max pooling layers have been removed to avoid change in dimension.
