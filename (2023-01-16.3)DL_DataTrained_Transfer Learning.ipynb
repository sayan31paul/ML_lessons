# %% [raw]
# Limitation problem in neural networks.
#
# In Alexnet we have to train 60 million parameters. In VGG we have to train 138 million parameters. As the size of the network changes, the number of trainable parameters increases which increases the computation cost. In case our trained model doesnot perform well, we will again have to spend time and resorces for training another model.
#
# To solve this problem of limitation of resources, we use transfer learning.
#
# Here we used a pretrained model, whose layers, weights and biases have been open sourced. Oue problem statement is not going to be exactly same as that of the pretrained model, neither it is possible to train the model from scratch. So we have to make changes in the pretrained model.

# %% [markdown]
# ![Screenshot%20%28470%29.png](attachment:Screenshot%20%28470%29.png)

# %% [raw]
# In the initial few layers of the CNN we keep the weights as constant. We train the weights and biases in the final layers.
#
# The initial features of a model are edges, corners etc which are common in all neural networks. During back propagation we will update only the weights and biases in the trainable part of the neural network.
#
# Back propagation will not be applied on the pre-trained part.The weights and biases in the pre trained part will remain the same. This is known as freezing of layers.

# %% [raw]
# In computer vision most tasks are executed through transfer learning.
