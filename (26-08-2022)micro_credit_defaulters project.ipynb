# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('MC_defaulters.csv')
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df=df.drop(columns=['Unnamed: 0'],axis=1)

# %%
df1=df

# %%
df=df.drop(columns=['label'],axis=1)

# %%
df.columns
# Out:
# Index(['msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pcircle', 'pdate'],
#       dtype='object')

# %%
df['label']=df1['label']

# %%
df.columns
# Out:
# Index(['msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pcircle', 'pdate', 'label'],
#       dtype='object')

# %%
df.isnull().sum()

#no null values present in data
# Out:
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# ...

# %%
df.shape

#number of  rows present is extremely high.
# Out:
# (209593, 36)

# %% [markdown]
# # EDA

# %%
df.dtypes
# Out:
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# ...

# %%
df['msisdn'].values
# Out:
# array(['21408I70789', '76462I70374', '17943I70372', ..., '28556I85350',
#        '59712I82733', '65061I85339'], dtype=object)

# %% [raw]
# 'msisdn' contains the mobile number of the customer. It is given in object format which is not being possible to convert to int or float in any manner.
# Moreover from common sense we know that it is not possible to detect a defaulter from his/her phone number. So we are dropping the column.

# %%
df=df.drop(columns=['msisdn'],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['pcircle']=le.fit_transform(df['pcircle'])

# %%
df['padte1']=pd.to_datetime(df['pdate'])
df['pdate'].dtypes
# Out:
# dtype('O')

# %%
df
# Out:
#            aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0        272.0   3055.050000   3065.150000    220.13    260.13
# 1        712.0  12122.000000  12124.750000   3691.26   3691.26
# 2        535.0   1398.000000   1398.000000    900.13    900.13
# 3        241.0     21.228000     21.228000    159.42    159.42
# 4        947.0    150.619333    150.619333   1098.90   1098.90
# ...        ...           ...           ...       ...       ...
# 209588   404.0    151.872333    151.872333   1089.19   1089.19
# 209589  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                     2.0                0.0              1539              2
# ...

# %%
df.dtypes
# Out:
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30              float64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# fr_da_rech90                     int64
# cnt_loans30                      int64
# amnt_loans30                     int64
# ...

# %%
df=df.drop(columns=['pdate','padte'],axis=1)

# %%
df.rename(columns={'pdate1':'pdate'},inplace=True)

# %%
df.columns
# Out:
# Index(['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pcircle', 'label', 'padte1'],
#       dtype='object')

# %%
df1=df

# %%
df=df.drop(columns=['label'],axis=1)

# %%
df['label']=df1['label']

# %%
df.columns
# Out:
# Index(['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pcircle', 'padte1', 'label'],
#       dtype='object')

# %%
sns.scatterplot(x=df['aon'],y=df['label'])
plt.show()
sns.distplot(df['aon'])
plt.show()

# %%
sns.scatterplot(x=df['daily_decr30'],y=df['label'])
plt.show()
sns.distplot(df['daily_decr30'])
plt.show()

#skewness present in data
#This column might be use ful in data calssification

# %%
i=df['daily_decr90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#skewness present in data
#This column might be useful in data classification

# %%
i=df['rental30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['rental30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['rental90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['last_rech_date_ma']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['last_rech_date_da']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#This column might not be too useful for classificaion purpose.

# %%
i=df['cnt_ma_rech30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['fr_ma_rech30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#This column might not be too beneficial for classification

# %%
i=df['sumamnt_ma_rech30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['medianamnt_ma_rech30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#skewness present in data is visible

# %%
i=df['medianamnt_ma_rech30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#skewness is visible

# %%
i=df['medianmarechprebal30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#This column might not be too useful for classification.

# %%
i=df['cnt_ma_rech90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#skewness present in data

# %%
i=df['fr_ma_rech90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#skewness present in data.

# %%
i=df['sumamnt_ma_rech90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['medianamnt_ma_rech90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#skewness present in data.

# %%
i=df['medianmarechprebal90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['cnt_da_rech30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#Not much beneficial for classification

# %%
i=df['fr_da_rech30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['cnt_da_rech90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['fr_da_rech90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['cnt_loans30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#Useful for classification but has skewness present in data.

# %%
i=df['amnt_loans30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['maxamnt_loans30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['medianamnt_loans30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['cnt_loans90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['amnt_loans90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['maxamnt_loans90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['medianamnt_loans90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['payback30']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['payback90']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['pcircle']
sns.scatterplot(x=i,y=df['label'])
plt.show()
sns.distplot(i)
plt.show()

#All the customers are from the same circle. This this column will not be effcetive for classification purpose.

# %%
df=df.drop(columns=['pcircle'],axis=1)

# %%
i=df['padte1']
sns.scatterplot(x=i,y=df['label'])
plt.xticks(rotation = 90)
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['Day']
sns.scatterplot(x=i,y=df['labels'])
plt.xticks(rotation = 90)
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['Month']
sns.scatterplot(x=i,y=df['labels'])
plt.xticks(rotation = 90)
plt.show()
sns.distplot(i)
plt.show()

# %%
i=df['Year']
sns.scatterplot(x=i,y=df['labels'])
plt.xticks(rotation = 90)
plt.show()
sns.distplot(i)
plt.show()

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
#Since the dataset is imbalanced, we are applying SMOTE on it
#x=df.iloc[:,0:-1]
#y=df.iloc[:,-1]

#from imblearn.over_sampling import SMOTE
#smt=SMOTE()
#x,y=smt.fit_resample(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-4910cf37fec8> in <module>
#       5 from imblearn.over_sampling import SMOTE
#       6 smt=SMOTE()
# ----> 7 x,y=smt.fit_resample(x,y)
#
# ~\AppData\Roaming\Python\Python38\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      75         check_classification_targets(y)
#      76         arrays_transformer = ArraysTransformer(X, y)
# ---> 77         X, y, binarize_y = self._check_X_y(X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
#
# ~\AppData\Roaming\Python\Python38\site-packages\imblearn\base.py in _check_X_y(self, X, y, accept_sparse)
#     130             accept_sparse = ["csr", "csc"]
#     131         y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 132         X, y = self._validate_data(X, y, reset=True, accept_sparse=accept_sparse)
# ...

# %% [raw]
# From the above code it is evident that we cannot apply SMOTE if the dataset conmtains datetime64 datatype. So here we will try to create one more datasset which will contain different column for year, month and date.

# %%
df['Day']=df['padte1'].dt.day      
df['Month']=df['padte1'].dt.month  
df['Year']=df['padte1'].dt.year

# %%
df1=df

# %%
df=df.drop(columns=['label'],axis=1)

# %%
df['label']=df1['label']

# %%
df.columns
# Out:
# Index(['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pcircle', 'padte1', 'Day', 'Month', 'Year', 'label'],
#       dtype='object')

# %%
df=df.drop(columns=['padte1'],axis=1)

# %%
df.shape
# Out:
# (209593, 37)

# %%
#Since the dataset is imbalanced, we are applying SMOTE on it
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

from imblearn.over_sampling import SMOTE
smt=SMOTE()
x,y=smt.fit_resample(x,y)

# %%
x
# Out:
#                   aon  daily_decr30  daily_decr90     rental30     rental90  \
# 0          272.000000   3055.050000   3065.150000   220.130000   260.130000
# 1          712.000000  12122.000000  12124.750000  3691.260000  3691.260000
# 2          535.000000   1398.000000   1398.000000   900.130000   900.130000
# 3          241.000000     21.228000     21.228000   159.420000   159.420000
# 4          947.000000    150.619333    150.619333  1098.900000  1098.900000
# ...               ...           ...           ...          ...          ...
# 366857     895.352852      1.532425      1.532425     5.835437     5.835437
# 366858     999.215219      0.197726      0.197726  3074.445026  3074.445026
# 366859     260.107466      2.244930      2.244930  1346.615429  1346.615429
# 366860  805467.516938    991.300698    991.300698  2563.292610  2563.292610
# 366861     150.450151      0.405324      0.405324     1.074186     1.074186
#
# ...

# %%
df=x

# %%
df['labels']=y

# %%
df.shape
# Out:
# (366862, 37)

# %%
df.columns
# Out:
# Index(['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90',
#        'pcircle', 'Day', 'Month', 'Year', 'labels'],
#       dtype='object')

# %%
df=df.drop(columns='pcircle',axis=1)

# %%
df
# Out:
#                   aon  daily_decr30  daily_decr90     rental30     rental90  \
# 0          272.000000   3055.050000   3065.150000   220.130000   260.130000
# 1          712.000000  12122.000000  12124.750000  3691.260000  3691.260000
# 2          535.000000   1398.000000   1398.000000   900.130000   900.130000
# 3          241.000000     21.228000     21.228000   159.420000   159.420000
# 4          947.000000    150.619333    150.619333  1098.900000  1098.900000
# ...               ...           ...           ...          ...          ...
# 366857     895.352852      1.532425      1.532425     5.835437     5.835437
# 366858     999.215219      0.197726      0.197726  3074.445026  3074.445026
# 366859     260.107466      2.244930      2.244930  1346.615429  1346.615429
# 366860  805467.516938    991.300698    991.300698  2563.292610  2563.292610
# 366861     150.450151      0.405324      0.405324     1.074186     1.074186
#
# ...

# %%
sns.countplot(df['labels'])
# Out:
# <AxesSubplot:xlabel='labels', ylabel='count'>

# %%
df.to_csv("MC_defaulters_final.csv")

# %%
df=pd.read_csv("MC_defaulters_final.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#         Unnamed: 0            aon  daily_decr30  daily_decr90     rental30  \
# 0                0     272.000000   3055.050000   3065.150000   220.130000
# 1                1     712.000000  12122.000000  12124.750000  3691.260000
# 2                2     535.000000   1398.000000   1398.000000   900.130000
# 3                3     241.000000     21.228000     21.228000   159.420000
# 4                4     947.000000    150.619333    150.619333  1098.900000
# ...            ...            ...           ...           ...          ...
# 366857      366857     895.352852      1.532425      1.532425     5.835437
# 366858      366858     999.215219      0.197726      0.197726  3074.445026
# 366859      366859     260.107466      2.244930      2.244930  1346.615429
# 366860      366860  805467.516938    991.300698    991.300698  2563.292610
# 366861      366861     150.450151      0.405324      0.405324     1.074186
#
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df.skew()

#As it is evident, most of the columns has very high skewness. So skewness removal will be required.
#We will be trying every model and every dataset with and without skewness removal.
# Out:
# aon                     10.134835
# daily_decr30             4.856739
# daily_decr90             5.289431
# rental30                 4.450783
# rental90                 4.539719
# last_rech_date_ma       15.258610
# last_rech_date_da       14.994474
# last_rech_amt_ma         4.868233
# cnt_ma_rech30            3.634853
# fr_ma_rech30            14.855373
# sumamnt_ma_rech30        6.797660
# medianamnt_ma_rech30     4.601591
# medianmarechprebal30    14.096410
# cnt_ma_rech90            3.930491
# fr_ma_rech90             2.532443
# sumamnt_ma_rech90        5.571031
# medianamnt_ma_rech90     4.760578
# medianmarechprebal90    49.344597
# cnt_da_rech30           18.471151
# fr_da_rech30            14.753374
# cnt_da_rech90           28.989788
# fr_da_rech90            27.244954
# cnt_loans30              3.418863
# amnt_loans30             3.651471
# maxamnt_loans30         17.845181
# medianamnt_loans30       5.094859
# cnt_loans90             17.562420
# ...

# %% [raw]
# Now we will be creating 3 different datasets and test which dataset is working better for which model:-
#     1.df--> Here we will keep all columns present in the dataset.
#     2.df_c--> Here we will keep only the columns which has high correlation with the target.
#     3.df_r--> Here we will use the visulaizations to decide which columns will help in classification and keep only those columns.

# %%
df.corr()['labels']
# Out:
# aon                    -0.004746
# daily_decr30            0.313641
# daily_decr90            0.312726
# rental30                0.096338
# rental90                0.130589
# last_rech_date_ma       0.005688
# last_rech_date_da       0.002351
# last_rech_amt_ma        0.214266
# cnt_ma_rech30           0.423788
# fr_ma_rech30            0.001956
# sumamnt_ma_rech30       0.363075
# medianamnt_ma_rech30    0.227189
# medianmarechprebal30   -0.007872
# cnt_ma_rech90           0.428174
# fr_ma_rech90            0.145240
# sumamnt_ma_rech90       0.374209
# medianamnt_ma_rech90    0.191068
# medianmarechprebal90    0.062820
# cnt_da_rech30           0.006595
# fr_da_rech30           -0.000631
# cnt_da_rech90           0.025868
# fr_da_rech90           -0.004560
# cnt_loans30             0.382930
# amnt_loans30            0.361524
# maxamnt_loans30         0.000233
# medianamnt_loans30      0.080907
# cnt_loans90             0.014023
# amnt_loans90            0.369852
# ...

# %%
df.shape
# Out:
# (366862, 36)

# %%
#since the value of year is same in al columns, it will not be beneficial for us. So are dropping the year column for df.
df=df.drop(columns=['Year'],axis=1)

# %%
#creating df_c
df_c=df.drop(columns=['aon','last_rech_date_ma','last_rech_date_da','fr_ma_rech30','medianmarechprebal30','cnt_da_rech30','fr_da_rech30','fr_da_rech90','maxamnt_loans30'],axis=1)

# %%
df_c.shape
# Out:
# (366862, 26)

# %%
#creating df_r
df_r=df.drop(columns=['aon','last_rech_date_ma','last_rech_date_da','fr_ma_rech30','medianmarechprebal30','fr_ma_rech90','cnt_da_rech30','fr_da_rech30','maxamnt_loans30','cnt_loans90','Day'],axis=1)

# %%
df_r.columns
# Out:
# Index(['daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'cnt_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech90',
#        'fr_da_rech90', 'cnt_loans30', 'amnt_loans30', 'medianamnt_loans30',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'Month', 'labels'],
#       dtype='object')

# %% [raw]
# We have prepared all the three datasets.

# %% [markdown]
# # Outlier Removal

# %%
#outlier removal
from scipy.stats import zscore
z=np.abs(zscore(df))


df_new=df[(z<3.0).all(axis=1)]
print(df.shape)
print(df_new.shape)

print("loss_percent= ",(df.shape[0]-df_new.shape[0])/df.shape[0]*100)

#The loss percent is very high, so we are not going for outlier removal
# Out:
# (366862, 35)
# (265399, 35)
# loss_percent=  27.6569936379347

# %%
#outlier removal
from scipy.stats import zscore
z=np.abs(zscore(df))


df_new=df_c[(z<3.0).all(axis=1)]
print(df.shape)
print(df_new.shape)

print("loss_percent= ",(df.shape[0]-df_new.shape[0])/df.shape[0]*100)

#The loss percent is very high, so we are not going for outlier removal
# Out:
# (366862, 35)
# (265399, 26)
# loss_percent=  27.6569936379347

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))


df_new=df_r[(z<3.0).all(axis=1)]
print(df.shape)
print(df_new.shape)

print("loss_percent= ",(df.shape[0]-df_new.shape[0])/df.shape[0]*100)

#The loss percent is very high, so we are not going for outlier removal
# Out:
# (366862, 35)
# (265399, 24)
# loss_percent=  27.6569936379347

# %%
df.to_csv("MC_defaulters_df.csv")

# %%
df_c.to_csv("MC_defaulters_df_c.csv")

# %%
df_r.to_csv("MC_defaulters_df_r.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.preprocessing import PowerTransformer
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Model training starts

# %% [markdown]
# #### Trying all the datasets with logistic regression model

# %%
#df
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[25749 10698]
#  [ 8498 28428]]
# accuracy_score= 0.7383778774208496
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73     36447
#            1       0.73      0.77      0.75     36926
#
#     accuracy                           0.74     73373
#    macro avg       0.74      0.74      0.74     73373
# weighted avg       0.74      0.74      0.74     73373

# %%
#df+power_transformer
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[29591  6856]
#  [ 7660 29266]]
# accuracy_score= 0.8021615580663187
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80     36447
#            1       0.81      0.79      0.80     36926
#
#     accuracy                           0.80     73373
#    macro avg       0.80      0.80      0.80     73373
# weighted avg       0.80      0.80      0.80     73373

# %%
#df_c+power_transformer
x=df_c.iloc[:,0:-1]
y=df_c.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[29268  7179]
#  [ 7755 29171]]
# accuracy_score= 0.7964646395813174
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80     36447
#            1       0.80      0.79      0.80     36926
#
#     accuracy                           0.80     73373
#    macro avg       0.80      0.80      0.80     73373
# weighted avg       0.80      0.80      0.80     73373

# %%
#df_r+power_transformer
x=df_r.iloc[:,0:-1]
y=df_r.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[29478  6969]
#  [ 8082 28844]]
# accuracy_score= 0.7948700475651806
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.80     36447
#            1       0.81      0.78      0.79     36926
#
#     accuracy                           0.79     73373
#    macro avg       0.80      0.79      0.79     73373
# weighted avg       0.80      0.79      0.79     73373

# %% [markdown]
# ##### Trying all the datasets with KNeighbors classifier model

# %%
#df
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
y_pred=knc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[35296  1151]
#  [ 8475 28451]]
# accuracy_score= 0.8688073269458793
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88     36447
#            1       0.96      0.77      0.86     36926
#
#     accuracy                           0.87     73373
#    macro avg       0.88      0.87      0.87     73373
# weighted avg       0.88      0.87      0.87     73373

# %%
from sklearn.preprocessing import StandardScaler

# %%
#df+standard_scaler
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

scaler = StandardScaler()
x=scaler.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
y_pred=knc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[33863  2584]
#  [ 6520 30406]]
# accuracy_score= 0.8759216605563355
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88     36447
#            1       0.92      0.82      0.87     36926
#
#     accuracy                           0.88     73373
#    macro avg       0.88      0.88      0.88     73373
# weighted avg       0.88      0.88      0.88     73373

# %% [markdown]
# ##### Trying RandomForestClassification model

# %%
#df+power transfomer
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[34537  1910]
#  [ 1843 35083]]
# accuracy_score= 0.9488503945593065
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     36447
#            1       0.95      0.95      0.95     36926
#
#     accuracy                           0.95     73373
#    macro avg       0.95      0.95      0.95     73373
# weighted avg       0.95      0.95      0.95     73373

# %%
#df_c+power transfomer
x=df_c.iloc[:,0:-1]
y=df_c.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[34288  2159]
#  [ 1987 34939]]
# accuracy_score= 0.9434942008640781
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     36447
#            1       0.94      0.95      0.94     36926
#
#     accuracy                           0.94     73373
#    macro avg       0.94      0.94      0.94     73373
# weighted avg       0.94      0.94      0.94     73373

# %%
#df_r+power transfomer
x=df_r.iloc[:,0:-1]
y=df_r.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[33905  2542]
#  [ 2275 34651]]
# accuracy_score= 0.9343491475065759
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93     36447
#            1       0.93      0.94      0.94     36926
#
#     accuracy                           0.93     73373
#    macro avg       0.93      0.93      0.93     73373
# weighted avg       0.93      0.93      0.93     73373

# %% [markdown]
# ##### Trying Gradient Boosting classifier model

# %%
#df+power transfomer
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
gbc=GradientBoostingClassifier(n_estimators=1000)
gbc.fit(x_train,y_train)
y_pred=gbc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[34056  2391]
#  [ 1827 35099]]
# accuracy_score= 0.9425129134695324
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94     36447
#            1       0.94      0.95      0.94     36926
#
#     accuracy                           0.94     73373
#    macro avg       0.94      0.94      0.94     73373
# weighted avg       0.94      0.94      0.94     73373

# %%
#df_c+power transfomer
x=df_c.iloc[:,0:-1]
y=df_c.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
gbc=GradientBoostingClassifier(n_estimators=1000)
gbc.fit(x_train,y_train)
y_pred=gbc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[33675  2772]
#  [ 2398 34528]]
# accuracy_score= 0.9295381134749839
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.93     36447
#            1       0.93      0.94      0.93     36926
#
#     accuracy                           0.93     73373
#    macro avg       0.93      0.93      0.93     73373
# weighted avg       0.93      0.93      0.93     73373

# %%
#df_r+power transfomer
x=df_r.iloc[:,0:-1]
y=df_r.iloc[:,-1]

pt=PowerTransformer()
x=pt.fit_transform(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
gbc=GradientBoostingClassifier(n_estimators=1000)
gbc.fit(x_train,y_train)
y_pred=gbc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[33177  3270]
#  [ 2603 34323]]
# accuracy_score= 0.9199569323865727
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92     36447
#            1       0.91      0.93      0.92     36926
#
#     accuracy                           0.92     73373
#    macro avg       0.92      0.92      0.92     73373
# weighted avg       0.92      0.92      0.92     73373

# %% [raw]
# As it is evident from the above results, Random forest classifier and Gradient Boosting classifier is giving best results. So we will apply hyperparameter tuning on them
