# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
books=pd.read_csv('BX-Books.csv',sep=';',error_bad_lines=False,encoding='latin-1')
# Out:
# b'Skipping line 6452: expected 8 fields, saw 9\nSkipping line 43667: expected 8 fields, saw 10\nSkipping line 51751: expected 8 fields, saw 9\n'
# b'Skipping line 92038: expected 8 fields, saw 9\nSkipping line 104319: expected 8 fields, saw 9\nSkipping line 121768: expected 8 fields, saw 9\n'
# b'Skipping line 144058: expected 8 fields, saw 9\nSkipping line 150789: expected 8 fields, saw 9\nSkipping line 157128: expected 8 fields, saw 9\nSkipping line 180189: expected 8 fields, saw 9\nSkipping line 185738: expected 8 fields, saw 9\n'
# b'Skipping line 209388: expected 8 fields, saw 9\nSkipping line 220626: expected 8 fields, saw 9\nSkipping line 227933: expected 8 fields, saw 11\nSkipping line 228957: expected 8 fields, saw 10\nSkipping line 245933: expected 8 fields, saw 9\nSkipping line 251296: expected 8 fields, saw 9\nSkipping line 259941: expected 8 fields, saw 9\nSkipping line 261529: expected 8 fields, saw 9\n'

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books=books[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher']]

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books=books.rename(columns={'Book-Title':'title','Book-Author':'author','Year-Of-Publication':'year','Publisher':'publisher'})

# %%
books
# Out:
#               ISBN                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
users=pd.read_csv('BX-Users.csv',sep=';',error_bad_lines=False,encoding='latin-1')

# %%
users.columns
# Out:
# Index(['User-ID', 'Location', 'Age'], dtype='object')

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
users.rename(columns={'User-ID':'user_id','Location':'location'},inplace=True)

# %%
users
# Out:
#         user_id                            location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
ratings=pd.read_csv('BX-Book-Ratings.csv',sep=';',error_bad_lines=False,encoding='latin-1')
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
ratings.rename(columns={'User-ID':'user_id','Book-Rating':'rating'},inplace=True)
ratings
# Out:
#          user_id         ISBN  rating
# 0         276725   034545104X       0
# 1         276726   0155061224       5
# 2         276727   0446520802       0
# 3         276729   052165615X       3
# 4         276729   0521795028       6
# ...          ...          ...     ...
# 1149775   276704   1563526298       9
# 1149776   276706   0679447156       0
# 1149777   276709   0515107662      10
# 1149778   276721   0590442449      10
# 1149779   276723  05162443314       8
#
# [1149780 rows x 3 columns]

# %%
books.shape
# Out:
# (271360, 5)

# %%
users.shape
# Out:
# (278858, 3)

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
# Which user has given rating to how many books?
ratings['user_id'].value_counts()
# Out:
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 271728        1
# 245123        1
# 234886        1
# 259466        1
# 187812        1
# Name: user_id, Length: 105283, dtype: int64

# %%
ratings['user_id'].value_counts().shape

#105283 users have actually read some books
# Out:
# (105283,)

# %%
x=ratings['user_id'].value_counts()>200

# %%
x.shape
# Out:
# (105283,)

# %%
x[x].shape

# 899 users have given ratings more than 200 times
# Out:
# (899,)

# %%
y=x[x]

# %%
y
# Out:
# 11676     True
# 198711    True
# 153662    True
# 98391     True
# 35859     True
#           ...
# 274808    True
# 73681     True
# 9856      True
# 268622    True
# 44296     True
# Name: user_id, Length: 899, dtype: bool

# %%
y=x[x].index

#These are the indexes of the users who have rated more than 200 books

# %%
y
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             116122,  28634, 188951,  59727, 155916, 274808,  73681,   9856,
#             268622,  44296],
#            dtype='int64', length=899)

# %%
ratings=ratings[ratings['user_id'].isin(y)]
ratings
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1457      277427  0026217457       0
# 1458      277427  003008685X       8
# 1459      277427  0030615321       0
# 1460      277427  0060002050       0
# ...          ...         ...     ...
# 1147612   275970  3829021860       0
# 1147613   275970  4770019572       0
# 1147614   275970   896086097       0
# 1147615   275970  9626340762       8
# 1147616   275970  9626344990       0
#
# [526356 rows x 3 columns]

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
type(ratings)
# Out:
# pandas.core.frame.DataFrame

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
z=ratings['ISBN'].value_counts()>50

# %%
z[z].shape
# Out:
# (504,)

# %%
z[z]
# Out:
# 0971880107    True
# 0316666343    True
# 0060928336    True
# 0440214041    True
# 0385504209    True
#               ...
# 0385420161    True
# 1558745157    True
# 0385503822    True
# 0440193613    True
# 0425121631    True
# Name: ISBN, Length: 504, dtype: bool

# %%
a=z[z].index
a
# Out:
# Index(['0971880107', '0316666343', '0060928336', '0440214041', '0385504209',
#        '044021145X', '0440211727', '067976402X', '0446672211', '0440222656',
#        ...
#        '0515135062', '0440207622', '0345445848', '0671014919', '0373218192',
#        '0385420161', '1558745157', '0385503822', '0440193613', '0425121631'],
#       dtype='object', length=504)

# %%
ratings=ratings[ratings['ISBN'].isin(a)]
ratings
# Out:
#          user_id        ISBN  rating
# 1456      277427  002542730X      10
# 1469      277427  0060930535       0
# 1471      277427  0060934417       0
# 1474      277427  0061009059       9
# 1484      277427  0140067477       0
# ...          ...         ...     ...
# 1147208   275970  0743412028       0
# 1147304   275970  0804111359       0
# 1147436   275970  140003065X       0
# 1147440   275970  1400031354       0
# 1147441   275970  1400031362       0
#
# [40936 rows x 3 columns]

# %%
ratings=ratings.merge(books,on='ISBN')

# %%
ratings
# Out:
#        user_id        ISBN  rating  \
# 0       277427  002542730X      10
# 1         3363  002542730X       0
# 2        11676  002542730X       6
# 3        12538  002542730X      10
# 4        13552  002542730X       0
# ...        ...         ...     ...
# 40752   251843  0553292722      10
# 40753   258185  0553292722       0
# 40754   265889  0553292722       0
# 40755   269566  0553292722       0
# 40756   269890  0553292722       0
#
#                                                    title             author  \
# 0      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 1      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 2      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 3      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# ...                                                  ...                ...
# ...

# %%
ratings.drop_duplicates(['user_id','title'],inplace=True)
ratings.shape
# Out:
# (40671, 7)

# %%
ratings=ratings.pivot_table(columns='user_id',index='title',values='rating').fillna(0)

# %%
ratings
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix
ratings=csr_matrix(ratings)

# %%
ratings
# Out:
# <493x883 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10103 stored elements in Compressed Sparse Row format>

# %%
type(ratings)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors

model_knn=NearestNeighbors(metric='cosine',algorithm='brute') #Creting object from class
model_knn.fit(ratings) #Not enteirng train_y , hence unsupervised ML
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')
