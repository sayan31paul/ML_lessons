# %% [markdown]
# # Introduction To Selenium

# %% [raw]
# 1. Selenium is a web browser automation tool.
#
# 2. It allows us to open browser of our choice and perform tasks as a human being would like:
#    a.Clicking Buttons
#    b.Entering information in forms
#    c.Searching for information in web pages
#
# Uses a web-driver package that can take control of the browser and mimic user-oriented actions

# %% [markdown]
# # Beautiful Soup vs Selenium

# %% [raw]
# BeautifulSoup:
# -A module that can be used for pulling data out of HTML or XML documents.
# -Depends heavily on other libraries like requests or urlib for sending web requests
# -Doesnot have a document parser. We need to chose one like 'html.parser'.
# -It is difficult to scrap websites which return Java Script code
# -It doesnot automate the web browser. It saves a copy of the web page source and then does further processing
#
# Selenium:
# -A tool developed for web application automated testing
# -Can send web requests on its own
# -It comes with a parser
# -Loads JavaScript and helps access data behind JavaScript files as well
# -Faster than BeautifulSoup while interacting with webpages.
# -Comes handy when handling JavaScript featured websites

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %% [raw]
# Selenium Drivers- These web drivers enable python to control the browser for interactions

# %% [markdown]
# # Locating Web Elements in Selenium

# %% [raw]
# find_element_by_id: uses id to find a element
#
# find_element_by_name:uses name to find a element
#
# find_element_by_xpath:uses xpath to find a element
#
# find_element_by_tag_name:uses tag name to find a element
#
# find_element_by_class_name: uses value of class attribute to find an element
#
# There are other functions as well which help us to locate elements on the web page.

# %% [markdown]
# # XPath Syntax

# %% [raw]
# XPath known as  XML path is a language that helps to query the XML documents. It consists of expression for a path with certain conditions to locate a particular element.
#
# The basic format of XPath is:
#
# XPath=//tagname[@Attribute='value']

# %% [markdown]
# # Types of XPaths

# %% [raw]
# There are two types of XPaths:
#     -Absolute XPath
#     -Relative XPath
#
# Absolute XPath: Begins with the single forward slash(/),means we select the element from the root node and go all the way down the element needed.
#
# Relative XPath: Starts from the middle of the HTML structure. Starts with double forward slash(//) and can search elements anywhere on the webpage without writing the long absolute xpath
#
# //div[@class='featured-box columnsize1']//h4[1]//b[1]

# %% [markdown]
# ![Screenshot%20%28351%29.png](attachment:Screenshot%20%28351%29.png)

# %% [markdown]
# ![Screenshot%20%28352%29.png](attachment:Screenshot%20%28352%29.png)

# %% [markdown]
# # Web Scraping On Naukri.com Using selenium

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
#Lets first connect to the web driver
#driver=webdriver.Chrome(r"‪C:\Users\sayan\chromedriver.exe")

# %%
#lets first connect to the web driver
driver=webdriver.Chrome("chromedriver.exe")

# %%
#driver.close()

# %%
driver.get('https://www.naukri.com/')

# %%
#finding element for job search bar
search_field_designation=driver.find_element_by_class_name('suggestor-input ')
search_field_designation.send_keys("Data Analyst")
search_field_location=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input")
search_field_location.send_keys("Bangalore")

# %%
search_button=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search_button.click()

# %%
#alternate way to open the same page
#specifying the url of the webpage to be scraped
#url="https://www.naukri.com/data-analyst-jobs-in-bangalore?k=data%20analyst&l=bangalore"
#driver.get(url)

# %%
job_titles=[]
company_names=[]
locations_list=[]
experience_list=[]

# %%
#lets extract all the tags having the job titles
titles_tags=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
titles_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="17333a2b-a856-4beb-b0f0-b9558cf91707")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="a0561c0a-8b1f-4ab8-972b-996c6d912a56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="9eae7846-c69c-4ed6-ada2-a9e33ba67f6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="f907c9fc-2ba7-44b5-9c79-ea347dd41b54")>]

# %%
for i in titles_tags:
    title=i.text
    job_titles.append(title)
job_titles[0:4]
# Out:
# ['Data Analysts with Business Analysis',
#  'Data Analyst / Data Engineer',
#  'Sr Domain Expert -Data Analysts',
#  'Business Analyst/Data Analyst']

# %%
companies_tags=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
companies_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="4861bd8f-a1e9-4319-9f70-ebb255489029")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="1e12371e-ccd2-4f59-8438-45dc51fc408d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="aed8527a-0049-4a82-b593-7cac5c35c34c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="ade0c4d9-3d57-477a-937a-de17d77e58e4")>]

# %%
for i in companies_tags:
    title=i.text
    company_names.append(title)
company_names[0:4]
# Out:
# ['Avanze Technologies India Pvt. Ltd.',
#  'TALENT MAX HR & MANAGEMENT CONSULTANTS',
#  'Siemens',
#  'Telamon HR Solutions']

# %%
experience_tags=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]/span[1]')
experience_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="bb5a87eb-0e8f-4624-87c4-3ea27bd0ad88")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="9c92003f-6157-461c-8a70-d9f094a4a7ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="55fb265b-be75-4daf-b25a-67da93319c9d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="1fe08b74-bdb6-4fc3-9ba3-1b736f23854d")>]

# %%
for i in experience_tags:
    title=i.text
    experience_list.append(title)
experience_list[0:4]
# Out:
# ['6-8 Yrs', '8-13 Yrs', '0-10 Yrs', '3-5 Yrs']

# %%
location_tags=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]/span[1]')
location_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="603caa29-45d1-46c9-ad1b-d1948e6d9d07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="d856fae5-54b3-4046-b1e9-3c762fd1e72c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="91199f1b-ecd8-4e10-80e3-dfecd47f5460")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a9b3b08e7d83a0f19f2e853ba8cfa86d", element="a3118de9-2f02-4a9d-bf98-5e394602769d")>]

# %%
for i in location_tags:
    title=i.text
    locations_list.append(title)
locations_list[0:4]
# Out:
# ['Bangalore/Bengaluru',
#  'Indore, Pune, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Bangalore/Bengaluru, Delhi / NCR']

# %%
print(len(job_titles),len(company_names),len(experience_list),len(locations_list))
# Out:
# 20 20 20 20

# %%
jobs=pd.DataFrame()
jobs['Titles']=job_titles[0:10]
jobs['company']=company_names[0:10]
jobs['experience_required']=experience_list[0:10]
jobs['location']=locations_list[0:10]

# %%
jobs
# Out:
#                                  Titles  \
# 0  Data Analysts with Business Analysis
# 1          Data Analyst / Data Engineer
# 2       Sr Domain Expert -Data Analysts
# 3         Business Analyst/Data Analyst
# 4             Senior Data Analyst - KPO
# 5                   Senior Data Analyst
# 6                          Data Analyst
# 7           Blockchain AML Data Analyst
# 8                   Senior Data Analyst
# 9                   Senior Data Analyst
#
#                                   company experience_required  \
# 0     Avanze Technologies India Pvt. Ltd.             6-8 Yrs
# 1  TALENT MAX HR & MANAGEMENT CONSULTANTS            8-13 Yrs
# 2                                 Siemens            0-10 Yrs
# 3                    Telamon HR Solutions             3-5 Yrs
# 4               Huquo Consulting Pvt. Ltd            7-12 Yrs
# 5                                  Cerner            8-12 Yrs
# 6                          Enrich talents             0-4 Yrs
# ...

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
#lets first connect to the web driver
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
#finding element for job search bar
search_field_designation=driver.find_element_by_class_name('suggestor-input ')
search_field_designation.send_keys("Data Scientist")
search_field_location=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input")
search_field_location.send_keys("Bangalore")

# %%
search_button=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search_button.click()

# %%
job_titles=[]
company_names=[]
locations_list=[]

# %%
#lets extract all the tags having the job titles
titles_tags=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
titles_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="29dfa1a4-5bef-4cbd-b48d-0ee0eee87fed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="ceeaa57d-1ee9-4c29-8c3b-1f2ba1f53239")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="e9c45f4f-4ea2-47c6-8655-53131745a637")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="22b54b61-8009-4692-8e83-560934e0fdb1")>]

# %%
for i in titles_tags:
    title=i.text
    job_titles.append(title)
job_titles[0:4]
# Out:
# ['ASSOCIATE DATA SCIENTIST',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist']

# %%
companies_tags=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
companies_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="7f3cdca4-f7a9-4be9-bfe6-3424f6ec3ef5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="a7224a25-240e-4464-9b2f-ba1f11697e16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="816c5150-8038-4604-ba6a-e671f2ee32af")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="a2d60e63-2b65-4ea0-a32a-1d3363e05f6c")>]

# %%
for i in companies_tags:
    title=i.text
    company_names.append(title)
company_names[0:4]
# Out:
# ['Hinduja Global',
#  'Applied Materials',
#  'Applied Materials',
#  'Applied Materials']

# %%
location_tags=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]/span[1]')
location_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="8d66af3f-2a5d-445e-b64a-d39647caba15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="dc21149d-9f6a-4d71-ade8-b76c78851f15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="49130391-02a9-4dde-a430-219102e93a54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="a8e4a1b983b22b833fb886a7832ab2ed", element="7f0c7026-884e-4e4b-a1f9-407df10c71f0")>]

# %%
for i in location_tags:
    title=i.text
    locations_list.append(title)
locations_list[0:4]
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
jobs=pd.DataFrame()
jobs['Titles']=job_titles[0:10]
jobs['company']=company_names[0:10]

jobs['location']=locations_list[0:10]

# %%
jobs
# Out:
#                                               Titles  \
# 0                           ASSOCIATE DATA SCIENTIST
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                                     Data Scientist
# 4     Data Scientist/Engineer - Global Telecom Setup
# 5                            Analyst- Data Scientist
# 6                 Data Scientist - Immediate Joiners
# 7  Senior Data Scientist/Data Scientist - Researc...
# 8                                     Data Scientist
# 9  Immediate requirement of Data Scientist ( Bang...
#
#                          company  \
# 0                 Hinduja Global
# 1              Applied Materials
# 2              Applied Materials
# 3              Applied Materials
# 4           Global Telecom Setup
# 5                  Sigma Aldrich
# 6                    Bristlecone
# 7                   Hexaconcepts
# 8                      GSK India
# 9  Firstsource Solutions Limited
#
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
#        You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
#lets first connect to the web driver
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
job_titles=[]
company_names=[]
locations_list=[]
experience_list=[]

# %%
#finding element for job search bar
search_field_designation=driver.find_element_by_class_name('suggestor-input ')
search_field_designation.send_keys("Data Scientist")

# %%
search_button=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search_button.click()

# %%
Delhi_NCR_button=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[1]/div[2]/div[3]/label/i")
Delhi_NCR_button.click()

# %%
salary_button=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[5]/div[2]/div[3]/label/i")
salary_button.click()

# %%
titles_tags=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
titles_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="546a2320-d035-42a1-ad24-f6d6153cb037")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="835c3d94-c85a-4dad-99e4-0d2f3820bc11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="e746205e-18d3-4df0-9067-fd0e1d8364bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="62a45d75-69d2-4fb8-ab6c-a6095e6d4255")>]

# %%
for i in titles_tags:
    title=i.text
    job_titles.append(title)
job_titles[0:4]
# Out:
# ['Manager - Data Scientist',
#  'Senior Business Analytics - Data Scientist/ NASDAQ Firm',
#  'Data Analyst/ Data Scientist Data Analytics & Visualizations',
#  'Data Scientist - Deep Learning Solutions']

# %%
companies_tags=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
companies_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="5032e6b8-34cd-4112-9708-ca8d5e9c82bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="f518cc1d-995b-41c6-8e94-45dd8a7f067f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="5cde0d31-2a78-4991-a198-86e419a12773")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="84814742-0d65-4938-9cc6-ca3643e9be6b")>]

# %%
for i in companies_tags:
    title=i.text
    company_names.append(title)
company_names[0:4]
# Out:
# ['SBI Card',
#  'Huquo Consulting Pvt. Ltd',
#  'SGS GLOBAL SERVICES PRIVATE LIMITED',
#  'Huquo Consulting Pvt. Ltd']

# %%
location_tags=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]/span[1]')
location_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="c8719ab0-c26c-4965-8064-37632f0410d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="235a37f8-07a5-4a53-819f-aa2ca7163ac1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="36705669-f2e6-4749-a24e-2514aba9b775")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="b0429022-a142-4791-8fb5-33d4462ae7bd")>]

# %%
for i in location_tags:
    title=i.text
    locations_list.append(title)
locations_list[0:4]
# Out:
# ['Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Noida(Sector-2 Noida)',
#  'Noida, Pune, Gurgaon/Gurugram, Bangalore/Bengaluru']

# %%
experience_tags=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]/span[1]')
experience_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="0eca8a16-6cbc-41b4-b44c-27002447c041")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="0f138a7f-c23e-4b46-88b6-d4a8da440ffc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="0aa423b8-b0a2-4a34-bc5a-c601d569ec33")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7eb069f46ae6deacc23e46e69083c948", element="9868d218-291c-49c8-bbc6-59fd477e62f2")>]

# %%
for i in experience_tags:
    title=i.text
    experience_list.append(title)
experience_list[0:4]
# Out:
# ['1-5 Yrs', '1-3 Yrs', '2-4 Yrs', '1-6 Yrs']

# %%
jobs=pd.DataFrame()
jobs['Titles']=job_titles[0:10]
jobs['company']=company_names[0:10]
jobs['experience_required']=experience_list[0:10]
jobs['location']=locations_list[0:10]

# %%
jobs
# Out:
#                                               Titles  \
# 0                           Manager - Data Scientist
# 1  Senior Business Analytics - Data Scientist/ NA...
# 2  Data Analyst/ Data Scientist Data Analytics & ...
# 3           Data Scientist - Deep Learning Solutions
# 4  Analytics India Magazine - Data Scientist - NL...
# 5    Data Scientist - Process Excellence & Analytics
# 6  Python Data Scientist - Banking/ Retail Domain...
# 7           Data Scientist - Python - Banking Domain
# 8                              Data Scientist - BFSI
# 9             Data Scientist - Python - IIT/DSE/IIMS
#
#                                company experience_required  \
# 0                             SBI Card             1-5 Yrs
# 1            Huquo Consulting Pvt. Ltd             1-3 Yrs
# 2  SGS GLOBAL SERVICES PRIVATE LIMITED             2-4 Yrs
# 3            Huquo Consulting Pvt. Ltd             1-6 Yrs
# 4                         AIM recruits             5-7 Yrs
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')
time.sleep(2)

# %%
brand=[]
product_desc=[]
price=[]

# %%
search_field_designation=driver.find_element_by_class_name('_3704LK')
search_field_designation.send_keys("sunglass")

# %%
search_button=driver.find_element_by_class_name("_34RNph")
search_button.click()

# %%
brand_tags=driver.find_elements_by_class_name('_2WkVRV')
brand_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="417dd430-c4e4-46f6-bcf8-bf5ae320b4fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="d86c3803-60ff-4f93-b0a3-fc5108ccf30e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="726930f0-15a9-47d0-b7ed-acb73ef6417d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="616dc060-79e6-413c-b664-2dc311d3dfea")>]

# %%
for i in brand_tags:
    title=i.text
    brand.append(title)
brand[0:4]
# Out:
# ['Resist', 'ROZZETTA CRAFT', 'Elligator', 'Fastrack']

# %%
desc_tags=driver.find_elements_by_class_name('IRpwTa')
desc_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="9bb356ee-68e9-4fcb-93d9-0830a6c40bbd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="b0575c42-b996-4b94-a7cf-87b50d4cc3e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="9b25552b-1fd4-4df9-9cfb-49f465808ef9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="49ce155b-7ff0-44b3-9703-3a7dcf633224")>]

# %%
for i in desc_tags:
    title=i.text
    product_desc.append(title)
product_desc[0:4]
# Out:
# ['UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Spectacle Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Wayfarer Sunglasses (Free Size)']

# %%
price_tags=driver.find_elements_by_class_name('_30jeq3')
price_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="2799d79b-7250-4601-b59c-819e12be42f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="81738055-f9da-4aa1-9598-c89551f573ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="50e2a91c-7c10-4eb0-8640-1834f6064129")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="d2034058-57ea-472f-adae-e01138230f42")>]

# %%
for i in price_tags:
    title=i.text
    price.append(title)
price[0:4]
# Out:
# ['₹829', '₹399', '₹295', '₹719']

# %%
len(price)
# Out:
# 45

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
next_button.click()

# %%
brand_tags1=driver.find_elements_by_class_name('_2WkVRV')
brand_tags1[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="e1713de8-22d6-49d7-b56f-ab30d17c0b14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="58416586-ef7c-45d1-8483-381f4e344967")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="478c4faf-5f96-4763-8087-ce85053f46b0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="4fd91a03-712c-4890-9a9f-92a810408ede")>]

# %%
for i in brand_tags1:
    title=i.text
    brand.append(title)
brand[0:4]
# Out:
# ['Resist', 'ROZZETTA CRAFT', 'Elligator', 'Fastrack']

# %%
desc_tags1=driver.find_elements_by_class_name('IRpwTa')
desc_tags1[0:4]

# %%
for i in desc_tags1:
    title=i.text
    product_desc.append(title)
product_desc[0:4]
# Out:
# ['UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Spectacle Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Wayfarer Sunglasses (Free Size)']

# %%
price_tags=driver.find_elements_by_class_name('_30jeq3')
price_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="227cc4e7-b84f-4430-bf20-5da40389f210")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="323238b4-6bc8-4f3c-9045-0de7997f5fb1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="fdac2b06-c6eb-413d-9a15-e275f2d81fe4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="0522c315-9f14-4a54-8412-f844eec06be2")>]

# %%
for i in price_tags:
    title=i.text
    price.append(title)
price[0:4]
# Out:
# ['₹829', '₹399', '₹295', '₹719']

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]/span')
next_button.click()

# %%
brand_tags1=driver.find_elements_by_class_name('_2WkVRV')
brand_tags1[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="3b7890ba-5f8c-461f-a6e4-3335353d5a5c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="673f63d0-b244-4e7e-9b48-df9ab6e533d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="0f583d6b-5cf6-4c0c-a17f-01ecebcfa8b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="3e383aa2-b584-4fbe-b910-82db48aad46b")>]

# %%
for i in brand_tags1:
    title=i.text
    brand.append(title)
brand[0:4]
# Out:
# ['Resist', 'ROZZETTA CRAFT', 'Elligator', 'Fastrack']

# %%
desc_tags1=driver.find_elements_by_class_name('IRpwTa')
desc_tags1[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="992e9de7-e618-4b26-888f-43b1bf4899da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="d00d14ca-7045-4fec-9feb-2051d0e897ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="295d06db-024f-4612-ac66-d78a72404bfb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="a0757fca-9471-4d34-bc83-5f817ff71ce7")>]

# %%
for i in desc_tags1:
    title=i.text
    product_desc.append(title)
product_desc[0:4]
# Out:
# ['UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Spectacle Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Wayfarer Sunglasses (Free Size)']

# %%
price_tags=driver.find_elements_by_class_name('_30jeq3')
price_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="df42f3d5-e02e-4837-866e-51cc19faf1ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="8e9038f3-2451-4a0e-b068-88c20870a55f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="175a905d-d36f-42ba-bcff-482413f0f557")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="ef1efc26b8c07ef20cfb89c33511d3fb", element="bc275adb-e379-44fe-ad42-4b3d3ba8557d")>]

# %%
for i in price_tags:
    title=i.text
    price.append(title)
price[0:4]
# Out:
# ['₹829', '₹399', '₹295', '₹719']

# %%
sunglass=pd.DataFrame()
sunglass['Brand']=brand[0:100]
sunglass['Product Description']=product_desc[0:100]
sunglass['Price']=price[0:100]

# %%
sunglass
# Out:
#              Brand                                Product Description Price
# 0           Resist      UV Protection Wayfarer Sunglasses (Free Size)  ₹829
# 1   ROZZETTA CRAFT     UV Protection Spectacle Sunglasses (Free Size)  ₹399
# 2        Elligator                UV Protection Round Sunglasses (54)  ₹295
# 3         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹719
# 4           PIRASO              UV Protection Aviator Sunglasses (54)  ₹249
# ..             ...                                                ...   ...
# 95  ROZZETTA CRAFT  Polarized, UV Protection Wayfarer Sunglasses (...  ₹499
# 96          AISLIN  Toughened Glass Lens, UV Protection Wayfarer, ...  ₹775
# 97  kingsunglasses  Mirrored, UV Protection Wayfarer Sunglasses (F...  ₹269
# 98          GANSTA  UV Protection, Gradient Clubmaster Sunglasses ...  ₹221
# 99          Fair-x              UV Protection Aviator Sunglasses (58)  ₹224
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone
#     1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb-includes- earpods-power- adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC TSVZAXUHGREPBFGI&marketplace')
time.sleep(2)

# %%
all_reviews=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div/div/div[5]/div/a/div/span')
all_reviews.click()

# %%
ratings=[]
review_desc=[]
review=[]

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
ratings_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="cfba37ad-794e-454d-8532-eeddf070f975")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="bf2507b8-f30e-4c4a-b46a-7129877865d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="00cba29d-d814-4e0f-8875-6bc95fcbdd9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="0c560b77-e62d-4e28-846c-f99a56f6e697")>]

# %%
for i in ratings_tags:
    title=i.text
    ratings.append(title)
ratings[0:4]
# Out:
# ['4.6', '5', '5', '5']

# %%
review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
review_desc_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="946a4632-fe3d-423c-b8a6-26c8899581b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="7a855de4-8133-48c5-a389-4e922d8b3b89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="90f5149b-f52a-49f8-bc34-dbeccd86b967")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="245067a1-89b6-42f6-ab07-b4773cd63ac4")>]

# %%
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)
review_desc[0:4]
# Out:
# ['Brilliant', 'Simply awesome', 'Best in the market!', 'Perfect product!']

# %%
review_tags=driver.find_elements_by_class_name('t-ZTKy')
review_tags[0:4]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="8e441b4f-b6d7-4d7d-99bd-d4d61c86ec55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="80e12cf5-b13c-4fc2-8e48-8d33afe9e88e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="f5a576ce-5898-4513-9af8-65018e091a20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0541c3bc7495d9a0a611fd0f893ec940", element="d72f2ec1-5f4e-425c-bccb-557358d73d5f")>]

# %%
for i in review_tags:
    title=i.text
    review.append(title)
review[0:4]
# Out:
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
#  'Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.',
#  'Great iPhone very snappy experience as apple kind. Upgraded from iPhone 7.\nPros\n-Camera top class\n- Battery top performed\n-Chipset no need to say as apple kind\n-Security as you expect from apple\n- Display super bright industry leading colour\naccuracy and super responsive\n-Build quality as expect from apple sturdy\npremium durable beautiful stylish.\n-Os most stable os in smartphone industry\n\nCons\n-No 5G\n-Display is not based on OLED technology\n-Charger headphones and 1 apple stic...\nREAD MORE',
# ...

# %%
next_button=driver.find_element_by_class_name('_1LKTO3')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[2]')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 33
# 30
# 30

# %%
ratings=ratings[0:30]

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 41
# 40
# 40

# %%
ratings=ratings[0:40]

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 51
# 50
# 50

# %%
ratings=ratings[0:50]

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 61
# 60
# 60

# %%
ratings=ratings[0:60]

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 71
# 70
# 70

# %%
ratings=ratings[0:70]

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 81
# 80
# 80

# %%
ratings=ratings[0:80]

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 91
# 90
# 90

# %%
ratings=ratings[0:90]

# %%
next_button=driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]/span')
next_button.click()

# %%
ratings_tags=driver.find_elements_by_class_name('_3LWZlK')
for i in ratings_tags:
    title=i.text
    ratings.append(title)

review_desc_tags=driver.find_elements_by_class_name('_2-N8zT')
for i in review_desc_tags:
    title=i.text
    review_desc.append(title)

review_tags=driver.find_elements_by_class_name('t-ZTKy')
for i in review_tags:
    title=i.text
    review.append(title)

# %%
print(len(ratings))
print(len(review_desc))
print(len(review))
# Out:
# 101
# 100
# 100

# %%
ratings=ratings[0:100]

# %%
ratings_df=pd.DataFrame()
ratings_df['Ratings']=ratings
ratings_df['Review_desc']=review_desc
ratings_df['review']=review

# %%
ratings_df
# Out:
#    Ratings          Review_desc  \
# 0      4.6            Brilliant
# 1        5       Simply awesome
# 2        5  Best in the market!
# 3        5     Perfect product!
# 4        5            Fabulous!
# ..     ...                  ...
# 95       5          Pretty good
# 96       4    Terrific purchase
# 97       5              Awesome
# 98       5       Classy product
# 99       5            Brilliant
#
#                                                review
# 0   The Best Phone for the Money\n\nThe iPhone 11 ...
# 1   Really satisfied with the Product I received.....
# 2   Great iPhone very snappy experience as apple k...
# 3   Amazing phone with great cameras and better ba...
# 4   This is my first iOS phone. I am very happy wi...
# ..                                                ...
# 95  I was using Iphone 6s and also Oneplus 6t. Bot...
# 96  Its Very awesome product working and good came...
# 97  I am using this phone for 5 days and its one o...
# ...

# %% [markdown]
# # Scrape data for first 100 sneakers you find when you visit flipkart.com andsearch for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')
time.sleep(2)

# %%
brand=[]
product_desc=[]
price=[]

# %%
search_field_designation=driver.find_element_by_class_name('_3704LK')
search_field_designation.send_keys("sneakers")

# %%
search_button=driver.find_element_by_class_name("_34RNph")
search_button.click()

# %%
brand_tags=driver.find_elements_by_class_name('_2WkVRV')
for i in brand_tags:
    title=i.text
    brand.append(title)

desc_tags=driver.find_elements_by_class_name('IRpwTa')
for i in desc_tags:
    title=i.text
    product_desc.append(title)
 
price_tags=driver.find_elements_by_class_name('_30jeq3')
for i in price_tags:
    title=i.text
    price.append(title)

# %%
next_button=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[2]")
next_button.click()

# %%
brand_tags=driver.find_elements_by_class_name('_2WkVRV')
for i in brand_tags:
    title=i.text
    brand.append(title)

desc_tags=driver.find_elements_by_class_name('IRpwTa')
for i in desc_tags:
    title=i.text
    product_desc.append(title)
 
price_tags=driver.find_elements_by_class_name('_30jeq3')
for i in price_tags:
    title=i.text
    price.append(title)

# %%
next_button=driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[4]")
next_button.click()

# %%
brand_tags=driver.find_elements_by_class_name('_2WkVRV')
for i in brand_tags:
    title=i.text
    brand.append(title)

desc_tags=driver.find_elements_by_class_name('IRpwTa')
for i in desc_tags:
    title=i.text
    product_desc.append(title)
 
price_tags=driver.find_elements_by_class_name('_30jeq3')
for i in price_tags:
    title=i.text
    price.append(title)

# %%
sneakers=pd.DataFrame()
sneakers['Brand']=brand[0:100]
sneakers['Product Description']=product_desc[0:100]
sneakers['Price']=price[0:100]

# %%
sneakers
# Out:
#          Brand                                Product Description Price
# 0     KWIK FIT  Kwik FIT casual sneaker shoes and partywear sh...  ₹399
# 1        SPARX                           Men 192 Sneakers For Men  ₹841
# 2   D-SNEAKERZ  Casual , Partywear Sneakers Shoes For Men's An...  ₹249
# 3       corsac        STYLISH MENS BLACK SNEAKER Sneakers For Men  ₹449
# 4     URBANBOX                          Sneakers Sneakers For Men  ₹158
# ..         ...                                                ...   ...
# 95       SPARX  Canvas Casual Partywear Outdoor Sneakers Shoes...  ₹714
# 96   Deals4you                                   Sneakers For Men  ₹376
# 97      Chevit  Unique & Perfect Collection Combo Pack of 02 S...  ₹449
# 98       BIRDE  Stylish Comfortable Lightweight, Breathable Ca...  ₹301
# 99       SPARX                            SM-322 Sneakers For Men  ₹841
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q7: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 7149 to Rs. 14099 ” , Color filter to “Black”, as shown inthe below image.
# And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get(' https://www.myntra.com/shoes')
time.sleep(2)

# %%
brand=[]
product_desc=[]
price=[]

# %%
price_button=driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")
price_button.click()

# %%
color_button=driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
color_button.click()

# %%
brand_tags=driver.find_elements_by_class_name('product-brand')
for i in brand_tags:
    title=i.text
    brand.append(title)

desc_tags=driver.find_elements_by_class_name('product-product')
for i in desc_tags:
    title=i.text
    product_desc.append(title)
 
price_tags=driver.find_elements_by_class_name('product-price')
for i in price_tags:
    title=i.text
    price.append(title)

# %%
next_button=driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[3]/a")
next_button.click()

# %%
brand_tags=driver.find_elements_by_class_name('product-brand')
for i in brand_tags:
    title=i.text
    brand.append(title)

desc_tags=driver.find_elements_by_class_name('product-product')
for i in desc_tags:
    title=i.text
    product_desc.append(title)
 
price_tags=driver.find_elements_by_class_name('product-price')
for i in price_tags:
    title=i.text
    price.append(title)

# %%
len(price)
# Out:
# 100

# %%
len(product_desc)
# Out:
# 100

# %%
len(brand)
# Out:
# 100

# %%
shoes=pd.DataFrame()
shoes['Brand']=brand[0:100]
shoes['Product Description']=product_desc[0:100]
shoes['Price']=price[0:100]

# %%
shoes
# Out:
#             Brand              Product Description  \
# 0        Skechers                Men Walking Shoes
# 1            ALDO        Men Leather Driving Shoes
# 2        Skechers       Men Max Cushioning Running
# 3          ADIDAS       Men Dropset Training Shoes
# 4            ALDO             Men Printed Sneakers
# ..            ...                              ...
# 95        Bugatti                Men Walking Shoes
# 96  Royal Enfield             Cabo WP Riding Boots
# 97          ASICS    Men Colourblocked PU Sneakers
# 98   Sole To Soul  Platform Peep Toes with Buckles
# 99           Nike     Men AIR MAX PRE-DAY Sneakers
#
#                           Price
# 0     Rs. 7649Rs. 8999(15% OFF)
# 1                     Rs. 12999
# 2     Rs. 7649Rs. 8999(15% OFF)
# 3                     Rs. 12999
# 4    Rs. 9099Rs. 12999(30% OFF)
# ..                          ...
# 95    Rs. 7199Rs. 8999(20% OFF)
# 96     Rs. 8075Rs. 8500(5% OFF)
# 97                     Rs. 9999
# ...

# %% [markdown]
# # Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” as shown in the below image
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')
time.sleep(2)

# %%
search_field_designation=driver.find_element_by_xpath('/html/body/div[2]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search_field_designation.send_keys("Laptops")

# %%
search_button=driver.find_element_by_xpath("/html/body/div[2]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search_button.click()

# %%
i7_button=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[4]/li[12]/span/a/div/label/i")
i7_button.click()

# %%
brand=[]
ratings=[]
price=[]

# %%
brand_tags=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in brand_tags:
    title=i.text
    brand.append(title)

ratings_tags=driver.find_elements_by_xpath('//li[@class="a-icon-row a-spacing-small a-padding-none"]/span[1]')
for i in ratings_tags:
    title=i.text
    ratings.append(title)
 
price_tags=driver.find_elements_by_class_name('a-price-whole')
for i in price_tags:
    title=i.text
    price.append(title)

# %%
i7_data=pd.DataFrame()
i7_data['Product']=brand[0:10]
i7_data['Price']=price[0:10]

# %%
i7_data
# Out:
#                                              Product     Price
# 0  Samsung Galaxy Book2 Pro 360 Intel 12th Gen i7...  1,29,990
# 1  Samsung Galaxy Book2 Pro Intel 12th Gen i7 Evo...  1,14,990
# 2  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...    57,490
# 3  ASUS TUF Gaming F15 (2021), 15.6-inch (39.62 c...    96,990
# 4  HP Pavilion 14, 11th Gen Intel Core i7-16GB RA...    86,990
# 5  Samsung Galaxy Book2 Pro Intel 12th Gen i7 Evo...  1,14,990
# 6  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    86,990
# 7  Acer Predator Helios 300 11th Gen Intel Core i...  1,69,990
# 8  Lenovo IdeaPad Gaming 3 Intel Core i7 10th Gen...    68,990
# 9  Fujitsu UH-X 11th Gen Intel i7 Core 13.3 inche...    89,990

# %%
i9_button=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[4]/li[13]/span/a/div/label/i")
i9_button.click()

# %%
brand_tags=driver.find_elements_by_xpath('//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
for i in brand_tags:
    title=i.text
    brand.append(title)

ratings_tags=driver.find_elements_by_xpath('//li[@class="a-icon-row a-spacing-small a-padding-none"]/span[1]')
for i in ratings_tags:
    title=i.text
    ratings.append(title)
 
price_tags=driver.find_elements_by_class_name('a-price-whole')
for i in price_tags:
    title=i.text
    price.append(title)

# %%
i9_data=pd.DataFrame()
i9_data['Product']=brand[10:20]
i9_data['Price']=price[10:20]

# %%
i9_data
# Out:
#                                              Product     Price
# 0  HP Pavilion 11th Gen Intel Core i7 Processor 1...    90,800
# 1  HP Pavilion Gaming 11th Gen Intel Core i7 15.6...    94,800
# 2  Dell 15 (2021) Inspiron 5518 Intel Thunderbolt...    94,800
# 3  HP Pavilion x360 11th Gen Intel Core i7 14 inc...  1,24,990
# 4  Dell 15 (2021) Inspiron 5518 Intel Thunderbolt...    44,930
# 5  Samsung Galaxy Book2 Pro Intel 12th Gen i7 Evo...  1,09,990
# 6  (Renewed) Dell Latitude E7470 Intel Core i7 6t...    86,990
# 7  Acer Nitro 5 Gaming Laptop/12th Gen Intel Core...    79,500
# 8  HP Pavilion x360 11th Gen Intel Core i7 14 inc...    91,699
# 9  Lenovo IdeaPad 5 Pro 11th Gen Intel Core i7 14...  1,03,000

# %% [markdown]
# # Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida
# location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.ambitionbox.com/')
time.sleep(2)

# %%
job_click=driver.find_element_by_xpath("/html/body/div[1]/nav/nav/a[6]")
job_click.click()

# %%
search_field_designation=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input')
search_field_designation.send_keys("Data Scientist")

# %%
search_button=driver.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button/span")
search_button.click()

# %%
location_button=driver.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[1]/p")
location_button.click()

# %%
location_select=driver.find_element_by_xpath("/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[5]/div/label")
location_select.click()

# %%
company=[]
n_day_ago=[]
com_rating=[]

# %%
company_tags=driver.find_elements_by_class_name('company-info')
for i in company_tags:
    title=i.text
    company.append(title)

day_tags=driver.find_elements_by_class_name("other-info")
for i in day_tags:
    title=i.text
    n_day_ago.append(title)
 
rating_tags=driver.find_elements_by_class_name('body-small')
for i in rating_tags:
    title=i.text
    com_rating.append(title)

# %%
company
# Out:
# ['GENPACT India Private Limited\n · \n4.0\nbased on 16.9k Reviews',
#  'GENPACT India Private Limited\n4.0\n(16.8k Reviews)',
#  'GENPACT India Private Limited\n4.0\n(16.8k Reviews)',
#  'Tech Mahindra Ltd\n3.7\n(17.2k Reviews)',
#  'GENPACT India Private Limited\n4.0\n(16.8k Reviews)',
#  'HCL Technologies\n3.8\n(18.1k Reviews)',
#  'Zyoin\n4.1\n(72 Reviews)',
#  'Newgen Software Technologies Ltd.\n3.5\n(490 Reviews)',
#  'Pitney Bowes India Pvt Ltd\n4.2\n(114 Reviews)',
#  'JK Technosoft Ltd\n3.6\n(301 Reviews)',
#  'Microsoft India (R and D) Pvt Ltd\n4.3\n(632 Reviews)']

# %%
com_name=[]
for i in company:
    com_name.append(i.split('\n'))

# %%
com_name
# Out:
# [['GENPACT India Private Limited', ' · ', '4.0', 'based on 16.9k Reviews'],
#  ['GENPACT India Private Limited', '4.0', '(16.8k Reviews)'],
#  ['GENPACT India Private Limited', '4.0', '(16.8k Reviews)'],
#  ['Tech Mahindra Ltd', '3.7', '(17.2k Reviews)'],
#  ['GENPACT India Private Limited', '4.0', '(16.8k Reviews)'],
#  ['HCL Technologies', '3.8', '(18.1k Reviews)'],
#  ['Zyoin', '4.1', '(72 Reviews)'],
#  ['Newgen Software Technologies Ltd.', '3.5', '(490 Reviews)'],
#  ['Pitney Bowes India Pvt Ltd', '4.2', '(114 Reviews)'],
#  ['JK Technosoft Ltd', '3.6', '(301 Reviews)'],
#  ['Microsoft India (R and D) Pvt Ltd', '4.3', '(632 Reviews)']]

# %%
company_final=[]
for i in com_name:
    company_final.append(i[0])

# %%
company_final
# Out:
# ['GENPACT India Private Limited',
#  'GENPACT India Private Limited',
#  'GENPACT India Private Limited',
#  'Tech Mahindra Ltd',
#  'GENPACT India Private Limited',
#  'HCL Technologies',
#  'Zyoin',
#  'Newgen Software Technologies Ltd.',
#  'Pitney Bowes India Pvt Ltd',
#  'JK Technosoft Ltd',
#  'Microsoft India (R and D) Pvt Ltd']

# %%
n_day_ago
# Out:
# ['7-10 Yrs\nNot Disclosed\nGurgaon/Gurugram, Noida\ndeep learning, nlp, Natural Language Processing +2 more\n1d ago·via naukri.com',
#  '7-12 Yrs\nNot Disclosed\nBengaluru/Bangalore, Hyderabad/Secunderabad, Gurgaon/Gurugram +1 more\ndeep learning, python, machine learning\n6d ago·via naukri.com',
#  '3-6 Yrs\nNot Disclosed\nNoida\nSAS, machine learning\n20d ago·via naukri.com',
#  '9-14 Yrs\nNot Disclosed\nGurgaon/Gurugram, Noida\nPredictive Modeling, R, python +4 more\n23d ago·via naukri.com',
#  '3-8 Yrs\nNot Disclosed\nDelhi NCR, Noida\nNLP, Artificial Intelligence, Natural Language Processing +4 more\n27d ago·via naukri.com',
#  '5-14 Yrs\nBengaluru/Bangalore, Noida\nData Scientist, Data Management, PhD +6 more\n5d ago·via hirist.com',
#  '0-2 Yrs\n₹ 3-5 LPA\nNoida\npython, nlp, Statistical Analyses +1 more\n7d ago·via naukri.com',
#  '6-10 Yrs\nNot Disclosed\nNoida\nQuest\n1mon ago·via naukri.com',
# ...

# %%
n_day_ago_new=[]
for i in n_day_ago:
    n_day_ago_new.append(i.split('\n'))

# %%
n_day_ago_new
# Out:
# [['7-10 Yrs',
#   'Not Disclosed',
#   'Gurgaon/Gurugram, Noida',
#   'deep learning, nlp, Natural Language Processing +2 more',
#   '1d ago·via naukri.com'],
#  ['7-12 Yrs',
#   'Not Disclosed',
#   'Bengaluru/Bangalore, Hyderabad/Secunderabad, Gurgaon/Gurugram +1 more',
#   'deep learning, python, machine learning',
#   '6d ago·via naukri.com'],
#  ['3-6 Yrs',
#   'Not Disclosed',
#   'Noida',
#   'SAS, machine learning',
#   '20d ago·via naukri.com'],
#  ['9-14 Yrs',
#   'Not Disclosed',
#   'Gurgaon/Gurugram, Noida',
#   'Predictive Modeling, R, python +4 more',
#   '23d ago·via naukri.com'],
#  ['3-8 Yrs',
#   'Not Disclosed',
#   'Delhi NCR, Noida',
#   'NLP, Artificial Intelligence, Natural Language Processing +4 more',
#   '27d ago·via naukri.com'],
#  ['5-14 Yrs',
#   'Bengaluru/Bangalore, Noida',
#   'Data Scientist, Data Management, PhD +6 more',
#   '5d ago·via hirist.com'],
#  ['0-2 Yrs',
#   '₹ 3-5 LPA',
#   'Noida',
#   'python, nlp, Statistical Analyses +1 more',
# ...

# %%
n_day_ago_new_1=[]
for i in n_day_ago_new:
    n_day_ago_new_1.append(i[-1])

# %%
n_day_ago_new_1
# Out:
# ['1d ago·via naukri.com',
#  '6d ago·via naukri.com',
#  '20d ago·via naukri.com',
#  '23d ago·via naukri.com',
#  '27d ago·via naukri.com',
#  '5d ago·via hirist.com',
#  '7d ago·via naukri.com',
#  '1mon ago·via naukri.com',
#  '16d ago·via naukri.com',
#  '2mon ago·via naukri.com']

# %%
n_day_final=[]
for i in n_day_ago_new_1:
    n_day_final.append(i.split('·via')[0])

# %%
n_day_final
# Out:
# ['1d ago',
#  '6d ago',
#  '20d ago',
#  '23d ago',
#  '27d ago',
#  '5d ago',
#  '7d ago',
#  '1mon ago',
#  '16d ago',
#  '2mon ago']

# %%
com_rating
# Out:
# ['4.0', '4.0', '3.7', '4.0', '3.8', '4.1', '3.5', '4.2', '3.6', '4.3']

# %%
ambi_job=pd.DataFrame()
ambi_job['company']=company_final[0:10]
ambi_job['number of days ago']=n_day_final
ambi_job['Ratings']=com_rating

# %%
ambi_job
# Out:
#                              company number of days ago Ratings
# 0      GENPACT India Private Limited             1d ago     4.0
# 1      GENPACT India Private Limited             6d ago     4.0
# 2      GENPACT India Private Limited            20d ago     3.7
# 3                  Tech Mahindra Ltd            23d ago     4.0
# 4      GENPACT India Private Limited            27d ago     3.8
# 5                   HCL Technologies             5d ago     4.1
# 6                              Zyoin             7d ago     3.5
# 7  Newgen Software Technologies Ltd.           1mon ago     4.2
# 8         Pitney Bowes India Pvt Ltd            16d ago     3.6
# 9                  JK Technosoft Ltd           2mon ago     4.3

# %% [markdown]
# # Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time

# %%
driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.ambitionbox.com/')
time.sleep(2)

# %%
salary_click=driver.find_element_by_xpath("/html/body/div[1]/nav/nav/a[4]")
salary_click.click()

# %%
search_field_designation=driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div/div/div/div[1]/span/input')
search_field_designation.send_keys("Data Scientist")

# %%
search_button=driver.find_element_by_xpath("/html/body/div/div/div/div[2]/div/div/div/button/span")
search_button.click()

# %%
link_button=driver.find_element_by_xpath("/html/body/section[1]/div/section/div/div/div/div/div/div/div[5]/div[2]/div/div/div[1]/div[1]/div[1]/div[1]/div/a")
link_button.click()

# %%
company_name=[]
number_of_salaries=[]
Avg_salary=[]
min_salary=[]
max_salary=[]

# %%
company_tags=driver.find_elements_by_class_name('averageCtc')
for i in company_tags:
    title=i.text
    company_name.append(title)

 
avg_salary=driver.find_elements_by_xpath("/html/body/div/div/div/div[2]/div[3]/div[3]/div[1]/div[6]/div[2]/div[2]")
for i in avg_salary:
    title=i.text
    Avg_salary.append(title)
    
min_salary_=driver.find_elements_by_xpath("/html/body/div/div/div/div[2]/div[3]/div[3]/div[1]/div[6]/div[2]/div[2]/div[3]/div[2]")
for i in min_salary_:
    title=i.text
    min_salary.append(title)
    
max_salary_=driver.find_elements_by_xpath("/html/body/div/div/div/div[2]/div[3]/div[3]/div[1]/div[6]/div[2]/div[2]/div[2]")
for i in max_salary_:
    title=i.text
    max_salary.append(title)

# %%
company_name
# Out:
# []

# %%
Avg_salary
# Out:
# []

# %%
min_salary
# Out:
# []

# %%
max_salary
# Out:
# []
