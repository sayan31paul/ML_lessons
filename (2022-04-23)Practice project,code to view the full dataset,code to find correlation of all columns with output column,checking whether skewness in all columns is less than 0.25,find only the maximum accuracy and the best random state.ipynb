# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('sonar.csv')
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
pd.set_option('display.max_rows',None) # This code forces pandas to show all rows

# %%
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 5    0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 6    0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 7    0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 8    0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 9    0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# 10   0.0123  0.0309  0.0169  0.0313  0.0358  0.0102  0.0182  0.0579  0.1122
# ...

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
df.isnull().sum()
# Out:
# 0.0200    0
# 0.0371    0
# 0.0428    0
# 0.0207    0
# 0.0954    0
# 0.0986    0
# 0.1539    0
# 0.1601    0
# 0.3109    0
# 0.2111    0
# 0.1609    0
# 0.1582    0
# 0.2238    0
# 0.0645    0
# 0.0660    0
# 0.2273    0
# 0.3100    0
# 0.2999    0
# 0.5078    0
# 0.4797    0
# 0.5783    0
# 0.5071    0
# 0.4328    0
# 0.5550    0
# 0.6711    0
# 0.6415    0
# 0.7104    0
# 0.8080    0
# 0.6791    0
# 0.3857    0
# 0.1307    0
# 0.2604    0
# 0.5121    0
# 0.7547    0
# 0.8537    0
# 0.8507    0
# 0.6692    0
# 0.6097    0
# 0.4943    0
# 0.2744    0
# 0.0510    0
# 0.2834    0
# 0.2825    0
# 0.4256    0
# 0.2641    0
# 0.1386    0
# 0.1051    0
# 0.1343    0
# 0.0383    0
# 0.0324    0
# 0.0232    0
# 0.0027    0
# 0.0065    0
# 0.0159    0
# 0.0072    0
# 0.0167    0
# 0.0180    0
# 0.0084    0
# 0.0090    0
# 0.0032    0
# R         0
# dtype: int64

# %%
pd.set_option('display.max_columns',500) #show max 500 columns

# %%
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 5    0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 6    0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 7    0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 8    0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 9    0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# 10   0.0123  0.0309  0.0169  0.0313  0.0358  0.0102  0.0182  0.0579  0.1122
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='count'>

# %%
df['R'].value_counts()
# Out:
# M    111
# R     96
# Name: R, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['R']=lb.fit_transform(df['R'])

# %%
df.corr()
# Out:
#           0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# 0.0200  1.000000  0.736104  0.571706  0.490853  0.345744  0.238824  0.262095
# 0.0371  0.736104  1.000000  0.779915  0.607297  0.419877  0.332319  0.279328
# 0.0428  0.571706  0.779915  1.000000  0.782662  0.546365  0.346271  0.190628
# 0.0207  0.490853  0.607297  0.782662  1.000000  0.729338  0.352901  0.248713
# 0.0954  0.345744  0.419877  0.546365  0.729338  1.000000  0.597438  0.334831
# 0.0986  0.238824  0.332319  0.346271  0.352901  0.597438  1.000000  0.703624
# 0.1539  0.262095  0.279328  0.190628  0.248713  0.334831  0.703624  1.000000
# 0.1601  0.356312  0.334747  0.237974  0.248131  0.203590  0.471942  0.675612
# 0.3109  0.356822  0.317929  0.253615  0.252048  0.176522  0.329145  0.469490
# 0.2111  0.318440  0.270787  0.219641  0.238136  0.183240  0.288639  0.425675
# 0.1609  0.343362  0.297186  0.274751  0.270466  0.232939  0.333560  0.398590
# ...

# %%
plt.figure(figsize=[40,40])
sns.heatmap(df.corr(),annot=False)
plt.show()

# %% [raw]
# We are unable to identify the correlation in above heatmap due to large number of columns. Let's print the correlation values of independent variables with the target variable in sorted form

# %%
corr_matrix=df.corr()
corr_matrix['R'].sort_values(ascending=False)
# Out:
# R         1.000000
# 0.8507    0.262727
# 0.8537    0.220761
# 0.6692    0.203826
# 0.7547    0.165523
# 0.1307    0.121008
# 0.5121    0.105149
# 0.2604    0.059882
# 0.2744    0.037101
# 0.6097    0.034187
# 0.3100    0.006070
# 0.3857    0.000364
# 0.2273   -0.008246
# 0.0180   -0.010152
# 0.2999   -0.011635
# 0.0510   -0.013833
# 0.6711   -0.025284
# 0.6415   -0.026867
# 0.6791   -0.037543
# 0.0660   -0.051240
# 0.7104   -0.055324
# 0.4943   -0.061572
# 0.5550   -0.071733
# 0.8080   -0.085259
# 0.0032   -0.086982
# 0.0072   -0.094392
# 0.1539   -0.117848
# 0.4328   -0.123539
# 0.0090   -0.132088
# 0.0986   -0.132172
# 0.0167   -0.138112
# 0.5078   -0.138648
# 0.0065   -0.139288
# 0.2834   -0.144705
# 0.0645   -0.151116
# 0.0084   -0.185066
# 0.0324   -0.185623
# 0.0159   -0.186932
# 0.1601   -0.191424
# 0.0428   -0.192589
# 0.5071   -0.199643
# 0.4797   -0.223143
# 0.0954   -0.224809
# 0.0371   -0.231670
# 0.2825   -0.236109
# 0.5783   -0.242818
# 0.0207   -0.247935
# ...

# %% [markdown]
# # Lets check the normal distribution among the columns

# %%
#df.plot(kind='density',subplots=True,layout=(10,7),figsize=(20,30),color='green')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0e9d6d546332> in <module>
# ----> 1 df.plot(kind='density',subplots=True,layout=(10,6),figsize=(20,30),color='green')
#       2 plt.show()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

# %%
#checking skewness
x.skew().sort_values(ascending=False)

#If skewness lies between -0.5 to +0.5 , then it is considered to be normal distribution

# %%
from sklearn.preprocessing import power_transform #power_transform reduces skewness
x_new=power_transform(x)

# %%
x_new

# %% [raw]
# power_transform converts the dataframe to array.
# Hence we need to convert it to DataFarme again

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x

# %%
x.skew().sort_values(ascending=False)

#skewness is reduced

# %%
#lets check whether the skewness lies between -0.25 to +0.25
x.skew()[np.abs(x.skew())<0.25].all()

# %% [raw]
# Skewness has been removed. Now we can move with further steps

# %% [markdown]
# # Checking Outliers

# %%
x.plot(kind='box',subplots=True,layout=(10,6),figsize=(20,30),color='green')
plt.show()

# %%
from scipy.stats import zscore
(np.abs(zscore(x))<3).all()

#no outliers are present in my data

# %% [markdown]
# # Training process begins

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Best Random State

# %%
maxAccu=0#maximum accuracy
maxRS=0 # best random_state for which maximum accuracy is acheived

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train,y_train)
    y_pred=LR.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i

print(maxAccu)
print(maxRS)

# %% [markdown]
# ### Creating train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=28)
LR=LogisticRegression()
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("Accuracy:",acc)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# # Decision Tree Classifier

# %%
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    LR=DecisionTreeClassifier()
    LR.fit(x_train,y_train)
    y_pred=LR.predict(x_test)
    acc=accuracy_score(y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        
print(maxAccu)
print(maxRS)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=28)
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
y_pred=dtc.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("Accuracy:",acc)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=28)
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("Accuracy:",acc)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=28)
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("Accuracy:",acc)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

scr=cross_val_score(LR, x,y,cv=5)
print(scr)
print(scr.mean())

# %%
scr=cross_val_score(dtc, x,y,cv=5)
print(scr)
print(scr.mean())

# %%
scr=cross_val_score(svc, x,y,cv=5)
print(scr)
print(scr.mean())

# %%
scr=cross_val_score(rfc, x,y,cv=5)
print(scr)
print(scr.mean())

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters={'max_features':['auto','sqrt','log2'],'max_depth':[4,5,6,7,8],'criterion':['gini','entropy']}
GCV=GridSearchCV(rfc,parameters,cv=5,scoring='accuracy')
GCV.fit(x_train,y_train)
GCV.best_params_

# %% [markdown]
# # Final model training

# %%
rfc=RandomForestClassifier(criterion='gini', max_depth= 8, max_features= 'log2')
rfc.fit(x_train,y_train)
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("Accuracy:",acc)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))

# %% [markdown]
# # ROC AUC Plot

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(rfc,x_test,y_test)
plt.show()

# %%
df.columns
