# %% [raw]
# Inferential statistics involves hypothesis testing.
# Hypothesis testing involves t-Test, Chi-square test, corelational test,ANOVA Test.

# %%
from scipy.stats import zscore
import pandas as pd
import numpy as np

# %%
zscore([56,34,45,23,10])
# Out:
# array([ 1.38854831,  0.02479551,  0.70667191, -0.6570809 , -1.46293482])

# %%
df=pd.read_csv('student_marks.csv')
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df=df.iloc[:,3:]
df
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History  Civics
# 0     55       45         56       87       21         52       89      65
# 1     75       96         78       64       90         61       58       2
# 2     25       54         89       76       95         87       56      74
# 3     78       96         86       63       54         89       75      45
# 4     58       96         78       46       96         77       83      53
# 5     45       87         52       89       55         89       87      52
# 6     55       64         61       58       75         58       64      61
# 7     54       76         87       56       25         56       76      87
# 8     55       63         89       75       78         75       63      89
# 9     96       46         77       83       58         83       46      77

# %% [raw]
# The central limit theorem states that the distribution of the sample means approximates a normal distribution as the sample size grows larger irrespective of the distribution of the population.
# The means of all samples of the population will be approximately equal to the mean of the population.
# Variance of all samples are approximately equal to the variance of the population.

# %% [raw]
# Hypothesis testing is an objective method of making inferences and desicions from sample data.
#
# Two types of hypothesis are null hypothesis and alternate hypothesis.

# %% [raw]
# pvalue>0.05 Then null hypothesis is accepted
# pvalue>0.05 then null hypothesis is accepted.
# pvalue>0.05 then null hypothesis is accepted.
# pvalue>0.05 then null hypothesis is accepted
# pvalue>0.05 then null hypothesis is accepted
# pvalue>0.05 then null hypothesis is accepted
# pvalue>0.05 then null hypothesis is accepted

# %% [raw]
# Two sample TTest compare the mean of two samples. If the means of two samples are indentical.then null hypothesis is accepted.
# One saple TTest compares the mean with a given value. If the means of the sample and the given value are equal,then null hypothesis is accepted.

# %%
data=pd.read_csv('brain_size.csv',sep=';',na_values=".")
data

#NaN values are reperesented by '.' which is not the deafualt representattion.
# Out:
#     id  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0    1  Female   133  132  124   118.0    64.5     816932
# 1    2    Male   140  150  124     NaN    72.5    1001121
# 2    3    Male   139  123  150   143.0    73.3    1038437
# 3    4    Male   133  129  128   172.0    68.8     965353
# 4    5  Female   137  132  134   147.0    65.0     951545
# 5    6  Female    99   90  110   146.0    69.0     928799
# 6    7  Female   138  136  131   138.0    64.5     991305
# 7    8  Female    92   90   98   175.0    66.0     854258
# 8    9    Male    89   93   84   134.0    66.3     904858
# 9   10    Male   133  114  147   172.0    68.8     955466
# 10  11  Female   132  129  124   118.0    64.5     833868
# 11  12    Male   141  150  128   151.0    70.0    1079549
# 12  13    Male   135  129  124   155.0    69.0     924059
# 13  14  Female   140  120  147   155.0    70.5     856472
# 14  15  Female    96  100   90   146.0    66.0     878897
# ...

# %%
import scipy.stats as stats

# %%
stats.ttest_1samp(data['PIQ'],106)
# Out:
# Ttest_1sampResult(statistic=1.4143037747013467, pvalue=0.16520690047123543)

# %%
stats.ttest_1samp(data['FSIQ'],106)
# Out:
# Ttest_1sampResult(statistic=1.9565566733141344, pvalue=0.05758723382384275)

# %%
np.mean(data['FSIQ']) #using numpy
# Out:
# 113.45

# %%
data['FSIQ'].mean()   #using pandas
# Out:
# 113.45

# %% [raw]
# Corelation coefficient R lies between -1 to +1
# Corelation coefficient R lies between -1 to +1
# Corelation coefficient R lies between -1 to +1
# Corelation coefficient R lies between -1 to +1
# Corealtion coefficient R lies between -1 to +1
# Corelation coefficient R lies between -1 to +1

# %%
dfcorr=data.corr()
dfcorr
# Out:
#                  id      FSIQ       VIQ       PIQ    Weight    Height  \
# id         1.000000 -0.334072 -0.241473 -0.371150  0.174359  0.123775
# FSIQ      -0.334072  1.000000  0.946639  0.934125 -0.051483 -0.086002
# VIQ       -0.241473  0.946639  1.000000  0.778135 -0.076088 -0.071068
# PIQ       -0.371150  0.934125  0.778135  1.000000  0.002512 -0.076723
# Weight     0.174359 -0.051483 -0.076088  0.002512  1.000000  0.699614
# Height     0.123775 -0.086002 -0.071068 -0.076723  0.699614  1.000000
# MRI_Count -0.139724  0.357641  0.337478  0.386817  0.513378  0.601712
#
#            MRI_Count
# id         -0.139724
# FSIQ        0.357641
# VIQ         0.337478
# PIQ         0.386817
# Weight      0.513378
# Height      0.601712
# MRI_Count   1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(dfcorr)
# Out:
# <AxesSubplot:>

# %%
ds=pd.read_csv('role_website.csv')
ds
# Out:
#        role   website
# 0   teacher  linkedin
# 1   teacher  linkedin
# 2   student  facebook
# 3   student  facebook
# 4   teacher  linkedin
# 5   student  facebook
# 6   student  facebook
# 7   teacher  linkedin
# 8   teacher  linkedin
# 9   teacher  facebook
# 10  teacher  facebook
# 11  teacher  facebook
# 12  teacher  facebook
# 13  student  facebook
# 14  student  linkedin
# 15  student  facebook
# 16  teacher  linkedin
# 17  student  linkedin
# 18  student  facebook
# 19  student  facebook
# 20  student  linkedin
# 21  teacher  facebook
# 22  teacher  linkedin
# 23  teacher  linkedin
# 24  teacher  linkedin
# 25  teacher  linkedin
# 26  teacher  linkedin
# 27  teacher  facebook
# 28  teacher  linkedin
# 29  teacher  linkedin
# 30  teacher  linkedin
# 31  teacher  linkedin
# 32  student  facebook
# 33  student  facebook

# %%
ds.describe()
# Out:
#            role   website
# count        34        34
# unique        2         2
# top     teacher  linkedin
# freq         21        18

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   role     34 non-null     object
#  1   website  34 non-null     object
# dtypes: object(2)
# memory usage: 672.0+ bytes

# %%
ds.dtypes
# Out:
# role       object
# website    object
# dtype: object

# %%
#create contingency table
df_crosstab=pd.crosstab(ds['role'],ds['website'],margins=True)

# %%
df_crosstab.columns=['facebbok','linkedin','row_totals']
df_crosstab.index=['student','teacher','col_totals']
df_crosstab
# Out:
#             facebbok  linkedin  row_totals
# student           10         3          13
# teacher            6        15          21
# col_totals        16        18          34

# %%
observed=df_crosstab.iloc[0:2,0:2]
observed
# Out:
#          facebbok  linkedin
# student        10         3
# teacher         6        15

# %%
stats.chi2_contingency(observed=observed)
# Out:
# (5.718991656491658,
#  0.01678236577734386,
#  1,
#  array([[ 6.11764706,  6.88235294],
#         [ 9.88235294, 11.11764706]]))

# %%
chi2,p,dof,expected=stats.chi2_contingency(observed=observed)

print('Chi Square Test:',chi2)
print('p-value:',p)
print('dof:',dof)
print('Expected:',expected)
# Out:
# Chi Square Test: 5.718991656491658
# p-value: 0.01678236577734386
# dof: 1
# Expected: [[ 6.11764706  6.88235294]
#  [ 9.88235294 11.11764706]]
