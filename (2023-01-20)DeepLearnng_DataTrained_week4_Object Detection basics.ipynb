# %% [raw]
# In classification the model tells us whether the image is a cat or a dog but it doesnot tells us where exactly in the image a particular object is.
#
# The exact location of the object is given by object detection. Object detection gives us a boundary box. It tells us exactly where the object is.

# %% [markdown]
# ![Screenshot%20%28472%29.png](attachment:Screenshot%20%28472%29.png)

# %% [raw]
# LOcalisation- Where exactly the object lies in the image. If we localise it, then it is known as object detection.

# %% [raw]
# MSCOCO dataset- Used mainly for detection. Microsoft common object context dataset.
# It has 80 classes and some 300000 images. Each image can has upto 5 classes.

# %% [markdown]
# ![Screenshot%20%28473%29.png](attachment:Screenshot%20%28473%29.png)

# %% [markdown]
# ![Screenshot%20%28474%29.png](attachment:Screenshot%20%28474%29.png)

# %% [raw]
# MAP- Mean average precision. This is one of the most used scores for object detection.

# %% [raw]
# Precison= TP/(TP+FP)
#
# Recall= TP/(TP+FN)

# %% [raw]
# IOU-> Intersection over union.
#
# IoU= Area of overlap/Area of union.
#
# IoU helps us to know, how different our predicted value is from the actual value.
# If IoU is high, then the predicted boxes are very close to actual boxes.
#
# Set a threshold IOU. Let our threshold be 0.5 . If the IOU is greater than or equal to 0.5, then we will consider it as true positive.

# %% [markdown]
# ![Screenshot%20%28475%29.png](attachment:Screenshot%20%28475%29.png)

# %% [markdown]
# ![Screenshot%20%28476%29.png](attachment:Screenshot%20%28476%29.png)

# %% [raw]
# Confidence value- How confident the boundary box is about a particular object. For every boundary box , we will get a confidence value.
# In softmax classification, we get the probability for each class. The probability can be considered as confidence value.
#
# IoU is not related to confidence.

# %% [raw]
# 1.All boundary boxes are sorted from most confident to least confident.
#
# 2.Calculate the IoU for the sorted boundary boxes.

# %% [raw]
# Precision interpolated-> For two similar recalls take the highest precision.

# %% [markdown]
# ![Screenshot%20%28478%29.png](attachment:Screenshot%20%28478%29.png)

# %% [raw]
# Eleven point precision-> This is used to find our average precision.
#
# We devide our recall from 0 to 1.(divided into 11 points)
# Plot the precision interpolation with the recall.
#
# For each classes, find the average interpolated precision from the graph.
#
# Find the mean of the average interpolated precisions.

# %% [markdown]
# ![Screenshot%20%28479%29.png](attachment:Screenshot%20%28479%29.png)

# %% [raw]
# If the IoU changes, the true positives change, the false positives changes, the graph changes, the MAP value changes.

# %% [raw]
# MAP in MSCOCO dataset- MAP varies from 0.5 to 0.95 and iy keeps increasing by 0.05 .
