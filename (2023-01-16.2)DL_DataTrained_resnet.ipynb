# %% [markdown]
# ![Screenshot%20%28450%29.png](attachment:Screenshot%20%28450%29.png)

# %% [raw]
# After a certain extent accuarcy is not increasing with increase in the number of layers. One of the reasons is overfitting.
# Other reasons for the above issue are as follows:-
# 1. Network Degradation.
# 2.

# %% [raw]
# Network degradation happens due to gradient explosion or vanishing gradient problem.
# The skip connection acts as a regularizer. While back-propagation(chain diferentiation), we will be skipping those layers which are not contributing much to the accuracy of the network.

# %% [markdown]
# ![Screenshot%20%28452%29.png](attachment:Screenshot%20%28452%29.png)

# %% [raw]
# In F(x)+x , If F(x) is not very important, it will technically be very little. So our main focus will be on x.
#
# Note that the addition is occuring first, then it is being followed by a Relu.

# %% [markdown]
# ![Screenshot%20%28453%29.png](attachment:Screenshot%20%28453%29.png)
