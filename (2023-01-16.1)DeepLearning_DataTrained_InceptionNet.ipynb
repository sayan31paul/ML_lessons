# %% [raw]
# In AlexNet and VGGNet as we increased the number of layers we still had the problem of more parameters which increased the chance of overfitting. InceptionNet was very much optimised and it reduced the trainable parameters a lot. The main idea on inception net is for going deeper we try to go wider as well.

# %% [raw]
# Let us consider a image that has a human figure. If the kernel size is large then we can capture large features like legs.
# If the kernel size is small then we can capture smaller features like eyes.

# %% [raw]
# Inception net has 9 inception modules. It has 22 layers and 5 max pooling layers. It was designed by google.

# %% [raw]
# 1*1 kernels reduce the number of trainable parameters by a huge amount while increasing the depth of the network. Hence it reduces overfitting while increasing the acuracy.

# %% [markdown]
# ![Screenshot%20%28444%29.png](attachment:Screenshot%20%28444%29.png)

# %% [markdown]
# ![Screenshot%20%28446%29.png](attachment:Screenshot%20%28446%29.png)

# %% [markdown]
# ![Screenshot%20%28447%29.png](attachment:Screenshot%20%28447%29.png)

# %% [raw]
# Since this model focuses on going deeper as well as going wider, we can also call this as sparse convolution.

# %% [markdown]
# ![Screenshot%20%28449%29.png](attachment:Screenshot%20%28449%29.png)
