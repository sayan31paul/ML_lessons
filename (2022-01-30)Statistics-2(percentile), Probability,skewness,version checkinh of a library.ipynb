# %% [markdown]
# # Percentile

# %% [raw]
# *In statistics, Percentile is used to indicate the value below which the group of percentage of the data falls. For example, consider if your score is 75 percentile, then 75% of the people who took part in the test have scored below you.
#
# *Median of the dataset is the 50 th percentile
#
# *It is commonly applicable in indicating the scores from the norm referenced tests such as SAT, GRE, LSAT

# %% [markdown]
# Percentile example 1

# %% [raw]
# Learn how to calculate percentile for the given example:
# There are 25 test scores such as:
# 72,54,56,61,62,66,68,43,69,69,70,71,77,78,79,85,87,88,89,93,95,96,98,99,99.
# Find the 60th percentile?
#
#
# Solution:
# Step 1: Arrange the data in the ascending order.
# Ascending order= 43,54,56,61,62,66,68,69,69,70,71,72,77,78,79,85,87,88,89,93,95,96,98,99,99.
# There are 25 values in the dataset.
#
# Step 2: Now finding 60% of the total number of values in the dataset.
# (60/100)*25=15
#
# From the dataset 15th number is 79.
# Now take the 15 th number and 16 th number and find the average.
#
# (79+85)/2 = 82
#
# Hence, 60th percentile of the given dataset is 82.

# %%
import numpy as np

# %%
a=np.array([1,3,3,4,5,6,6,7,8,8])
np.percentile(a,100)
# Out:
# 8.0

# %%
np.percentile(a,50)
# Out:
# 5.5

# %%
np.percentile(a,25)
# Out:
# 3.25

# %%
import pandas as pd

# %%
data=pd.read_csv("president_heights.csv")
data
# Out:
#     order                    name  height
# 0       1       George Washington     189
# 1       2              John Adams     170
# 2       3        Thomas Jefferson     189
# 3       4           James Madison     163
# 4       5            James Monroe     183
# 5       6       John Quincy Adams     171
# 6       7          Andrew Jackson     185
# 7       8        Martin Van Buren     168
# 8       9  William Henry Harrison     173
# 9      10              John Tyler     183
# 10     11           James K. Polk     173
# 11     12          Zachary Taylor     173
# 12     13        Millard Fillmore     175
# 13     14         Franklin Pierce     178
# 14     15          James Buchanan     183
# 15     16         Abraham Lincoln     193
# 16     17          Andrew Johnson     178
# 17     18        Ulysses S. Grant     173
# 18     19     Rutherford B. Hayes     174
# 19     20       James A. Garfield     183
# 20     21       Chester A. Arthur     183
# ...

# %%
heights=data["height"]

# %%
print("25th percentile:",np.percentile(heights,25))
print("Median:", np.median(heights))
print("50th percentile:",np.percentile(heights,50)) #50th percentile is same as the median of the data.
print("75th percentile:",np.percentile(heights,75))
# Out:
# 25th percentile: 174.25
# Median: 182.0
# 50th percentile: 182.0
# 75th percentile: 183.0

# %% [markdown]
# # Scipy library

# %% [raw]
# Scipy= Scientific pyhton
# This library contains several packages which are related with mathematics, physics, different engineering branches.
# *Stats package in Scipy library will be used for statistics.
# *Mode function is not present in numpy but it is present in scipy library.

# %%
import scipy
import warnings
warnings.filterwarnings("ignore")

# %%
#cheching version of a package
scipy.__version__
# Out:
# '1.6.2'

# %%
a=np.array([[3,7,5],[8,4,3],[2,4,9]])

# %%
a
# Out:
# array([[3, 7, 5],
#        [8, 4, 3],
#        [2, 4, 9]])

# %%
print(scipy.mean(a))
# Out:
# 5.0

# %%
print(scipy.median(a))
# Out:
# 4.0

# %%
print(round(scipy.var(a),2)) #round off to two digits after decimal.
# Out:
# 5.33

# %%
print(round(scipy.std(a),2))
# Out:
# 2.31

# %%
a
# Out:
# array([[3, 7, 5],
#        [8, 4, 3],
#        [2, 4, 9]])

# %%
#st.mode

# %% [raw]
# Mode function is present inside scipy library.
# Mode function is present inside scipy library.
# Mode function is present inside scipy library.
# Mode function is present inside scipy library.
# Mode function is present inside scipy library.
# Mode function is present inside scipy library.
# Mode function is present insdie scipy library.

# %%
import scipy.stats as st  #mode cannot be calculate without importing scipy.stats. scipy alone is not sufficient.
import pandas as pd
import numpy as np
b=np.array([[1,3,4,2,2,7],[5,2,2,1,4,1],[3,3,2,2,1,1]])
b
# Out:
# array([[1, 3, 4, 2, 2, 7],
#        [5, 2, 2, 1, 4, 1],
#        [3, 3, 2, 2, 1, 1]])

# %%
m=st.mode(b)
m
# Out:
# ModeResult(mode=array([[1, 3, 2, 2, 1, 1]]), count=array([[1, 2, 2, 2, 1, 2]]))

# %%
df=pd.read_csv("studentmarks.csv")
df
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
#25% , 50%, 75% are the percentiles.

# %%
np.mean(df['Maths'])
# Out:
# 59.6

# %%
df['Maths'].mean()
# Out:
# 59.6

# %%
df['English'].mean()
# Out:
# 69.7

# %%
df['Chemistry'].mean()
# Out:
# 75.3

# %%
df['Maths'].median()
# Out:
# 55.0

# %%
df['Maths'].mode()
# Out:
# 0    55
# dtype: int64

# %% [raw]
# Mode is present in pandas too
# Mode is present in pandas too
# Mode is present in pandas too
# Mode is present in pandas too
# Mode is present in pandas too
# Mode is present in pandas too
# Mode is present in pandas too

# %%
st.mode(df['Maths'])
# Out:
# ModeResult(mode=array([55], dtype=int64), count=array([3]))

# %%
st.mode(df['Physics'])
# Out:
# ModeResult(mode=array([96], dtype=int64), count=array([3]))

# %%
#scipy.stats can also be used to find percentile
from scipy.stats import percentileofscore as percentile

# %%
percentileofscore(df['Maths'],25)
# Out:
# 10.0

# %%
percentile(df['Maths'],30)
# Out:
# 10.0

# %%
percentileofscore(df['English'],75)
# Out:
# 60.0

# %%
percentileofscore(df['Biology'],60)
# Out:
# 50.0

# %%
max_m=df['Maths'].max()
max_m
# Out:
# 96

# %%
min_m=df["Maths"].min()
min_m
# Out:
# 25

# %%
np.min(df['Maths'])
# Out:
# 25

# %%
range=max_m-min_m
range
# Out:
# 71

# %% [markdown]
# # Spread of data

# %% [raw]
# Q1(25th percentile),
# Q2(50th percentile)(meadian),
# Q3(75th percentile)
# IQR= Inter Quartile Range= Q3-Q1

# %%
#50th percentile is the median

# %%
q1=df['Maths'].quantile(0.25) #Here we are using pandas to find percentile
q3=df['Maths'].quantile(0.75) #Here we are using pandas to find percentile.
IQR=q3-q1

# %%
IQR
# Out:
# 16.5

# %% [markdown]
# # PROBABILITY

# %% [raw]
# In real-life situations what the probabilites are of certain event occuring,such as winning the lottery, the victory of your soccer team or a discount on your favourite pair of shoes. Determining the chances of an event occuring is known as probability.
#
# Probability is a measure of uncertainty of various phenomena.
#
# Probability is mainly concerned with predicting the likelyhood of future events.

# %% [markdown]
# Binomial theorem

# %% [raw]
# Only two events will be there.
#
# yes or no, 0 or 1, success or failure.
#
# The events are dependent events.(If tail comes in toss, then head will not come)
#
# Binomial is a discrete distribution.

# %% [markdown]
# Poisson probability or distribution

# %% [raw]
# The events here are independent events.
#
# Ex- How many people are visiting the mall on a particular day of the week.
# The number of people visiting a mall on a particular day is independent of the number of people visiting on another day.
#
# Poisson distribution is also a discrete distribution.

# %% [raw]
# What is a random variable?
#
# Ans- Suppose we flip a fair coin 3 times and record if it shows a head or tail.
# The outcome or sample space is S=[HHH,HHT,HTH,THH,TTH,THT,HTT,TTT]. There are 8 possible outcomes and each of the outcomes is equally likely. Instead of considering all possible outcomes, we cab consider asigning the variable X to the number of heads in 3 flips of a  fair coin. Then X can take the possible values of 0,1,2,3. By defining the variable X we have created a random variable.
#
# A random variable is a variable that takes on different values determined by chance. In other words it is a numerical quantity that varies at random.
#
# Random variables are of two types:-
# 1. Discrete random variable.   2. Continuous random variable.
#
# Discrete random variable:- When random variable can assume only integers.
#
# Continuous random variable:- When random variables can assume an uncountable number of values on the line interval.

# %% [markdown]
# # Probability Functions

# %% [raw]
# Probability mass function(PMF):-
# If the random variable is a discrete random variable, the probability function is usually called the probability mass function.
#
# Probability density function(PDF):-
# If the random variable is a continuous random variable, the probability function is usually called the probability density function.

# %% [markdown]
# # Independent and dependent events

# %% [raw]
# Idependent events are events that donot impact the occurance of other events.
# Ex- 3 persons are applying for 2 vacancy.
# Ex- Three coins are tossed. The first two coins are head. The third coin can be either head or tail. The result of the third toss is independent of the previous two tosses.
#
# Dependent events have an impact on the occurance of other events.
# Ex- 3 persons are applying for 1 vacancy.

# %% [markdown]
# # Types of distribution

# %% [raw]
# 1. Discrete data- Binomial distribution, Poisson distribution, Enponential distribution.
#    Ex- 3 coins tossed. Probabilty of 0,1,2,3 heads.
#
# 2. Continuous data:-  Normal distribution, Gaussian distribution.
#    Ex- the amount of rainfall in cm in a year in a city.
#        the weight of a newborn baby.
#        the height of a randomly selected student.

# %% [markdown]
# ![C1.PNG](attachment:C1.PNG)

# %% [raw]
# * It is a normal distribution only when mean=meadian=mode
#
# * For ideal normal distribution, mean=median=mode=0 and std deviation= (+-)1

# %% [markdown]
# # Types of Probability Distributions

# %% [raw]
# The binomial distribution evlautes the probability of an event occuring several times over a given number of trails and gives the events probability in each trial.
# Ex- Use a fair coin and figuring the probability of that coin coming up heads in 10 staright flips. A binomial distribution is discrete since only 1 or 0 is a valid response.
#
#
# The normal distribution is fully characterized by its mean and standard deviation. This makes the distribution symetric and is depicted as a bell shaped curve when plotted. A normal distribution is defined by a mean of zero and a standard deviation of (+-)1.0
# In a normal distribution, approximately 68% of the data collected will fall within +/- one standard deviation of the mean, approximately 95% will fall within +/- of two standard deviation, and 99.7% will fall within +/- of 3 standard deviations.

# %% [markdown]
# ![empirical_rule.png](attachment:empirical_rule.png)

# %% [markdown]
# # Three Sigma rule/ Empirical rule 68-95-99.7

# %% [raw]
# It is expression of how many of our observation will fall within certain distance from the mean. The standard devaition(a.k.a sigma) is the average diatance an obseravtion in the dataset is away from the mean.
#
# The three sigma rule dictates that given a normal distribution 68% of your observations will fall within one standard deviation from the mean. 95% of the observation will fall within two standard deviation from the mean ans 99.7% will fall within three standard deviation from the mean.
#
# The remaining 0.3% is lying very far. In statistics we call them outliers or abnormal data.
# Abnormal datas are inside the dataset due to human error.

# %% [markdown]
# ![Screenshot%20%28289%29.png](attachment:Screenshot%20%28289%29.png)

# %% [markdown]
# # Measures of Asymmetry(Exponential distribution)

# %% [raw]
# Skewness:- Skewness is the asymetry in a statistical distribution, in which the curve appears distorted towards the left or right.
# Skewness indicates whether data is concentrated on one side.

# %% [markdown]
# ![pearson-mode-skewness.jpg](attachment:pearson-mode-skewness.jpg)

# %% [markdown]
# ![Screenshot%20%28288%29.png](attachment:Screenshot%20%28288%29.png)

# %% [raw]
# Percentile and many other caulations can be carried out using 3 libraries:-
# 1. np.percentile() in pandas
# 2. scipy.stats.percentileofscore() in scipy
# 3. .quantile() method in pandas

# %% [raw]
# Pandas is very suitable for importing data. It can also do the functions done by numpy,sqllite3 ,scipy etc.
# Pandas can perform the work of many libraries. So it becomes so much important.
