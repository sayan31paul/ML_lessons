# %%
"""Alexnet (case studies of CNN)"""
# Out:
# 'Alexnet (case studies of CNN)'

# %%
"""Alexnet has 5 convolution layers and three fully connected layers.
Notice that they have reduced the length and breadth while they have increased the depth. The reserchers have found that this works best.

After convolution it passes through ReLU activation and local normalisation. Local normalisation was later removed from alexnet because it didnot show much 
improvement in the result.

What made Alexnet a good network?
1. Alexnet has ReLU Activation ReLu helps in faster convergence.
2. Dropout reduces overfitting
3. Data Augmentation."""
# Out:
# 'Alexnet has 5 convolution layers and three fully connected layers.\nNotice that they have reduced the length and breadth while they have increased the depth. The reserchers have found that this works best.\n\nAfter convolution it passes through ReLU activation and local normalisation. Local normalisation was later removed from alexnet because it didnot show much \nimprovement in the result.\n\nWhat made Alexnet a good network?\n1. Alexnet has ReLU Activation ReLu helps in faster convergence.\n2. Dropout reduces overfitting\n3. Data Augmentation.'

# %% [markdown]
# ![Screenshot%20%28439%29.png](attachment:Screenshot%20%28439%29.png)

# %%
"After every convolution layer there is ReLU activation function."
# Out:
# 'After every convolution layer there is ReLU activation function.'

# %%
"We are making the image smaller and smaller, at the same time we are increasing the depth."

# %%
"""What is data augmentation?

Augmenation are random crops, mirror imaging, tilting of image, upside down etc. One way to reduce overfitting is increasing the data. Augmentation increases
the size of the data by random means like cropping, mirror_imaging, tilting, upside down etc."""
# Out:
# 'What is data augmentation?\n\nAugmenation are random crops, mirror imaging, tilting of image, upside down etc. One way to reduce overfitting is increasing the data. Augmentation increases\nthe size of the data by random means like cropping, mirror_imaging, tilting, upside down etc.'

# %%
"""What made AlexNet a good network?

"""
