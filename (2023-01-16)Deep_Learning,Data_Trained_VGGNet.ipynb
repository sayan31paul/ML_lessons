# %%
"""Alexnet came in 2012. VGGNet came in 2014"""
"""VGG stands for visual geometry group.
VGG has dofferent layers, VGG 11, VGG 13, VGG 16, VGG19.
VGG 11 and VGG 13 are not used a lot . Mostly VGG 16 and VGG 19 are used. Whatever be the VGG, the last three layers will always be fully connected.
"""
# Out:
# 'VGG stands for visual geometry group.\nVGG has dofferent layers, VGG 11, VGG 13, VGG 16, VGG19.\nVGG 11 and VGG 13 are not used a lot . Mostly VGG 16 and VGG 19 are used. Whatever be the VGG, the last three layers will always be fully connected.\n'

# %% [markdown]
# ![Screenshot%20%28440%29.png](attachment:Screenshot%20%28440%29.png)

# %% [markdown]
# ![Screenshot%20%28441%29.png](attachment:Screenshot%20%28441%29.png)

# %%
"""In Alexnet padding was valid but in VCGNet padding is "same" because size remains same for two convolutions consecutiely. Here dimensions of feature maps 
are reduced using max pooling."""
# Out:
# 'In Alexnet padding was valid but in VCGNet padding is "same" because size remains same for two convolutions consecutiely. Here dimensions of feature maps \nare reduced using max pooling.'

# %%
"""How is VGG better than ALEXNet?

Ans: While traininng a neural network, we need to make sure that the depth of the network is increased without increasing the number of trainable parameters.
Alexnet used 5*5 size kernels, but VGGNet used two 3*3 kernels instead of it. This reduced the number of trainable parameters while increasing the depth.

VGG provided greater accuarcy.

VGG showed how we can optimise the model . VGG showed us how we can increase the layers without increasing trainable parameters a lot .

"""
# Out:
# 'How is VGG better than ALEXNet?\n\nAns: While traininng a neural network, we need to make sure that the depth of the network is increased without increasing the number of trainable parameters.\nAlexnet used 5*5 size kernels, but VGGNet used two 3*3 kernels instead of it. This reduced the number of trainable parameters while increasing the depth.\n'

# %%
"""In configuration C , 1*1 kernels are used a lot because the dimensions of the feature maps remains same after applying it but the number of trainable 
parameters are reduced a lot while increasing the depth. Also the 1*1 kernels induce non-linearity. Convolution layers and Relu activation adds linearity 
to the network. 1*1 kernels adds non linearity to the network."""
# Out:
# 'In configuration C , 1*1 kernels are used a lot because the dimensions of the feature maps remains same after applying it but the number of trainable \nparameters are reduced a lot while increasing the depth. Also the 1*1 kernels induce non-linearity.'

# %% [markdown]
# ![Screenshot%20%28442%29.png](attachment:Screenshot%20%28442%29.png)

# %%
"""In training they applied SGD with moemtum as optimiser(momemtum value was 0.9). Batch size for training was 256. Regularization methods used are L2 and 
dropout(dropout value = 0.5). Weights were initialised normally and the weights lied between 0 and 0.01. Biases we initially set to zero."""
