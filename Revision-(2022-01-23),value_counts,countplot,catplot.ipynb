# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
dsiris=pd.read_csv('iris.csv')
dsiris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.set(style='whitegrid') #just for a visually attractive presentation
ax=sns.stripplot(x='class',y='sepal length',data=dsiris) #plotting actually
plt.title('Graph')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ax=sns.swarmplot(x='class',y='sepal length',data=dsiris) #plotting actually
plt.title('Graph')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ax=sns.swarmplot(x='class',y='petal length',data=dsiris) #plotting actually
plt.title('Graph')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dsiris['class'].value_counts() #shows the unique values present and the number in which they are present
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: class, dtype: int64

# %%
sns.countplot(dsiris['class']) #shows the numbers in which the unique values are present
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.get_dataset_names() #these datasets are already present in seaborn library
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#Load data
titanicds=sns.load_dataset('titanic')
titanicds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanicds['class'] #showa the class column only
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
titanicds['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(titanicds['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='bar')
plt.show()

# %%
g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='violin')
plt.show()

# %%
#sns.catplot?               #Remove the '#' and run it to know all information about catplot

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.violinplot(x='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.histplot(x=tips['total_bill'],bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
#sns.histplot?        ##Remove the '#' and run it to know all information about histplot

# %%
sns.histplot(x=tips['total_bill'],bins=20)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
#sns.distplot?        ##Remove the '#' and run it to know all information about distplot

# %%
sns.distplot(tips['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips['tip'],bins=10)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],bins=10)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],bins=100)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],bins=100,kde=False) #kde-kernel density estimation.
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
#sns.kdeplot?

# %%
sns.kdeplot(data=tips,x='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(tips['total_bill'])     #kde-->kernel density estimation #univariate
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=tips,kind='ecdf',x='total_bill',col='time',hue='smoker') #univariate

# %%
sns.jointplot(data=tips,x='total_bill',y='tip') #bivarite since two columns are given as input

# %%
#sns.rugplot?

# %%
sns.rugplot(data=tips,x='tip')
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.rugplot(data=tips,x='tip',y='total_bill')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',hue='smoker',data=tips,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(tips)

# %%
sns.catplot(x='day',y='total_bill',kind='box',data=tips)

# %%
sns.catplot(x='day',y='total_bill',hue='smoker',kind='box',data=tips)

# %%
sns.catplot(x='smoker',y='total_bill',hue='day',kind='box',data=tips)

# %%
iris=pd.read_csv('iris.csv')
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
ax=sns.swarmplot(x='class',y='petal length',data=dsiris) #plotting actually
plt.title('Graph')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mpgds=sns.load_dataset('mpg')
mpgds
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %% [raw]
# Numerical plot- All the columns should have numerical data.

# %%
sns.scatterplot(data=mpgds,x='mpg',y='weight')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %%
sns.scatterplot(data=mpgds,x='horsepower',y='mpg')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
#continue from 1:54:58

# %%
#sns.lineplot?

# %%
sns.lineplot(x='horsepower',y='mpg',data=mpgds)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.relplot(x='horsepower',y='mpg',data=mpgds)

# %%
sns.regplot(x='horsepower',y='mpg',data=mpgds)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.lmplot(x='horsepower',y='mpg',data=mpgds)

# %%
sns.boxplot(y=mpgds['weight'])
# Out:
# <AxesSubplot:ylabel='weight'>

# %%
sns.boxplot(x=mpgds['weight'])
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
sns.rugplot(y='mpg',x='weight',data=mpgds)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='kde')

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg')

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='hex')

# %%
sns.stripplot(data=mpgds,x='origin',y='mpg')
#stripplot is a categorical plot.
#categorical plot takes one categorical data(here it is origin) and one numerical data( here it is mpg)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.swarmplot(data=mpgds,x='origin',y='mpg')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.catplot(data=mpgds,x='origin',y='mpg')

# %%
flights=sns.load_dataset('flights')

# %%
flights=flights.pivot("month","year","passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
ax=sns.heatmap(flights)
