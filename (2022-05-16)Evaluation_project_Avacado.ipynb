# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("avocado.csv")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df['Date'].nunique()
# Out:
# 169

# %%
df=df.sort_values(by='Date').reset_index(drop=True)

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 0              51  2015-01-04          1.75      27365.89     9307.34
# 1              51  2015-01-04          1.49      17723.17     1189.35
# 2              51  2015-01-04          1.68       2896.72      161.68
# 3              51  2015-01-04          1.52      54956.80     3013.04
# 4              51  2015-01-04          1.64       1505.12        1.27
# ...           ...         ...           ...           ...         ...
# 18244           0  2018-03-25          1.36     908202.13   142681.06
# 18245           0  2018-03-25          0.70    9010588.32  3999735.71
# 18246           0  2018-03-25          1.42     163496.70    29253.30
# 18247           0  2018-03-25          1.70     190257.38    29644.09
# 18248           0  2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
df['Date'].dtypes
# Out:
# dtype('O')

# %%
df['Date']=pd.to_datetime(df['Date'])

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [raw]
# 1.There is high difference between median(50th precentile) and mean in most of the columns. Hence high skewness is present in most of the columns.
# 2.The columns 'Total Volume','4026','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags' has high differnce between the 75th percentile and the max value. So outliers will be present in these columns.

# %%
df.isnull().sum()

#No null values prsent
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())

#no null values present
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['Unnamed: 0'])
plt.show()

# %%
sns.scatterplot(df['Unnamed: 0'],df['AveragePrice'])
plt.show()

# %%
sns.scatterplot(df['Unnamed: 0'],df['region'])
plt.show()

# %%
sns.distplot(df['Date'])
plt.show()

# %%
plt.figure(figsize=[12,8])
sns.scatterplot(df['Date'],df['AveragePrice'])
plt.show()

#The price is seen to increase in certain parts of the year.

# %%
sns.distplot(df['AveragePrice'])
plt.show()

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['AveragePrice'])

plt.xticks(rotation = 90)
plt.show()

#Price is high in some regions and low in some regions

# %%
sns.distplot(df['Total Volume'])
plt.show()

#Total volume is varying over a very high range.
#There is high skewness present in this 'Total Volume'
#Outliers surely present in this column.

# %%
sns.scatterplot(df['Total Volume'],df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['Total Volume'])
plt.xticks(rotation = 90)
plt.show()


#There is are rows where 'region'='TotalUS' . These rows might significantly(positively or negatively) effect the data.
#We need to try models with or without these rows.

# %%
sns.distplot(df['4046'])
plt.show()

#High skewness present in the sales of 4046

# %%
sns.scatterplot(df['4046'],df['AveragePrice'])
plt.show()

#This graph resembles with the graph of 'Total Volume'. High correlation may be present between 'Total Volume' and '4046'

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['4046'])
plt.xticks(rotation = 90)
plt.show()

#Region which has high 'Total Volumes' are showing high sales of '4046'

# %%
sns.distplot(df['4225'])
plt.show()

#high skewness present
#outliers present

# %%
sns.scatterplot(df['4225'],df['AveragePrice'])
plt.show()

#When sales of 4225 is low, the 'AveragePrice' is high

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['4225'])
plt.xticks(rotation = 90)
plt.show()

#Some regions show high sales.
#Ignore the 'total US '

# %%
sns.distplot(df['4770'])
plt.show()

#high skewness present
#outliers present

# %%
sns.scatterplot(df['4770'],df['AveragePrice'])
plt.show()

#When sales of 4225 is low, the 'AveragePrice' is high

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['4770'])
plt.xticks(rotation = 90)
plt.show()

#Some regions show high sales.
#Ignore the 'total US '

# %%
sns.distplot(df['Total Bags'])
plt.show()
#Skewness present in data
#Outliers might be present

# %%
sns.scatterplot(df['Total Bags'],df['AveragePrice'])
plt.show()

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['Total Bags'])
plt.xticks(rotation = 90)
plt.show()

#This column might have high correlation with Total Volume,4046,4225,4770

# %%
sns.distplot(df['Small Bags'])
plt.show()
#Skewness present in data
#Outliers might be present

# %%
sns.scatterplot(df['Small Bags'],df['AveragePrice'])
plt.show()

#When 'Small Bags' sold is low, the price is high

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['Small Bags'])
plt.xticks(rotation = 90)
plt.show()

#some regions have high sales of small bags, while some regions have low sales
#Ignore Total US

# %%
sns.distplot(df['Large Bags'])
plt.show()
#Skewness present in data
#Outliers might be present

# %%
sns.scatterplot(df['Small Bags'],df['AveragePrice'])
plt.show()

#When 'Large Bags' sold is low, the price is high

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['Large Bags'])
plt.xticks(rotation = 90)
plt.show()

#some regions have high sales of large bags, while some regions have low sales
#Ignore Total US

# %%
sns.distplot(df['XLarge Bags'])
plt.show()
#Skewness present in data
#Outliers might be present

# %%
sns.scatterplot(df['XLarge Bags'],df['AveragePrice'])
plt.show()

#When 'XLarge Bags' sold is low, the price is high

# %%
plt.figure(figsize=[12,7.5])
sns.scatterplot(df['region'],df['XLarge Bags'])
plt.xticks(rotation = 90)
plt.show()

#some regions have high sales of Xlarge bags, while some regions have low sales
#Ignore Total US

# %%
df['type'].unique()
# Out:
# array(['organic', 'conventional'], dtype=object)

# %%
sns.countplot(df['type'])
plt.show()

# %%
sns.histplot(data=df,x='AveragePrice',bins=20,kde=True,hue='type')
plt.show()

#Price of organic Avocado is higher.
#Conventional Avocado is present in higher quantities.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['type']=le.fit_transform(df['type'])
df['region']=le.fit_transform(df['region'])

# %%
plt.figure(figsize=[13,10])
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#sns.pairplot(df)

# %%
#unnamed has very low correlation with Average Price(Target Variable). Hence we will be removing that column
#unnamed is a irrelevant column as per the project description also.
df=df.drop(columns=['Unnamed: 0'],axis=1)

# %% [raw]
# 'Region' has very less correlation with 'Average Price'. But we are not removing it now. Because we will be needing it in Classification problem.
# We will remove it before applying it on regression problem.

# %% [raw]
# 'year' column has very low correlation with the output but we will keep it and leave it to the lasso regression model to reduce the respective coefficient to zero.

# %% [raw]
# 'Total Volume', '4046','4225','Total Bags','Small Bags' has high correlation. But removing any of them might negatively effect the model accuracy. So we will be using Principal Component Analysis instead.
#
# 'Total Bags','Small Bags','Large Bags' has very high correlation. Thsi also justifies the application of PCA.

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.shape
# Out:
# (18249, 13)

# %%
#checking skewness
df.skew()

#Acceptable limit of skewness is 0.5
#All columns here have high skewness. Hence we have to remove skewness.
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
df_new_1=df[['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags']]

# %%
from sklearn.preprocessing import power_transform #power_transform reduces skewness
df_new_1=power_transform(df_new_1)

# %%
df_new_1=pd.DataFrame(df_new_1,columns=['Total Volume','4046','4225','4770','Total Bags','Small Bags','Large Bags','XLarge Bags'])

# %%
df_new_1.skew()
#Skewness has been reduced in selected columns.
# Out:
# Total Volume    0.011171
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# dtype: float64

# %%
df_new_1['type']=df['type']
df_new_1['year']=df['year']
df_new_1['region']=df['region']
df_new_1['AveragePrice']=df['AveragePrice']

# %%
df=df_new_1

# %%
df
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.463628 -0.022412 -0.628576  0.362010   -0.331267   -0.179011
# 1         -0.657853 -0.620433 -0.152712 -1.238310   -1.457170   -1.133879
# 2         -1.484436 -1.154503 -1.495047 -1.238310   -1.042283   -0.787941
# 3         -0.155107 -0.356327  0.145147  0.579718   -0.290771   -0.236842
# 4         -1.789926 -2.167971 -1.011444 -1.238310   -1.802829   -1.618145
# ...             ...       ...       ...       ...         ...         ...
# 18244      1.046969  0.850515  1.184397  1.632391    0.676928    0.697656
# 18245      1.985449  2.052944  1.513874  1.249727    2.383212    2.501887
# 18246      0.319482  0.332313 -0.537325 -1.238310    0.683319    0.721143
# 18247      0.384721  0.336519  0.409680 -1.238310    0.513536    0.631095
# 18248      1.325062  0.583783  1.485611  0.436093    1.562452    1.682619
#
#        Large Bags  XLarge Bags  type  year  region  AveragePrice
# ...

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10),color='green')
plt.show()

#huge  number of outliers are present in the data. Hence we have to remive them.

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))


df_new=df[(z<3.0).all(axis=1)]
print(df.shape)
print(df_new.shape)

print("loss_percent= ",(df.shape[0]-df_new.shape[0])/df.shape[0]*100)
# Out:
# (18249, 12)
# (18025, 12)
# loss_percent=  1.2274645186037592

# %% [raw]
# Outliers have been removed.
# Now we will be preparing two separate datasets for regression and classification

# %%
df
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.463628 -0.022412 -0.628576  0.362010   -0.331267   -0.179011
# 1         -0.657853 -0.620433 -0.152712 -1.238310   -1.457170   -1.133879
# 2         -1.484436 -1.154503 -1.495047 -1.238310   -1.042283   -0.787941
# 3         -0.155107 -0.356327  0.145147  0.579718   -0.290771   -0.236842
# 4         -1.789926 -2.167971 -1.011444 -1.238310   -1.802829   -1.618145
# ...             ...       ...       ...       ...         ...         ...
# 18244      1.046969  0.850515  1.184397  1.632391    0.676928    0.697656
# 18245      1.985449  2.052944  1.513874  1.249727    2.383212    2.501887
# 18246      0.319482  0.332313 -0.537325 -1.238310    0.683319    0.721143
# 18247      0.384721  0.336519  0.409680 -1.238310    0.513536    0.631095
# 18248      1.325062  0.583783  1.485611  0.436093    1.562452    1.682619
#
#        Large Bags  XLarge Bags  type  year  region  AveragePrice
# ...

# %% [markdown]
# # Dataset for regression model

# %%
#dropping the region column for the regression model as decided earlier
dfr=df.drop(columns=['region'],axis=1)

# %%
dfr.head()
# Out:
#    Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0     -0.463628 -0.022412 -0.628576  0.362010   -0.331267   -0.179011
# 1     -0.657853 -0.620433 -0.152712 -1.238310   -1.457170   -1.133879
# 2     -1.484436 -1.154503 -1.495047 -1.238310   -1.042283   -0.787941
# 3     -0.155107 -0.356327  0.145147  0.579718   -0.290771   -0.236842
# 4     -1.789926 -2.167971 -1.011444 -1.238310   -1.802829   -1.618145
#
#    Large Bags  XLarge Bags  type  year  AveragePrice
# 0   -0.355660    -0.699849     1  2015          1.75
# 1   -1.645675    -0.699849     1  2015          1.49
# 2   -1.645675    -0.699849     1  2015          1.68
# 3    0.168596    -0.699849     0  2015          1.52
# 4   -0.613224    -0.699849     1  2015          1.64

# %%
x=dfr.iloc[:,0:-1]
y=dfr.iloc[:,-1]

# %% [raw]
# Lets decide which value of n_components in PCA would be best

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score

# %%
#trying different regression models with n_components=5

pca=PCA(n_components=5)
xpca=pca.fit_transform(x)
xpca=pd.DataFrame(xpca)
x_train,x_test,y_train,y_test=train_test_split(xpca,y,test_size=0.22,random_state=45)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)
print("r2_score for LinearRegression is: ",r2_score(y_test,y_pred_lr))

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred_rfr=rfr.predict(x_test)
print("r2_score for RandomForestRegression is: ",r2_score(y_test,y_pred_rfr))

knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred_knr=knr.predict(x_test)
print("r2_score for KNeighborsRegression is: ",r2_score(y_test,y_pred_knr))
# Out:
# r2_score for LinearRegression is:  0.3739942821836977
# r2_score for RandomForestRegression is:  0.739676931699968
# r2_score for KNeighborsRegression is:  0.7278190534610833

# %%
#trying different regression models with n_components=6

pca=PCA(n_components=6)
xpca=pca.fit_transform(x)
xpca=pd.DataFrame(xpca)
x_train,x_test,y_train,y_test=train_test_split(xpca,y,test_size=0.22,random_state=45)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)
print("r2_score for LinearRegression is: ",r2_score(y_test,y_pred_lr))

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred_rfr=rfr.predict(x_test)
print("r2_score for RandomForestRegression is: ",r2_score(y_test,y_pred_rfr))

knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred_knr=knr.predict(x_test)
print("r2_score for KNeighborsRegression is: ",r2_score(y_test,y_pred_knr))
# Out:
# r2_score for LinearRegression is:  0.37878129314417475
# r2_score for RandomForestRegression is:  0.7548004434758055
# r2_score for KNeighborsRegression is:  0.7541908156909993

# %%
#trying different regression models with n_components=7

pca=PCA(n_components=7)
xpca=pca.fit_transform(x)
xpca=pd.DataFrame(xpca)
x_train,x_test,y_train,y_test=train_test_split(xpca,y,test_size=0.22,random_state=45)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)
print("r2_score for LinearRegression is: ",r2_score(y_test,y_pred_lr))

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred_rfr=rfr.predict(x_test)
print("r2_score for RandomForestRegression is: ",r2_score(y_test,y_pred_rfr))

knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred_knr=knr.predict(x_test)
print("r2_score for KNeighborsRegression is: ",r2_score(y_test,y_pred_knr))
# Out:
# r2_score for LinearRegression is:  0.39920575286248483
# r2_score for RandomForestRegression is:  0.7883277345476838
# r2_score for KNeighborsRegression is:  0.7917067589391924

# %%
#trying different regression models with n_components=8

pca=PCA(n_components=8)
xpca=pca.fit_transform(x)
xpca=pd.DataFrame(xpca)
x_train,x_test,y_train,y_test=train_test_split(xpca,y,test_size=0.22,random_state=45)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)
print("r2_score for LinearRegression is: ",r2_score(y_test,y_pred_lr))

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred_rfr=rfr.predict(x_test)
print("r2_score for RandomForestRegression is: ",r2_score(y_test,y_pred_rfr))

knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred_knr=knr.predict(x_test)
print("r2_score for KNeighborsRegression is: ",r2_score(y_test,y_pred_knr))
# Out:
# r2_score for LinearRegression is:  0.48568579994633765
# r2_score for RandomForestRegression is:  0.7974535561964105
# r2_score for KNeighborsRegression is:  0.795924816676755

# %%
#trying different regression models with n_components=9

pca=PCA(n_components=9)
xpca=pca.fit_transform(x)
xpca=pd.DataFrame(xpca)
x_train,x_test,y_train,y_test=train_test_split(xpca,y,test_size=0.22,random_state=45)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)
print("r2_score for LinearRegression is: ",r2_score(y_test,y_pred_lr))

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred_rfr=rfr.predict(x_test)
print("r2_score for RandomForestRegression is: ",r2_score(y_test,y_pred_rfr))

knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred_knr=knr.predict(x_test)
print("r2_score for KNeighborsRegression is: ",r2_score(y_test,y_pred_knr))
# Out:
# r2_score for LinearRegression is:  0.5088480341414199
# r2_score for RandomForestRegression is:  0.7998737557762368
# r2_score for KNeighborsRegression is:  0.7974105003480376

# %%
#trying without PCA


x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=45)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)
print("r2_score for LinearRegression is: ",r2_score(y_test,y_pred_lr))

rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred_rfr=rfr.predict(x_test)
print("r2_score for RandomForestRegression is: ",r2_score(y_test,y_pred_rfr))

knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred_knr=knr.predict(x_test)
print("r2_score for KNeighborsRegression is: ",r2_score(y_test,y_pred_knr))
# Out:
# r2_score for LinearRegression is:  0.5106601825629922
# r2_score for RandomForestRegression is:  0.8122937083275609
# r2_score for KNeighborsRegression is:  0.7970699378174118

# %% [raw]
# models are working better without PCA

# %% [markdown]
# # Regression model Training Process Begins

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### Lets try out the best polynomial for LinearRegression

# %%
max_cv_score=0
best_polynomial=0
for i in range(1,4):
    poly = PolynomialFeatures(i)
    X_=poly.fit_transform(x)
    lr =LinearRegression()
    lsscore=cross_val_score(lr,X_,y,cv=5)
    if lsscore.mean()>max_cv_score:
        max_cv_score=lsscore.mean()
        best_polynomial=i

print(max_cv_score)
print(best_polynomial)
# Out:
# 0.4877885256722537
# 1

# %% [raw]
# since model is working best with polynomial=1, we will go for simple LinearRegression

# %% [markdown]
# Finding out the random_state for which LinearRegression model works best

# %%
max_r2_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    
    if r2_score(y_test,y_pred)>max_r2_score:
        max_r2_score=r2_score(y_test,y_pred)
        best_rand_state=i

print(max_r2_score)
print(best_rand_state)
# Out:
# 0.5562304360724559
# 56

# %% [raw]
# So the best random state for training the LinearRegression model is 56

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=56)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print("r2_score is: ",r2_score(y_test,y_pred))
print('root_mean_sqaured_error:',mean_squared_error(y_test,y_pred))
# Out:
# r2_score is:  0.5562304360724559
# root_mean_sqaured_error: 0.07184093093738389

# %% [markdown]
# #### Lets find out the best parameters for ridge regression model

# %%
r=Ridge()
parameters={'alpha':[0.1,0.01,0.001],'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs']}
gd_sr=GridSearchCV(estimator=r, param_grid= parameters, scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'alpha': 0.1, 'solver': 'lsqr'}
# 0.4895585407404729

# %% [markdown]
# Trying out the best random_state for RidgeRegression model for the above obtained parameters.

# %%
max_r2_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    r=Ridge(alpha= 0.1, solver= 'lsqr')
    r.fit(x_train,y_train)
    y_pred=r.predict(x_test)
    
    if r2_score(y_test,y_pred)>max_r2_score:
        max_r2_score=r2_score(y_test,y_pred)
        best_rand_state=i

print(max_r2_score)
print(best_rand_state)

#Ridge regression is giving better accuracy than LinearRegression model
# Out:
# 0.5559241939572054
# 56

# %% [raw]
# Lets train the final Ridge regression model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=56)
r=Ridge(alpha= 0.1, solver= 'lsqr')
r.fit(x_train,y_train)
y_pred=r.predict(x_test)
print("r2_score is: ",r2_score(y_test,y_pred))
print('root_mean_sqaured_error:',mean_squared_error(y_test,y_pred))

#Ridge Regresion model is giving slightly higher accuracy than LinearRegression model
# Out:
# r2_score is:  0.5559241939572054
# root_mean_sqaured_error: 0.0718905078359371

# %% [markdown]
# #### Finding out the best parameters for Lasso Regression model

# %%
l=Lasso()
parameters={'alpha':[0.1,0.01,0.001]}
gd_sr=GridSearchCV(estimator=l, param_grid= parameters, scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'alpha': 0.001}
# 0.4863311126609708

# %% [markdown]
# Finding out the best random_state for LassoRegression

# %%
max_r2_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    l=Lasso(alpha=0.001)
    l.fit(x_train,y_train)
    y_pred=l.predict(x_test)
    
    if r2_score(y_test,y_pred)>max_r2_score:
        max_r2_score=r2_score(y_test,y_pred)
        best_rand_state=i

print(max_r2_score)
print(best_rand_state)
# Out:
# 0.5545436953015315
# 56

# %% [markdown]
# Training the final model for LassoRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=56)
l=Lasso(alpha=0.001)
l.fit(x_train,y_train)
y_pred=l.predict(x_test)
print("r2_score is: ",r2_score(y_test,y_pred))
print('root_mean_sqaured_error:',mean_squared_error(y_test,y_pred))

#Lasso is giving poorer performance than ridge regresison model
# Out:
# r2_score is:  0.5545436953015315
# root_mean_sqaured_error: 0.072113993889608

# %% [markdown]
# #### Applying GridSaerchCV on KNN Regressor

# %%
knr=KNeighborsRegressor()
parameters={'n_neighbors':[10,15,20,25,30,35,40,45,50],"weights":['uniform','distance'],'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],}
gd_sr=GridSearchCV(estimator=knr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 50, 'weights': 'distance'}
# 0.4619605267994739

# %%
#trying GridSearchCV once again, to check if CV score increases.

knr=KNeighborsRegressor()
parameters={'n_neighbors':[45,50,55,60,65,70,75,80],"weights":['uniform','distance'],'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],}
gd_sr=GridSearchCV(estimator=knr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 80, 'weights': 'distance'}
# 0.4779639915315201

# %%
#trying GridSearchCV once again, to check if CV score increases.

knr=KNeighborsRegressor()
parameters={'n_neighbors':[80,90,100,110,120,130,140,150,160,170,180,190,200],"weights":['uniform','distance'],'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],}
gd_sr=GridSearchCV(estimator=knr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 200, 'weights': 'distance'}
# 0.49604437609772756

# %%
#trying GridSearchCV once again, to check if CV score increases.

knr=KNeighborsRegressor()
parameters={'n_neighbors':[210,220,230,240,250,260,270,280,290,300,310,320,330,340,350,360,370,380,390,400],'weights':['distance']}
gd_sr=GridSearchCV(estimator=knr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'n_neighbors': 210, 'weights': 'distance'}
# 0.4961661793562235

# %%
#trying GridSearchCV once again, to check if CV score increases.

knr=KNeighborsRegressor()
parameters={'n_neighbors':[200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220],'weights':['distance']}
gd_sr=GridSearchCV(estimator=knr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'n_neighbors': 211, 'weights': 'distance'}
# 0.4961811392393738

# %%
#trying GridSearchCV once again, to check if CV score increases.

knr=KNeighborsRegressor()
parameters={'n_neighbors':[208,209,210,211,212,213,214],"weights":['uniform','distance'],'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute']}
gd_sr=GridSearchCV(estimator=knr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'algorithm': 'auto', 'n_neighbors': 211, 'weights': 'distance'}
# 0.4961811392393738

# %% [raw]
# So from all the above GrisSearchCV results, the hyperparameters obtained are :-
#     1. n_neighbors=211
#     2. weights= distance
#     3. algorithm=auto

# %% [markdown]
# finding out the best random state for KNeighborsregressor

# %%
max_r2_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    knr=KNeighborsRegressor(algorithm= 'auto', n_neighbors= 211, weights= 'distance')
    knr.fit(x_train,y_train)
    y_pred=knr.predict(x_test)
    
    if r2_score(y_test,y_pred)>max_r2_score:
        max_r2_score=r2_score(y_test,y_pred)
        best_rand_state=i

print(max_r2_score)
print(best_rand_state)
# Out:
# 0.6708899528638013
# 59

# %% [raw]
# Since the model_accuracy is detoriating after using GridSearchCV on KNNRegressor. We are going with the default settings of KNNRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=59)
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred=knr.predict(x_test)
print("r2_score is: ",r2_score(y_test,y_pred))
print('root_mean_sqaured_error:',mean_squared_error(y_test,y_pred))

#KNNRegressor is giving better accuracy than all the prevoius models.
# Out:
# r2_score is:  0.8286440458059756
# root_mean_sqaured_error: 0.027940946849315067

# %% [markdown]
# #### Finding out the best parameters for RandomForestRegressor

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred_rfr=rfr.predict(x_test)
print("r2_score for RandomForestRegression is: ",r2_score(y_test,y_pred_rfr))
# Out:
# r2_score for RandomForestRegression is:  0.8265576596726812

# %% [raw]
# Accuracy of regression model without hyperparameter tuning is 0.8265576596726812.
# We have to improve it or accept this model

# %%
rfr=RandomForestRegressor()
parameters={'n_estimators':[80,90,100,110,120],'max_depth':[10,13,15,17,20]}
gd_sr=GridSearchCV(estimator=rfr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'max_depth': 17, 'n_estimators': 80}
# 0.47564335728093055

# %%
rfr=RandomForestRegressor()
parameters={'n_estimators':[30,40,50,60,70,80],'max_depth':[15,16,17,18,19]}
gd_sr=GridSearchCV(estimator=rfr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'max_depth': 19, 'n_estimators': 40}
# 0.47752084570035

# %%
#finding out the best random state and the r2_score for the above obtained best parameters.

max_r2_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    rfr=RandomForestRegressor(max_depth= 19, n_estimators= 40)
    knr.fit(x_train,y_train)
    y_pred=knr.predict(x_test)
    
    if r2_score(y_test,y_pred)>max_r2_score:
        max_r2_score=r2_score(y_test,y_pred)
        best_rand_state=i

print(max_r2_score)
print(best_rand_state)
# Out:
# 0.8286440458059756
# 59

# %%
rfr=RandomForestRegressor()
parameters={'n_estimators':[38,39,40,41,42],'max_depth':[17,18,19,20,21,22]}
gd_sr=GridSearchCV(estimator=rfr, param_grid= parameters,scoring='r2')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'max_depth': 21, 'n_estimators': 41}
# 0.4734132233126596

# %%
#finding out the best random state and the r2_score for the above obtained best parameters.

max_r2_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    rfr=RandomForestRegressor(max_depth= 21, n_estimators= 41)
    knr.fit(x_train,y_train)
    y_pred=knr.predict(x_test)
    
    if r2_score(y_test,y_pred)>max_r2_score:
        max_r2_score=r2_score(y_test,y_pred)
        best_rand_state=i

print(max_r2_score)
print(best_rand_state)
# Out:
# 0.8286440458059756
# 59

# %% [raw]
# By applying GridSearchCV, the accuracy of the model has increased slightly than the default model.

# %% [markdown]
# # Finalising the best regression model

# %% [raw]
# KNNRegressor is giving the best accuracy out of all the models. So we are finalising KNNRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=59)
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
y_pred=knr.predict(x_test)
print("r2_score is: ",r2_score(y_test,y_pred))
print('root_mean_sqaured_error:',mean_squared_error(y_test,y_pred))
print('mean_absolute_error:',mean_absolute_error(y_test,y_pred))
# Out:
# r2_score is:  0.8286440458059756
# root_mean_sqaured_error: 0.027940946849315067
# mean_absolute_error: 0.11602739726027397

# %% [markdown]
# # Saving the KNNRegressor model

# %%
import pickle
filename='avocado_price.pkl'
pickle.dump(knr,open(filename,'wb'))

# %% [markdown]
# # Dataset for classification model

# %%
plt.figure(figsize=[13,10])
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [raw]
# Region has very low correlation with 'type','year','AveragePrice','XLarge Bags'. So we are removing those columns

# %%
dfc=df.drop(columns=['type','year','AveragePrice','XLarge Bags'],axis=1)

# %%
dfc.columns
# Out:
# Index(['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags',
#        'Large Bags', 'region'],
#       dtype='object')

# %%
x=dfc.iloc[:,0:-1]
y=dfc.iloc[:,-1]

# %%
x.head(3)
# Out:
#    Total Volume      4046      4225     4770  Total Bags  Small Bags  \
# 0     -0.463628 -0.022412 -0.628576  0.36201   -0.331267   -0.179011
# 1     -0.657853 -0.620433 -0.152712 -1.23831   -1.457170   -1.133879
# 2     -1.484436 -1.154503 -1.495047 -1.23831   -1.042283   -0.787941
#
#    Large Bags
# 0   -0.355660
# 1   -1.645675
# 2   -1.645675

# %%
y.head(3)
# Out:
# 0    46
# 1     8
# 2    16
# Name: region, dtype: int32

# %% [markdown]
# # Classification model training process begins

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Trying the Logistic Regression model

# %%
#finding the result of DEFAULT Logistic regression model 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

#logistic regresion model is performing very bad
# Out:
# [[17  0  0 ...  0  0  0]
#  [ 0 12  0 ...  0  3  0]
#  [ 0  0 23 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 42  3  0]
#  [ 0  5  0 ... 12 28  0]
#  [ 0  4  0 ...  0  1  1]]
# accuracy_score= 0.273972602739726
#               precision    recall  f1-score   support
#
#            0       0.31      0.28      0.30        60
#            1       0.10      0.18      0.13        65
#            2       0.32      0.36      0.34        64
#            3       0.07      0.05      0.06        65
#            4       0.31      0.35      0.33        65
#            5       0.12      0.08      0.10        72
#            6       0.70      0.71      0.71        77
#            7       0.25      0.54      0.34        65
#            8       0.40      0.55      0.46        66
#            9       0.33      0.60      0.42        62
#           10       0.20      0.05      0.08        64
#           11       0.30      0.25      0.28        63
#           12       0.14      0.15      0.15        74
# ...

# %%
lr=LogisticRegression()
parameters={'penalty':[ 'l2', 'none'],'solver':[ 'lbfgs', 'liblinear', 'sag', 'saga']}
gd_sr=GridSearchCV(estimator=lr, param_grid= parameters,scoring='accuracy')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'penalty': 'l2', 'solver': 'lbfgs'}
# nan

# %%
#finding the result of default KNeighborsClassifier model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
y_pred=knc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

#Kneighbors classifier is giving far better results than LogisticRegression model
# Out:
# [[56  0  0 ...  0  0  0]
#  [ 0 52  0 ...  0  0  2]
#  [ 0  0 63 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 61  0  0]
#  [ 0  0  0 ...  0 57  0]
#  [ 0  0  0 ...  0  0 48]]
# accuracy_score= 0.8265753424657534
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84        60
#            1       0.74      0.80      0.77        65
#            2       0.97      0.98      0.98        64
#            3       0.77      0.91      0.83        65
#            4       0.86      0.88      0.87        65
#            5       0.89      0.58      0.71        72
#            6       0.97      0.95      0.96        77
#            7       0.72      0.89      0.79        65
#            8       0.97      0.91      0.94        66
#            9       0.76      0.81      0.78        62
#           10       0.70      0.77      0.73        64
#           11       0.87      0.94      0.90        63
#           12       0.87      0.82      0.85        74
# ...

# %%
#finding the best random state for KNNClassifier

# %%
#applying GridSearchCV on KneighborsClassifier
knc=KNeighborsClassifier()
parameters={'n_neighbors':[5,7,9],'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute']}
gd_sr=GridSearchCV(estimator=knc, param_grid= parameters,scoring='f1')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)


#We are getting the default values of KNeighborsClassifier as the best_parameters.
# Out:
# {'algorithm': 'auto', 'n_neighbors': 5}
# nan

# %%
#finding the best random state for KNearestNeighbors model
max_acc_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    knc=KNeighborsClassifier(algorithm='auto', n_neighbors= 5)
    knc.fit(x_train,y_train)
    y_pred=knc.predict(x_test)
    
    if accuracy_score(y_test,y_pred)>max_acc_score:
        max_acc_score=accuracy_score(y_test,y_pred)
        best_rand_state=i

print(max_acc_score)
print(best_rand_state)
# Out:
# 0.8441095890410959
# 59

# %%
#final KNNClassifier model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=59)
knc=KNeighborsClassifier(algorithm='auto', n_neighbors= 5)
knc.fit(x_train,y_train)
y_pred=knc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[58  0  0 ...  0  0  0]
#  [ 0 35  0 ...  0  0  0]
#  [ 0  0 71 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 79  0  0]
#  [ 0  0  0 ...  0 75  0]
#  [ 0  1  1 ...  0  0 40]]
# accuracy_score= 0.8441095890410959
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87        63
#            1       0.56      0.73      0.63        48
#            2       0.92      0.96      0.94        74
#            3       0.76      0.76      0.76        63
#            4       0.84      0.90      0.87        63
#            5       0.87      0.74      0.80        65
#            6       0.97      0.99      0.98        67
#            7       0.79      0.92      0.85        52
#            8       0.91      0.90      0.91        92
#            9       0.79      0.83      0.81        54
#           10       0.72      0.78      0.75        67
#           11       0.84      0.98      0.91        63
#           12       0.97      0.85      0.90        66
# ...

# %%
#finding the accuracy of default support vector classifier model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
svc=SVC()
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

#it has lower accuarcy than KNNClassifier 
#so we are not doing any more approach on this
# Out:
# [[56  0  0 ...  0  0  0]
#  [ 0 36  0 ...  0  0  0]
#  [ 0  0 56 ...  1  0  0]
#  ...
#  [ 0  0  0 ... 59  0  0]
#  [ 0  0  0 ...  0 58  0]
#  [ 0  1  1 ...  0  0 43]]
# accuracy_score= 0.7350684931506849
#               precision    recall  f1-score   support
#
#            0       0.66      0.93      0.77        60
#            1       0.58      0.55      0.57        65
#            2       0.92      0.88      0.90        64
#            3       0.73      0.78      0.76        65
#            4       0.75      0.74      0.74        65
#            5       0.86      0.51      0.64        72
#            6       0.97      0.94      0.95        77
#            7       0.72      0.66      0.69        65
#            8       0.94      0.91      0.92        66
#            9       0.68      0.81      0.74        62
#           10       0.59      0.80      0.68        64
#           11       0.77      0.81      0.79        63
#           12       0.87      0.78      0.82        74
# ...

# %%
#finding the accuracy of RandomForestClassifier model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))

#This is giving higher accuarcy than KNeighborsClassifier model
# Out:
# [[55  0  0 ...  0  0  0]
#  [ 0 53  0 ...  0  0  0]
#  [ 0  0 63 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 60  0  0]
#  [ 0  0  0 ...  0 59  0]
#  [ 0  1  0 ...  0  0 47]]
# accuracy_score= 0.8635616438356164
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87        60
#            1       0.83      0.82      0.82        65
#            2       0.98      0.98      0.98        64
#            3       0.89      0.95      0.92        65
#            4       0.84      0.91      0.87        65
#            5       0.86      0.67      0.75        72
#            6       0.96      0.96      0.96        77
#            7       0.84      0.91      0.87        65
#            8       0.98      0.91      0.94        66
#            9       0.83      0.89      0.86        62
#           10       0.80      0.88      0.84        64
#           11       0.92      0.97      0.95        63
#           12       0.89      0.86      0.88        74
# ...

# %%
#Applying GridSearchCV on RandomForestClassifier model.
rfc=RandomForestClassifier()
parameters={'n_estimators':[20,30,40,50,60,70],'max_depth':[15,17,20,21,23,25]}
gd_sr=GridSearchCV(estimator=rfc, param_grid= parameters,scoring='f1')
gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.
print(best_result)
# Out:
# {'max_depth': 15, 'n_estimators': 20}
# nan

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
rfc=RandomForestClassifier(max_depth=15, n_estimators=20)
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))


#the default RandomForestClassifier model is giving better accuracy than this model.
#So we will get with the RandomForestClassifier model.
# Out:
# [[51  0  0 ...  0  0  0]
#  [ 0 45  0 ...  0  0  0]
#  [ 0  0 61 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 60  0  0]
#  [ 0  0  0 ...  0 57  0]
#  [ 0  2  1 ...  0  0 40]]
# accuracy_score= 0.8035616438356165
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.80        60
#            1       0.68      0.69      0.69        65
#            2       0.94      0.95      0.95        64
#            3       0.85      0.86      0.85        65
#            4       0.81      0.86      0.84        65
#            5       0.80      0.65      0.72        72
#            6       0.95      0.91      0.93        77
#            7       0.79      0.75      0.77        65
#            8       0.97      0.89      0.93        66
#            9       0.73      0.85      0.79        62
#           10       0.71      0.78      0.75        64
#           11       0.90      0.90      0.90        63
#           12       0.86      0.81      0.83        74
# ...

# %%
##finding out the best random state for default random forest classifier model
max_acc_score=0
best_rand_state=0
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    rfc=RandomForestClassifier()
    rfc.fit(x_train,y_train)
    y_pred=rfc.predict(x_test)
    
    if accuracy_score(y_test,y_pred)>max_acc_score:
        max_acc_score=accuracy_score(y_test,y_pred)
        best_rand_state=i

print(max_acc_score)
print(best_rand_state)
# Out:
# 0.8679452054794521
# 37

# %%
#training the final random forest classifier model
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=37)
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[59  0  0 ...  0  0  0]
#  [ 0 53  0 ...  0  0  0]
#  [ 0  0 68 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 61  0  0]
#  [ 0  0  0 ...  0 67  0]
#  [ 0  3  0 ...  0  0 52]]
# accuracy_score= 0.8679452054794521
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        67
#            1       0.73      0.84      0.78        63
#            2       0.97      0.99      0.98        69
#            3       0.86      0.70      0.77        73
#            4       0.93      0.90      0.92        61
#            5       0.83      0.66      0.73        58
#            6       0.95      0.97      0.96        74
#            7       0.93      0.93      0.93        69
#            8       0.97      0.95      0.96        63
#            9       0.86      0.83      0.85        53
#           10       0.77      0.85      0.81        59
#           11       0.91      0.88      0.89        67
#           12       0.89      0.86      0.87        63
# ...

# %% [markdown]
# # Final Classification model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=37)
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
y_pred=rfc.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print('accuracy_score=',accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[58  0  0 ...  0  0  0]
#  [ 0 56  0 ...  0  0  0]
#  [ 0  0 64 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 61  0  0]
#  [ 0  0  0 ...  0 66  0]
#  [ 0  3  0 ...  0  0 49]]
# accuracy_score= 0.8663013698630136
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81        67
#            1       0.73      0.89      0.80        63
#            2       0.97      0.93      0.95        69
#            3       0.88      0.68      0.77        73
#            4       0.95      0.87      0.91        61
#            5       0.84      0.64      0.73        58
#            6       0.95      1.00      0.97        74
#            7       0.91      0.93      0.92        69
#            8       0.97      0.97      0.97        63
#            9       0.85      0.83      0.84        53
#           10       0.75      0.83      0.79        59
#           11       0.89      0.85      0.87        67
#           12       0.92      0.90      0.91        63
# ...

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='region.pkl'
pickle.dump(rfc,open(filename,'wb'))
