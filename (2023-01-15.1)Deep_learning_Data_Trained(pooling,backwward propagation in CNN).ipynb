# %%
"""If we use two fliters, we will have two results. The results are known as feature maps.
Number of feature maps = Number of filters."""
# Out:
# 'If we use two fliters, we will have two results. The results are known as feature maps.\nNumber of feature maps = Number of filters.'

# %% [markdown]
# ![Screenshot%20%28528%29.png](attachment:Screenshot%20%28528%29.png)

# %% [markdown]
# ![Screenshot%20%28529%29.png](attachment:Screenshot%20%28529%29.png)

# %%
"""Pooling reduces the dimensions without loosing the important information to make the calculations easier.
Let an image contain a chair while remaining parts of the image are empty. We have to convulate only the chair.

Pooling is of two types:- Max pooling and Average pooling.

Max pooling:- We take clusters of pixels and take out the maximum from each cluster.

There is also another type of pooling called minimum pooling. """
# Out:
# 'Pooling reduces the dimensions without loosing the important information to make the calculations easier.\nLet an image contain a chair while remaining parts of the image are empty. We have to convulate only the chair.\n\nPooling is of two types:- Max pooling and Average pooling.\n\nMax pooling:- We take clusters of pixels and take out the maximum from each cluster.\n\nThere is also another type of pooling called minimum pooling. '

# %% [markdown]
# ![Screenshot%20%28424%29.png](attachment:Screenshot%20%28424%29.png)

# %%
"""Backpropagation in CNN"""
""""""

# %% [markdown]
# ![Screenshot%20%28425%29.png](attachment:Screenshot%20%28425%29.png)

# %% [markdown]
# ![Screenshot%20%28428%29.png](attachment:Screenshot%20%28428%29.png)

# %% [markdown]
# ![Screenshot%20%28429%29.png](attachment:Screenshot%20%28429%29.png)

# %% [markdown]
# ![Screenshot%20%28430%29.png](attachment:Screenshot%20%28430%29.png)

# %% [markdown]
# ![Screenshot%20%28433%29.png](attachment:Screenshot%20%28433%29.png)

# %% [markdown]
# ![Screenshot%20%28434%29.png](attachment:Screenshot%20%28434%29.png)

# %% [markdown]
# ![Screenshot%20%28435%29.png](attachment:Screenshot%20%28435%29.png)
